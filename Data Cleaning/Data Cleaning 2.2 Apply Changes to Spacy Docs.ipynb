# %% [markdown]
# # Incorporating Data Cleaning 1 and 2 changes to Spacy.
#
# Before proceeding with further data cleaning that will depend on untagged tokens in Spacy's document objects, we will apply our changes to the pickled spacy documents.
#
# Spacy outputs a doc object with several attributes, including tokens that have their own attributes that mark where they are in an entity. In other words, what we need to change are these attributes in the tokens of our documents (which we already imported above).
#
# Potentially useful token attributes include:
#
# |attribute| datatype| function|
# |--|--|--|
# |ent_type| int| Named entity type.|
# |ent_type_|unicode|Named entity type.|
# |ent_iob|int|IOB code of named entity tag. 3 means the token begins an entity, 2 means it is outside an entity, 1 means it is inside an entity, and 0 means no entity tag is set.|
# |ent_iob_|unicode|IOB code of named entity tag. “B” means the token begins an entity, “I” means it is inside an entity, “O” means it is outside an entity, and "" means no entity tag is set.|
# |ent_kb_id V2.2|int|Knowledge base ID that refers to the named entity this token is a part of, if any.|
# |ent_kb_id_ V2.2|unicode|Knowledge base ID that refers to the named entity this token is a part of, if any.|
# |ent_id|int|ID of the entity the token is an instance of, if any. Currently not used, but potentially for coreference resolution.|
# |ent_id_|unicode|ID of the entity the token is an instance of, if any. Currently not used, but potentially for coreference resolution.

# %% [markdown]
# From Spacy:
#
# > To ensure that the sequence of token annotations remains consistent, you have to set entity annotations at the document level. However, you can’t write directly to the token.ent_iob or token.ent_type attributes, so the easiest way to set entities is to assign to the doc.ents attribute and create the new entity as a Span.
#
# Sample code:
# ```python
# import spacy
# from spacy.tokens import Span
#
# nlp = spacy.load("en_core_web_sm")
# doc = nlp("fb is hiring a new vice president of global policy")
# ents = [(e.text, e.start_char, e.end_char, e.label_) for e in doc.ents]
# print('Before', ents)
# # the model didn't recognise "fb" as an entity :(
#
# fb_ent = Span(doc, 0, 1, label="ORG") # create a Span for the new entity
# doc.ents = list(doc.ents) + [fb_ent]
#
# ents = [(e.text, e.start_char, e.end_char, e.label_) for e in doc.ents]
# print('After', ents)
# # [('fb', 0, 2, 'ORG')] 🎉
# ```
# > Keep in mind that you need to create a Span with the start and end index of the token, not the start and end index of the entity in the document. In this case, “fb” is token (0, 1) – but at the document level, the entity will have the start and end indices (0, 2).
#
# Source: https://spacy.io/usage/linguistic-features#named-entities

# %% [markdown]
# So our plan will be to import our processed, pickled documents, and I believe the best approach is actually to drop all the PER tags, and then reupload the ones that weren't rejected with their updated spans and categories.

# %%
# importing pandas and our previous work in a new session
import pandas as pd
from IPython.display import clear_output
import spacy
from spacy import displacy
import pickle

# %%
file = open("../Text Mining (NER)/Trained_EMS2_NER_data.p", 'rb')
docs = pickle.load(file)

# %%
people = pd.read_csv('Files_Cleaning2/PER_tags_clean2_manual2.csv')

# %% [markdown]
# We sadly do not have entity IDs in our people dataframe (we do have their document ID, as well as their position within the document).  We do preserve the original spans, however, which can help us identify tokens.

# %%
people.groupby('Remove').count()
# Out:
#         Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  Unnamed: 0.1.1.1  \
# Remove
# 0            32350         32350           32350             32350
# 1              639           639             639               639
# D                6             6               6                 6
# L               44            44              44                44
# M                6             6               6                 6
# O               75            75              75                75
#
#         Unnamed: 0.1.1.1.1  Unnamed: 0.1.1.1.1.1  Unnamed: 0.1.1.1.1.1.1  \
# Remove
# 0                    32350                 32350                   32350
# 1                      639                   639                     639
# D                        6                     6                       6
# L                       44                    44                      44
# M                        6                     6                       6
# O                       75                    75                      75
#
#         Unnamed: 0.1.1.1.1.1.1.1  docid  string  label  start    end  \
# Remove
# 0                          32350  32350   32350  32350  32350  32350
# 1                            639    639     636     78    639    639
# D                              6      6       6      6      6      6
# L                             44     44      44     44     44     44
# M                              6      6       6      6      6      6
# O                             75     75      75     75     75     75
#
#         matched_str  edit_long  newstart  newend
# Remove
# 0             32350      32350       173     449
# 1               639          0         0       0
# D                 6          0         0       0
# L                44          0         0       0
# M                 6          0         0       0
# O                75          0         0       0

# %%
len(people)
# Out:
# 33120

# %% [markdown]
# The first thing we can do is drop all the entities marked as '1' in our people dataframe. The number of remaining rows should  be 32,481.

# %%
people = people[people['Remove']!='1']

# %%
len(people)
# Out:
# 32481

# %% [markdown]
# Recall that docs are stored as tuples with the doc itself and the ID as context.

# %%
docs[0]
# Out:
# (...martin de gaynça maestro mayor de las obras de canteria de la santa iglesia de Sevilla y juan sanchez de caliz maestro mayor de las obras (roto) desta dicha ciudad de sevilla... otorgamos... que damos todo nuestro poder... a rodrigo de cordova vecino de la ciudad de gibraltar... para... que por nos... pueda fazer qualquier yguala e convenencia... con luis de toro en nombre de su majestad para fazer un muro de abajo que se a de fazer en la ciudad de gibraltar desde san francisco fasta encima del cuchillo de una sierra que a de ser el dicho muro de grueso de nueve pies desde el dicho monasterio de san francisco fasta la cueva de san cristoval e desde la dicha cueva... fasta el cuchillo de la sierra a de ser de cuatro pies de grueso... e otrosi nos pueda obligar que faremos otras qualesquier obras de canteria e manposteria que fueren menester de se faser en la dicha ciudad de Gibraltar,
#  {'id': 1})

# %% [markdown]
# Creating a temporary list of entities in our file except for the PER entities:

# %%
tempents =[]

for doc, context in docs:
    ents = list(doc.ents)
    ents2 =[]
    for ent in ents:
        if ent.label_ != 'PER':
            a = spacy.tokens.Span(doc, ent.start,ent.end,label = ent.label)
            ents2.append(a)
    ents_id = [context['id'], ents2]
    tempents.append(ents_id)

# %%
print(tempents)
# Out:
# [[1, [santa iglesia, Sevilla, sevilla, gibraltar, gibraltar, san francisco, monasterio de san francisco, cueva de san cristoval, Gibraltar]], [2, [monasterio de san pablo, Sevilla, puerto de santa maria, fin del mes de marzo de 1543, 400 ducados]], [3, [monesterio e, convento de señor san pablo, Sevilla, 40000 maravedis]], [4, [Sevilla, Santa Iglesia, Sevilla, provincia del Rio de la Plata]], [5, [Llanos, 10.150 maravedis]], [6, [Moron, 75.000 maravedis]], [7, [Santa Iglesia, Sevilla]], [8, [Jerez de la Frontera, Puerto de Santa Maria]], [9, [Alcazares reales, Sevilla, 40 ducados de oro, Alcazar]], [10, [95.962 maravedis]], [11, []], [12, []], [13, [Santa Iglesia, Sevilla, 150.000 maravedis, Holanda]], [14, [Hospital de los Caballeros]], [15, [Moron]], [16, [Moron]], [17, [Nueva España]], [18, [Marchena]], [19, [Santa Iglesia, Sevilla, Sevilla, collacion de Santa Maria, Capilla del Sagrario, Catedral, Sevilla, Medina-Sidonia, seis ducados de oro, Aracena, un ducado de oro]], [20, [1.500 maravedis, calle Santo Domingo, Triana]], [21, [750 maravedis]], [22, [Sevilla, 7.480 maravedis]], [23, []], [24, [
es de julio deste año de 1650, 9 junio 1650]], [8521, [6 enero 1651]], [8522, [San Gil, Santa María la mayor, colegio de Santo Tomás, hospital de los Flamencos, primer día del mes de julio deste año 1651, 12 ducados, 11 mayo 1651, 10 ducados, 30 abril 1654]], [8523, [Santa Cofradía, 4 enero 1652]], [8524, [24 marzo 1652]], [8525, [Santa María, 16,000 reales en moneda de vellón, 22,0 reales, 31 mayo 1652]], [8526, [collación de la Iglesia Mayor, Coria, 400 pesos de plata, 8 reales, 8 de junio 1650, 5 octubre 1652]], [8527, [25 octubre 1652]], [8528, [18 noviembre 1652]], [8529, [14 diciembre 1652]], [8530, []], [8531, []], [8532, []], [8533, [9 julio 1653]], [8534, [Santa María, calle Francos, 100 ducados de moneda de vellón, provincia de Tierra Firme de Indias, 100 ducados, Santa María la mayor, 20 agosto 1653]], [8535, [20 mayo 1654]], [8536, [Sevilla, collación de Santa María, San Gregorio, 50 reales, 16 enero 1655]], [8537, [Sevilla, collación de Santa María, collación de San Gregorio, 6 ducados, 27 febrero 1655]], [8538, [Sevilla, calle de San Gregorio, collación de Santa María, calle de San Gregorio, 71 reales, 12 marzo 1655]], [8539, [Sevilla, collación de Santa María, calle del Rosario, collación de la Magdalena, 2,500 reales, 8 mayo 1655]], [8540, [collación de Santa María, 1,278 reales en moneda de vellón, fin del mes de junio del año, calle y corral de San Gregorio, 20 agosto 1655]], [8541, [2 noviembre 1655]], [8542, [calle Abades]], [8543, [22 reales, 23, mayo 1657]], [8544, [collación de Santa María, 15 octubre 1657]], [8545, [Santa Iglesia, Sevilla, calle de Abades, 1,300 reales de moneda de vellón, 15 octubre 1657]], [8546, [1658, San Alberto]], [8547, [Sevilla, collación de Santa María  ...

# %%
for doc, context in docs:
    for item in tempents:
        if item[0]==context['id']:
            doc.ents= item[1]

# %% [markdown]
# Now we should have replaced all entities in the documents with the filtered tags. If we display a document with displacy, this should be reflected:

# %%
displacy.render(docs[0][0],style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">...martin de gaynça maestro mayor de las obras de canteria de la
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     santa iglesia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  de
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Sevilla
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  y juan sanchez de caliz maestro mayor de las obras (roto) desta dicha ciudad de
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     sevilla
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# ... otorgamos... que damos todo nuestro poder... a rodrigo de cordova vecino de la ciudad de
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     gibraltar
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# ... para... que por nos... pueda fazer qualquier yguala e convenencia... con luis de toro en nombre de su majestad para fazer un muro de abajo que se a de fazer en la ciudad de
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     gibraltar
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  desde
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     san francisco
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  fasta encima del cuchillo de una sierra que a de ser el dicho muro de grueso de nueve pies desde el dicho
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     monasterio de san francisco
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  fasta la
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     cueva de san cristoval
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  e desde la dicha cueva... fasta el cuchillo de la sierra a de ser de cuatro pies de grueso... e otrosi nos pueda obligar que faremos otras qualesquier obras de canteria e manposteria que fueren menester de se faser en la dicha ciudad de
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Gibraltar
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# </div></span>

# %% [markdown]
# This should be reflected in tokens' ent_iob attributes, where 2 means that they are not assigned to any entity. This should prove true for names, like the first 3 tokens.

# %%
for token in docs[0][0]:
    print(token.ent_iob,end=" ")
# Out:
# 2 2 2 2 2 2 2 2 2 2 2 2 2 3 1 2 3 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 3 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 3 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 3 2 3 1 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 3 1 1 1 2 2 3 1 1 1 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 3

# %% [markdown]
# Now, let's create a list with the same format for our person entities. We will need to have a list of lists where each item is a docnumber and a list of Span objects as such:
#
# spacy.tokens.Span(doc, ent.start,ent.end,label = ent.label)
#
# To make this process easier, it might help to transfer the information contained in the Remove section. Additionally, we will transfer begin and end values to any empty newbegin and newend cells, so we can use the latter as the start and end points of our spans (endpoint = newend-1).

# %%
people.groupby('edit_long').count()
# Out:
#            Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  Unnamed: 0.1.1.1  \
# edit_long
# 0               31582         31582           31582             31582
# 1                 610           610             610               610
# o                 158           158             158               158
#
#            Unnamed: 0.1.1.1.1  Unnamed: 0.1.1.1.1.1  Unnamed: 0.1.1.1.1.1.1  \
# edit_long
# 0                       31582                 31582                   31582
# 1                         610                   610                     610
# o                         158                   158                     158
#
#            Unnamed: 0.1.1.1.1.1.1.1  docid  string  label  start    end  \
# edit_long
# 0                             31582  31582   31582  31582  31582  31582
# 1                               610    610     610    610    610    610
# o                               158    158     158    158    158    158
#
#            Remove  matched_str  newstart  newend
# edit_long
# 0           31582        31582         0       0
# 1             610          610       173     449
# o             158          158         0       0

# %%
people.fillna('').groupby(['Remove','label']).count()
# Out:
#               Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  Unnamed: 0.1.1.1  \
# Remove label
# 0      PER         32350         32350           32350             32350
# D      DATE            6             6               6                 6
# L      LOC            39            39              39                39
#        PER             5             5               5                 5
# M      MON             6             6               6                 6
# O      ORG            66            66              66                66
#        PER             9             9               9                 9
#
#               Unnamed: 0.1.1.1.1  Unnamed: 0.1.1.1.1.1  \
# Remove label
# 0      PER                 32350                 32350
# D      DATE                    6                     6
# L      LOC                    39                    39
#        PER                     5                     5
# M      MON                     6                     6
# O      ORG                    66                    66
#        PER                     9                     9
#
#               Unnamed: 0.1.1.1.1.1.1  Unnamed: 0.1.1.1.1.1.1.1  docid  string  \
# Remove label
# 0      PER                     32350                     32350  32350   32350
# D      DATE                        6                         6      6       6
# L      LOC                        39                        39     39      39
#        PER                         5                         5      5       5
# M      MON                         6                         6      6       6
# O      ORG                        66                        66     66      66
#        PER                         9                         9      9       9
#
#               start    end  matched_str  edit_long  newstart  newend
# Remove label
# 0      PER    32350  32350        32350      32350     32350   32350
# D      DATE       6      6            6          6         6       6
# L      LOC       39     39           39         39        39      39
#        PER        5      5            5          5         5       5
# M      MON        6      6            6          6         6       6
# O      ORG       66     66           66         66        66      66
#        PER        9      9            9          9         9       9

# %%
people.loc[(people['Remove']=='L')&(people['label']=='PER'),'label']='LOC'

# %%
people.loc[(people['Remove']=='O')&(people['label']=='PER'),'label']='ORG'

# %%
people.loc[people['newstart'].isnull(),'newstart'] = people['start']

# %%
people['newstart']
# Out:
# 1          6.0
# 2         34.0
# 3         11.0
# 4         29.0
# 5         14.0
#          ...
# 33115     19.0
# 33116     28.0
# 33117    238.0
# 33118     90.0
# 33119    649.0
# Name: newstart, Length: 32481, dtype: float64

# %%
people.loc[people['newend'].isnull(),'newend'] = people['end']

# %%
people['newstart']=people['newstart'].astype(int)
people['newend']=people['newend'].astype(int)

# %%
people['newstart']
# Out:
# 1          6
# 2         34
# 3         11
# 4         29
# 5         14
#         ...
# 33115     19
# 33116     28
# 33117    238
# 33118     90
# 33119    649
# Name: newstart, Length: 32481, dtype: int64

# %%
people.fillna('').groupby(['Remove','label']).count()
# Out:
#               Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  Unnamed: 0.1.1.1  \
# Remove label
# 0      PER         32350         32350           32350             32350
# D      DATE            6             6               6                 6
# L      LOC            44            44              44                44
# M      MON             6             6               6                 6
# O      ORG            75            75              75                75
#
#               Unnamed: 0.1.1.1.1  Unnamed: 0.1.1.1.1.1  \
# Remove label
# 0      PER                 32350                 32350
# D      DATE                    6                     6
# L      LOC                    44                    44
# M      MON                     6                     6
# O      ORG                    75                    75
#
#               Unnamed: 0.1.1.1.1.1.1  Unnamed: 0.1.1.1.1.1.1.1  docid  string  \
# Remove label
# 0      PER                     32350                     32350  32350   32350
# D      DATE                        6                         6      6       6
# L      LOC                        44                        44     44      44
# M      MON                         6                         6      6       6
# O      ORG                        75                        75     75      75
#
#               start    end  matched_str  edit_long  newstart  newend
# Remove label
# 0      PER    32350  32350        32350      32350     32350   32350
# D      DATE       6      6            6          6         6       6
# L      LOC       44     44           44         44        44      44
# M      MON        6      6            6          6         6       6
# O      ORG       75     75           75         75        75      75

# %%
people[people['edit_long']=='1']
# Out:
#        Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  Unnamed: 0.1.1.1  \
# 814           814           814             814               814
# 815           815           815             815               815
# 816           816           816             816               816
# 817           817           817             817               817
# 898           898           898             898               898
# ...           ...           ...             ...               ...
# 32942       32942         32942           32942             32942
# 32982       32982         32982           32982             32982
# 33061       33061         33061           33061             33061
# 33070       33070         33070           33070             33070
# 33105       33105         33105           33105             33105
#
#        Unnamed: 0.1.1.1.1  Unnamed: 0.1.1.1.1.1  Unnamed: 0.1.1.1.1.1.1  \
# 814                   814                   814                   21404
# 815                   815                   815                   21356
# 816                   816                   816                   21254
# 817                   817                   817                   21434
# 898                   898                   898                   19755
# ...                   ...                   ...                     ...
# 32942               32942                 32942                   27836
# 32982               32982                 32982                   41245
# 33061               33061                 33061                   19414
# 33070               33070                 33070                    8106
# 33105               33105                 33105                   21141
#
#        Unnamed: 0.1.1.1.1.1.1.1  docid                            string  \
# 814                       21404   2329                 Alarcon Escribano
# 815                       21356   2327         Alarcon Escribano Publico
# 816                       21254   2325         Alarcon Escribano Publico
# 817                       21434   2330         Alarcon Escribano Publico
# 898                       19755   2186               Alo alarcon escriuo
# ...                         ...    ...                               ...
# 32942                     27836   3007       xpoval nuñes frayle profefo
# 32982                     41245   4427             ynes carrillo buestra
# 33061                     19414   2148                ysabel india horra
# 33070                      8106   1065  ysabel rrodriguez hermoso vezina
# 33105                     21141   2321     Francisco Saavedra Escribano
#
#       label  start   end Remove  matched_str edit_long  newstart  newend
# 814     PER    299   301      0            1         1       299     300
# 815     PER   2301  2304      0            1         1      2301    2302
# 816     PER    253   256      0            1         1       253     254
# 817     PER    448   451      0            1         1       448     449
# 898     PER   1584  1588      0            0         1      1584    1587
# ...     ...    ...   ...    ...          ...       ...       ...     ...
# 32942   PER     17    21      0            0         1        17      19
# 32982   PER    130   133      0            0         1       130     132
# 33061   PER     41    44      0            0         1        41      42
# 33070   PER      2     6      0            0         1         2       5
# 33105   PER   1821  1826      0            1         1      1821    1825
#
# [610 rows x 18 columns]

# %% [markdown]
# Now we can use the information in our docid, label, newstart and newend columns to build our spans.

# %%
people2 = people[['docid','label','newstart','newend']].values.tolist()

# %%
people2
# Out:
# [[4978, 'PER', 6, 8],
#  [4961, 'PER', 34, 38],
#  [4952, 'PER', 11, 13],
#  [7342, 'PER', 29, 31],
#  [4803, 'PER', 14, 16],
#  [5849, 'PER', 32, 34],
#  [5588, 'PER', 23, 25],
#  [5810, 'PER', 1, 5],
#  [8589, 'PER', 177, 182],
#  [7839, 'PER', 1, 4],
#  [5229, 'PER', 14, 18],
#  [5402, 'PER', 5, 7],
#  [3748, 'PER', 0, 2],
#  [3739, 'PER', 1, 3],
#  [3465, 'PER', 0, 3],
#  [3855, 'PER', 0, 3],
#  [3623, 'PER', 0, 2],
#  [2622, 'PER', 0, 3],
#  [1223, 'PER', 372, 376],
#  [124, 'PER', 7, 9],
#  [8056, 'PER', 7, 9],
#  [8579, 'PER', 101, 104],
#  [4999, 'PER', 16, 19],
#  [5000, 'PER', 49, 52],
#  [4997, 'PER', 26, 29],
#  [4997, 'PER', 83, 86],
#  [5666, 'PER', 9, 11],
#  [8063, 'PER', 0, 2],
#  [6170, 'PER', 25, 27],
#  [5665, 'PER', 24, 26],
#  [5664, 'PER', 97, 99],
#  [5663, 'PER', 13, 15],
#  [5884, 'PER', 7, 9],
#  [5883, 'PER', 15, 17],
#  [7547, 'PER', 5, 7],
#  [7548, 'PER', 30, 32],
#  [7544, 'PER', 0, 3],
#  [7545, 'PER', 34, 37],
#  [7546, 'PER', 0, 3],
#  [6127, 'PER', 19, 21],
#  [5447, 'PER', 82, 84],
#  [8379, 'PER', 82, 84],
#  [5500, 'PER', 1083, 1085],
#  [5500, 'PER', 1027, 1029],
#  [8379, 'PER', 71, 73],
#  [5447, 'PER', 71, 73],
#  [8090, 'PER', 287, 289],
#  [7355, 'PER', 56, 58],
#  [6564, 'PER', 7, 9],
#  [5868, 'PER', 52, 54],
#  [8233, 'PER', 0, 2],
#  [5858, 'PER', 15, 17],
#  [8503, 'PER', 1302, 1304],
#  [8117, 'PER', 6, 8],
#  [5879, 'PER', 0, 2],
#  [8116, 'PER', 41, 43],
#  [8570, 'PER', 103, 105],
#  [5863, 'PER', 143, 145],
#  [4675, 'PER', 86, 88],
#  [5878, 'PER', 43, 45],
#  [6564, 'PER', 112, 114],
#  [7354, 'PER', 89, 91],
#  [6564, 'PER', 205, 207],
#  [5001, 'PER', 163, 165],
#  [6568, 'PER', 74, 76],
#  [7354, 'PER', 7, 9],
#  [5342, 'PER', 85, 87],
#  [6554, 'PER', 6, 8],
#  [5302, 'PER', 70, 72],
#  [6558, 'PER', 13, 15],
#  [6574, 'PER', 9, 11],
#  [5296, 'PER', 8, 10],
#  [6564, 'PER', 100, 102],
#  [7693, 'PER', 6, 8],
#  [7694, 'PER', 13, 15],
#  [7691, 'PER', 5, 7],
#  [7690, 'PER', 6, 8],
#  [7689, 'PER', 10, 12],
#  [7688, 'PER', 42, 44],
#  [7692, 'PER', 8, 10],
#  [4677, 'PER', 0, 3],
#  [5118, 'PER', 8, 11],
#  [4725, 'PER', 10, 13],
#  [4676, 'PER', 0, 3],
#  [5622, 'PER', 14, 17],
#  [5620, 'PER', 4, 7],
#  [5624, 'PER', 47, 50],
#  [5621, 'PER', 8, 11],
#  [7145, 'PER', 10, 13],
#  [8358, 'PER', 21, 24],
#  [8358, 'PER', 45, 48],
#  [8370, 'PER', 7, 10],
#  [8348, 'PER', 56, 59],
#  [8362, 'PER', 55, 58],
#  [8560, 'PER', 21, 24],
#  [8347, 'PER', 0, 3],
#  [8562, 'PER', 113, 116],
#  [8364, 'PER', 528, 531],
#  [8364, 'PER', 301, 304],
#  [8359, 'PER', 50, 53],
#  [8364, 'PER', 12, 15],
#  [7218, 'PER', 142, 145],
#  [8363, 'PER', 128, 131],
#  [8350, 'PER', 9, 12],
#  [8356, 'PER', 0, 3],
#  [5204, 'PER', 60, 63],
#  [8373, 'PER', 9, 12],
#  [8363, 'PER', 32, 35],
#  [8372, 'PER', 33, 36],
#  [8369, 'PER', 7, 10],
#  [8368, 'PER', 7, 10],
#  [8349, 'PER', 29, 32],
#  [8357, 'PER', 0, 3],
#  [8354, 'PER', 4, 7],
#  [8361, 'PER', 15, 18],
#  [8352, 'PER', 0, 3],
#  [8366, 'PER', 7, 10],
#  [7536, 'PER', 18, 21],
#  [8499, 'PER', 347, 350],
#  [8505, 'PER', 249, 252],
#  [8376, 'PER', 0, 3],
#  [8505, 'PER', 264, 267],
#  [8505, 'PER', 288, 291],
#  [8501, 'PER', 16, 19],
#  [8496, 'PER', 0, 3],
#  [8377, 'PER', 0, 3],
#  [8500, 'PER', 21, 24],
#  [8462, 'PER', 10, 13],
#  [8450, 'PER', 29, 32],
#  [8466, 'PER', 15, 18],
#  [8374, 'PER', 0, 3],
#  [8375, 'PER', 0, 3],
#  [8484, 'PER', 47, 50],
#  [8499, 'PER', 263, 266],
#  [5883, 'PER', 47, 49],
#  [8502, 'PER', 109, 111],
#  [5505, 'PER', 51, 53],
#  [8499, 'PER', 316, 318],
#  [5502, 'PER', 23, 25],
#  [5471, 'PER', 7, 9],
#  [5459, 'PER', 7, 9],
#  [5460, 'PER', 7, 9],
#  [5461, 'PER', 0, 2],
#  [5462, 'PER', 7, 9],
#  [5501, 'PER', 34, 36],
#  [5463, 'PER', 0, 2],
#  [5464, 'PER', 7, 9],
#  [5465, 'PER', 0, 2],
#  [5458, 'PER', 7, 9],
#  [5466, 'PER', 7, 9],
#  [5468, 'PER', 7, 9],
#  [5469, 'PER', 7, 9],
#  [5470, 'PER', 7, 9],
#  [8424, 'PER', 23, 25],
#  [5472, 'PER', 7, 9],
#  [5473, 'PER', 7, 9],
#  [8424, 'PER', 100, 102],
#  [5474, 'PER', 7, 9],
#  [5467, 'PER', 7, 9],
#  [5475, 'PER', 0, 2],
#  [5457, 'PER', 40, 42],
#  [5455, 'PER', 7, 9],
#  [8403, 'PER', 23, 25],
#  [8421, 'PER', 19, 21],
#  [8513, 'PER', 72, 74],
#  [8423, 'PER', 46, 48],
#  [8476, 'PER', 18, 20],
#  [5442, 'PER', 7, 9],
#  [5443, 'PER', 27, 29],
#  [5444, 'PER', 7, 9],
#  [5456, 'PER', 7, 9],
#  [8505, 'PER', 26, 28],
#  [5446, 'PER', 49, 51],
#  [5448, 'PER', 7, 9],
#  [5449, 'PER', 21, 23],
#  [5450, 'PER', 21, 23],
#  [5451, 'PER', 5, 7],
#  [5452, 'PER', 14, 16],
#  [5453, 'PER', 7, 9],
#  [5454, 'PER', 28, 30],
#  [5445, 'PER', 7, 9],
#  [5476, 'PER', 0, 2],
#  [8513, 'PER', 83, 85],
#  [5477, 'PER', 0, 2],
#  [5482, 'PER', 0, 2],
#  [5483, 'PER', 9, 11],
#  [5485, 'PER', 22, 24],
#  [5486, 'PER', 0, 2],
#  [5488, 'PER', 0, 2],
#  [5489, 'PER', 0, 2],
#  [5490, 'PER', 0, 2],
#  [5491, 'PER', 0, 2],
#  [5492, 'PER', 0, 2],
#  [8570, 'PER', 244, 246],
#  [8476, 'PER', 115, 117],
#  [8426, 'PER', 48, 50],
#  [5494, 'PER', 0, 2],
#  [5495, 'PER', 0, 2],
#  [5496, 'PER', 0, 2],
#  [5497, 'PER', 0, 2],
#  [5498, 'PER', 0, 2],
#  [5499, 'PER', 14, 16],
#  [8427, 'PER', 15, 17],
#  [5500, 'PER', 65, 67],
#  [5500, 'PER', 997, 999],
#  [5500, 'PER', 1149, 1151],
#  [5493, 'PER', 0, 2],
#  [5481, 'PER', 0, 2],
#  [5484, 'PER', 4, 6],
#  [8425, 'PER', 130, 132],
#  [8425, 'PER', 23, 25],
#  [5480, 'PER', 0, 2],
#  [5478, 'PER', 42, 44],
#  [5479, 'PER', 0, 2],
#  [8425, 'PER', 207, 209],
#  [5505, 'PER', 22, 27],
#  [6257, 'PER', 0, 2],
#  [7253, 'PER', 7, 9],
#  [6258, 'PER', 41, 43],
#  [6256, 'PER', 0, 2],
#  [6255, 'PER', 34, 36],
#  [6255, 'PER', 2, 4],
#  [5287, 'PER', 10, 12],
#  [5127, 'PER', 860, 864],
#  [7390, 'PER', 27, 29],
#  [7267, 'PER', 64, 66],
#  [7455, 'PER', 3, 7],
#  [7316, 'PER', 0, 2],
#  [7317, 'PER', 0, 2],
#  [6821, 'PER', 10, 12],
#  [7314, 'PER', 0, 2],
#  [7312, 'PER', 0, 2],
#  [7308, 'PER', 0, 2],
#  [7311, 'PER', 0, 2],
#  [7306, 'PER', 65, 67],
#  [7347, 'PER', 0, 2],
#  [7318, 'PER', 0, 2],
#  [7313, 'PER', 0, 2],
#  [7309, 'PER', 21, 23],
#  [7344, 'PER', 0, 2],
#  [7346, 'PER', 0, 2],
#  [7345, 'PER', 0, 2],
#  [7310, 'PER', 0, 2],
#  [7307, 'PER', 0, 2],
#  [6581, 'PER', 29, 31],
#  [7315, 'PER', 19, 21],
#  [7342, 'PER', 43, 45],
#  [7343, 'PER', 0, 2],
#  [7323, 'PER', 0, 2],
#  [6818, 'PER', 42, 44],
#  [7338, 'PER', 22, 24],
#  [7337, 'PER', 0, 2],
#  [7336, 'PER', 23, 25],
#  [7335, 'PER', 18, 20],
#  [8240, 'PER', 27, 29],
#  [7334, 'PER', 0, 2],
#  [7339, 'PER', 38, 40],
#  [7333, 'PER', 29, 31],
#  [7332, 'PER', 0, 2],
#  [7331, 'PER', 21, 23],
#  [8241, 'PER', 47, 49],
#  [8242, 'PER', 89, 91],
#  [7330, 'PER', 0, 2],
#  [7329, 'PER', 30, 32],
#  [8243, 'PER', 63, 65],
#  [8247, 'PER', 19, 21],
#  [8247, 'PER', 107, 109],
#  [7319, 'PER', 0, 2],
#  [7341, 'PER', 0, 2],
#  [7340, 'PER', 0, 2],
#  [7320, 'PER', 0, 2],
#  [7321, 'PER', 0, 2],
#  [7322, 'PER', 28, 30],
#  [8283, 'PER', 119, 121],
#  [7324, 'PER', 17, 19],
#  [7325, 'PER', 13, 15],
#  [8260, 'PER', 0, 2],
#  [7326, 'PER', 33, 35],
#  [8247, 'PER', 136, 138],
#  [7327, 'PER', 21, 23],
#  [7328, 'PER', 27, 29],
#  [7324, 'PER', 63, 65],
#  [7306, 'PER', 3, 5],
#  [5375, 'PER', 30, 32],
#  [7304, 'PER', 12, 14],
#  [7240, 'PER', 53, 55],
#  [7241, 'PER', 0, 2],
#  [7242, 'PER', 7, 9],
#  [7243, 'PER', 0, 2],
#  [7244, 'PER', 32, 34],
#  [7244, 'PER', 131, 133],
#  [7245, 'PER', 60, 62],
#  [7246, 'PER', 7, 9],
#  [7247, 'PER', 7, 9],
#  [7248, 'PER', 7, 9],
#  [7249, 'PER', 7, 9],
#  [7250, 'PER', 7, 9],
#  [7251, 'PER', 0, 2],
#  [7252, 'PER', 34, 36],
#  [7254, 'PER', 40, 42],
#  [7255, 'PER', 0, 2],
#  [7256, 'PER', 27, 29],
#  [7257, 'PER', 0, 2],
#  [7258, 'PER', 7, 9],
#  [7239, 'PER', 25, 27],
#  [7238, 'PER', 7, 9],
#  [7237, 'PER', 31, 33],
#  [7236, 'PER', 77, 79],
#  [7218, 'PER', 15, 17],
#  [7218, 'PER', 99, 101],
#  [7218, 'PER', 119, 121],
#  [7219, 'PER', 7, 9],
#  [7220, 'PER', 7, 9],
#  [7221, 'PER', 7, 9],
#  [7222, 'PER', 4, 6],
#  [7223, 'PER', 0, 2],
#  [7224, 'PER', 16, 18],
#  [6580, 'PER', 35, 37],
#  [7225, 'PER', 7, 9],
#  [7227, 'PER', 7, 9],
#  [7228, 'PER', 7, 9],
#  [7229, 'PER', 11, 13],
#  [7230, 'PER', 0, 2],
#  [7231, 'PER', 7, 9],
#  [7232, 'PER', 3, 5],
#  [7233, 'PER', 27, 29],
#  [7234, 'PER', 63, 65],
#  [7235, 'PER', 7, 9],
#  [7226, 'PER', 7, 9],
#  [7259, 'PER', 0, 2],
#  [7260, 'PER', 42, 44],
#  [7261, 'PER', 39, 41],
#  [7285, 'PER', 45, 47],
#  [7286, 'PER', 38, 40],
#  [7287, 'PER', 0, 2],
#  [7288, 'PER', 40, 42],
#  [7289, 'PER', 15, 17],
#  [7290, 'PER', 0, 2],
#  [7291, 'PER', 0, 2],
#  [7292, 'PER', 0, 2],
#  [7292, 'PER', 77, 79],
#  [7284, 'PER', 17, 19],
#  [7293, 'PER', 10, 12],
#  [7295, 'PER', 0, 2],
#  [7296, 'PER', 0, 2],
#  [7297, 'PER', 0, 2],
#  [7298, 'PER', 5, 7],
#  [7299, 'PER', 0, 2],
#  [7300, 'PER', 0, 2],
#  [7301, 'PER', 0, 2],
#  [7302, 'PER', 17, 19],
#  [7303, 'PER', 6, 8],
#  [7294, 'PER', 6, 8],
#  [7305, 'PER', 0, 2],
#  [7283, 'PER', 0, 2],
#  [7281, 'PER', 17, 19],
#  [7261, 'PER', 127, 129],
#  [7262, 'PER', 7, 9],
#  [7263, 'PER', 7, 9],
#  [7264, 'PER', 7, 9],
#  [7265, 'PER', 9, 11],
#  [7266, 'PER', 3, 5],
#  [7267, 'PER', 173, 175],
#  [7268, 'PER', 7, 9],
#  [7269, 'PER', 7, 9],
#  [7282, 'PER', 0, 2],
#  [7270, 'PER', 34, 36],
#  [7272, 'PER', 3, 5],
#  [7273, 'PER', 0, 2],
#  [7274, 'PER', 7, 9],
#  [7275, 'PER', 3, 5],
#  [7276, 'PER', 56, 58],
#  [7278, 'PER', 16, 18],
#  [7278, 'PER', 47, 49],
#  [7279, 'PER', 0, 2],
#  [7280, 'PER', 29, 31],
#  [7271, 'PER', 30, 32],
#  [7348, 'PER', 16, 18],
#  [7181, 'PER', 44, 46],
#  [7350, 'PER', 32, 34],
#  [7416, 'PER', 17, 19],
#  [7415, 'PER', 14, 16],
#  [7414, 'PER', 24, 26],
#  [7413, 'PER', 0, 2],
#  [5884, 'PER', 27, 29],
#  [7412, 'PER', 0, 2],
#  [7411, 'PER', 0, 2],
#  [7410, 'PER', 23, 25],
#  [6000, 'PER', 0, 2],
#  [7409, 'PER', 0, 2],
#  [7408, 'PER', 0, 2],
#  [7407, 'PER', 0, 2],
#  [7406, 'PER', 258, 260],
#  [7406, 'PER', 220, 222],
#  [7349, 'PER', 0, 2],
#  [7406, 'PER', 40, 42],
#  [7405, 'PER', 0, 2],
#  [7404, 'PER', 0, 2],
#  [7403, 'PER', 44, 46],
#  [7403, 'PER', 25, 27],
#  [6135, 'PER', 61, 63],
#  [7402, 'PER', 0, 2],
#  [7401, 'PER', 0, 2],
#  [6136, 'PER', 23, 25],
#  [7400, 'PER', 0, 2],
#  [7399, 'PER', 0, 2],
#  [7398, 'PER', 18, 20],
#  [7397, 'PER', 16, 18],
#  [7396, 'PER', 0, 2],
#  [7395, 'PER', 10, 12],
#  [7406, 'PER', 4, 6],
#  [7394, 'PER', 7, 9],
#  [7418, 'PER', 0, 2],
#  [7420, 'PER', 0, 2],
#  [5213, 'PER', 63, 65],
#  [5270, 'PER', 0, 2],
#  [5132, 'PER', 41, 43],
#  [5409, 'PER', 57, 59],
#  [5414, 'PER', 0, 2],
#  [5415, 'PER', 3, 5],
#  [5415, 'PER', 11, 13],
#  [5441, 'PER', 0, 2],
#  [7671, 'PER', 63, 65],
#  [4968, 'PER', 0, 2],
#  [5528, 'PER', 38, 40],
#  [5538, 'PER', 0, 2],
#  [4692, 'PER', 37, 39],
#  [4688, 'PER', 30, 32],
#  [7419, 'PER', 0, 2],
#  [4683, 'PER', 33, 35],
#  [4678, 'PER', 47, 49],
#  [7465, 'PER', 6, 8],
#  [7462, 'PER', 14, 16],
#  [7448, 'PER', 6, 8],
#  [5667, 'PER', 17, 19],
#  [5695, 'PER', 8, 10],
#  [5698, 'PER', 0, 2],
#  [7806, 'PER', 0, 2],
#  [5701, 'PER', 75, 77],
#  [7426, 'PER', 30, 32],
#  [5710, 'PER', 31, 33],
#  [5710, 'PER', 40, 42],
#  [7422, 'PER', 18, 20],
#  [7421, 'PER', 14, 16],
#  [4682, 'PER', 38, 40],
#  [7393, 'PER', 0, 2],
#  [7417, 'PER', 0, 2],
#  [7360, 'PER', 36, 38],
#  [7378, 'PER', 0, 2],
#  [7358, 'PER', 27, 29],
#  [7377, 'PER', 0, 2],
#  [7376, 'PER', 0, 2],
#  [7375, 'PER', 0, 2],
#  [7374, 'PER', 86, 88],
#  [7374, 'PER', 17, 19],
#  [7373, 'PER', 0, 2],
#  [7372, 'PER', 0, 2],
#  [7371, 'PER', 0, 2],
#  [7379, 'PER', 0, 2],
#  [7369, 'PER', 0, 2],
#  [7368, 'PER', 48, 50],
#  [7367, 'PER', 0, 2],
#  [6475, 'PER', 27, 29],
#  [7366, 'PER', 35, 37],
#  [7365, 'PER', 0, 2],
#  [7364, 'PER', 0, 2],
#  [7363, 'PER', 5, 7],
#  [7362, 'PER', 0, 2],
#  [7361, 'PER', 0, 2],
#  [7359, 'PER', 0, 2],
#  [7368, 'PER', 57, 59],
#  [7357, 'PER', 0, 2],
#  [7370, 'PER', 0, 2],
#  [7381, 'PER', 0, 2],
#  [7354, 'PER', 40, 42],
#  [7353, 'PER', 0, 2],
#  [7380, 'PER', 0, 2],
#  [7387, 'PER', 15, 17],
#  [7354, 'PER', 140, 142],
#  [7355, 'PER', 21, 23],
#  [7386, 'PER', 0, 2],
#  [7385, 'PER', 0, 2],
#  [7389, 'PER', 0, 2],
#  [7352, 'PER', 29, 31],
#  [8572, 'PER', 674, 676],
#  [7391, 'PER', 10, 12],
#  [7351, 'PER', 0, 2],
#  [7356, 'PER', 0, 2],
#  [7383, 'PER', 29, 31],
#  [7392, 'PER', 9, 11],
#  [7382, 'PER', 0, 2],
#  [7384, 'PER', 15, 17],
#  [7388, 'PER', 0, 2],
#  [7449, 'PER', 0, 4],
#  [5843, 'PER', 7, 11],
#  [5843, 'PER', 159, 163],
#  [7450, 'PER', 7, 11],
#  [7460, 'PER', 7, 11],
#  [7459, 'PER', 0, 4],
#  [7458, 'PER', 105, 109],
#  [7457, 'PER', 0, 4],
#  [7456, 'PER', 3, 7],
#  [7463, 'PER', 24, 28],
#  [5663, 'PER', 0, 4],
#  [6475, 'PER', 54, 58],
#  [7461, 'PER', 13, 17],
#  [7463, 'PER', 8, 12],
#  [7464, 'PER', 8, 12],
#  [7454, 'PER', 0, 4],
#  [7466, 'PER', 8, 12],
#  [7452, 'PER', 11, 15],
#  [7453, 'PER', 7, 11],
#  [7466, 'PER', 23, 27],
#  [7451, 'PER', 0, 4],
#  [7469, 'PER', 0, 3],
#  [7423, 'PER', 45, 48],
#  [7277, 'PER', 0, 2],
#  [7687, 'PER', 14, 17],
#  [7796, 'PER', 89, 91],
#  [7794, 'PER', 0, 2],
#  [7795, 'PER', 17, 19],
#  [7797, 'PER', 33, 35],
#  [7798, 'PER', 27, 29],
#  [7808, 'PER', 133, 135],
#  [8355, 'PER', 0, 2],
#  [8561, 'PER', 116, 118],
#  [8367, 'PER', 7, 9],
#  [8365, 'PER', 28, 32],
#  [8371, 'PER', 7, 9],
#  [8351, 'PER', 0, 2],
#  [8360, 'PER', 153, 155],
#  [8353, 'PER', 6, 8],
#  [7043, 'PER', 37, 39],
#  [5292, 'PER', 0, 2],
#  [7043, 'PER', 0, 2],
#  [8070, 'PER', 224, 226],
#  [8070, 'PER', 394, 396],
#  [8070, 'PER', 136, 138],
#  [5680, 'PER', 14, 16],
#  [7051, 'PER', 33, 35],
#  [5165, 'PER', 0, 2],
#  [5162, 'PER', 13, 15],
#  [5163, 'PER', 69, 71],
#  [5160, 'PER', 31, 33],
#  [5154, 'PER', 8, 10],
#  [5166, 'PER', 22, 24],
#  [5167, 'PER', 1, 3],
#  [5161, 'PER', 12, 14],
#  [5159, 'PER', 42, 44],
#  [5158, 'PER', 44, 46],
#  [5157, 'PER', 9, 11],
#  [5156, 'PER', 25, 27],
#  [5155, 'PER', 31, 33],
#  [5178, 'PER', 14, 16],
#  [5153, 'PER', 6, 10],
#  [6015, 'PER', 9, 12],
#  [6016, 'PER', 10, 13],
#  [5164, 'PER', 0, 3],
#  [5525, 'PER', 67, 69],
#  [5670, 'PER', 0, 2],
#  [5669, 'PER', 0, 2],
#  [5668, 'PER', 0, 2],
#  [5671, 'PER', 36, 38],
#  [5671, 'PER', 0, 2],
#  [6827, 'PER', 36, 38],
#  [5667, 'PER', 0, 2],
#  [8299, 'PER', 37, 39],
#  [8297, 'PER', 19, 21],
#  [7013, 'PER', 51, 53],
#  [6802, 'PER', 0, 2],
#  [7423, 'PER', 53, 56],
#  [7724, 'PER', 15, 17],
#  [7104, 'PER', 10, 12],
#  [5304, 'PER', 24, 26],
#  [5335, 'PER', 95, 97],
#  [5315, 'PER', 58, 60],
#  [5310, 'PER', 0, 2],
#  [8090, 'PER', 64, 66],
#  [5366, 'PER', 53, 55],
#  [8091, 'PER', 62, 64],
#  [8090, 'PER', 31, 33],
#  [5321, 'PER', 539, 541],
#  [5334, 'PER', 0, 4],
#  [7423, 'PER', 4, 6],
#  [7423, 'PER', 24, 27],
#  [8559, 'PER', 16, 18],
#  [8559, 'PER', 149, 151],
#  [7923, 'PER', 75, 77],
#  [4723, 'PER', 6, 9],
#  [6139, 'PER', 8, 11],
#  [5108, 'PER', 8, 11],
#  [6138, 'PER', 0, 3],
#  [6136, 'PER', 89, 92],
#  [6136, 'PER', 65, 68],
#  [6135, 'PER', 33, 36],
#  [7217, 'PER', 1, 4],
#  [7594, 'PER', 5, 8],
#  [6108, 'PER', 0, 3],
#  [8230, 'PER', 41, 44],
#  [8231, 'PER', 23, 26],
#  [8232, 'PER', 5, 8],
#  [8227, 'PER', 34, 37],
#  [8228, 'PER', 29, 32],
#  [8233, 'PER', 20, 23],
#  [8229, 'PER', 25, 28],
#  [8230, 'PER', 7, 10],
#  [8499, 'PER', 356, 359],
#  [6103, 'PER', 0, 3],
#  [6114, 'PER', 1, 4],
#  [6105, 'PER', 0, 3],
#  [6104, 'PER', 44, 47],
#  [6102, 'PER', 0, 3],
#  [6101, 'PER', 0, 3],
#  [6118, 'PER', 1, 4],
#  [5400, 'PER', 11, 13],
#  [5495, 'PER', 16, 18],
#  [5494, 'PER', 20, 22],
#  [5491, 'PER', 29, 31],
#  [5402, 'PER', 13, 15],
#  [5483, 'PER', 33, 35],
#  [5401, 'PER', 28, 30],
#  [5481, 'PER', 40, 42],
#  [6137, 'PER', 15, 19],
#  [5733, 'PER', 15, 17],
#  [5726, 'PER', 204, 206],
#  [5738, 'PER', 15, 17],
#  [5727, 'PER', 12, 14],
#  [5739, 'PER', 21, 23],
#  [5728, 'PER', 0, 2],
#  [5729, 'PER', 0, 2],
#  [5736, 'PER', 2, 4],
#  [5737, 'PER', 0, 2],
#  [5725, 'PER', 0, 2],
#  [5735, 'PER', 0, 2],
#  [5731, 'PER', 0, 2],
#  [5734, 'PER', 2, 4],
#  [5732, 'PER', 2, 4],
#  [5730, 'PER', 0, 2],
#  [5727, 'PER', 88, 90],
#  [5740, 'PER', 3, 5],
#  [5724, 'PER', 115, 117],
#  [5723, 'PER', 29, 31],
#  [5722, 'PER', 27, 29],
#  [5721, 'PER', 15, 17],
#  [5719, 'PER', 74, 76],
#  [5720, 'PER', 46, 48],
#  [6765, 'PER', 47, 52],
#  [7068, 'PER', 88, 90],
#  [6051, 'PER', 29, 31],
#  [6045, 'PER', 0, 2],
#  [6046, 'PER', 0, 2],
#  [6047, 'PER', 0, 2],
#  [6048, 'PER', 0, 2],
#  [7710, 'PER', 62, 64],
#  [6049, 'PER', 0, 2],
#  [6050, 'PER', 28, 30],
#  [4906, 'PER', 242, 244],
#  [6123, 'PER', 9, 13],
#  [7948, 'PER', 29, 33],
#  [6120, 'PER', 21, 25],
#  [6106, 'PER', 7, 10],
#  [5251, 'PER', 54, 57],
#  [6111, 'PER', 30, 33],
#  [6110, 'PER', 1, 4],
#  [6115, 'PER', 16, 19],
#  [6122, 'PER', 8, 11],
#  [6113, 'PER', 16, 19],
#  [6119, 'PER', 5, 8],
#  [6107, 'PER', 3, 6],
#  [6116, 'PER', 1, 4],
#  [5707, 'PER', 84, 86],
#  [8572, 'PER', 718, 721],
#  [7710, 'PER', 87, 89],
#  [7426, 'PER', 7, 9],
#  [7427, 'PER', 6, 8],
#  [7428, 'PER', 0, 2],
#  [7276, 'PER', 7, 9],
#  [7430, 'PER', 21, 23],
#  [7431, 'PER', 13, 15],
#  [7432, 'PER', 6, 8],
#  [7433, 'PER', 6, 8],
#  [7229, 'PER', 44, 46],
#  [7434, 'PER', 0, 2],
#  [7435, 'PER', 0, 2],
#  [7429, 'PER', 18, 20],
#  [7164, 'PER', 0, 2],
#  [7425, 'PER', 7, 9],
#  [7406, 'PER', 47, 49],
#  [7424, 'PER', 28, 30],
#  [5887, 'PER', 30, 33],
#  [7713, 'PER', 0, 2],
#  [6555, 'PER', 0, 2],
#  [7714, 'PER', 0, 2],
#  [7715, 'PER', 0, 2],
#  [6121, 'PER', 45, 47],
#  [8510, 'PER', 23, 25],
#  [8226, 'PER', 0, 2],
#  [6117, 'PER', 29, 32],
#  [6112, 'PER', 32, 35],
#  [6109, 'PER', 9, 11],
#  [6946, 'PER', 15, 17],
#  [2241, 'PER', 0, 3],
#  [2241, 'PER', 208, 211],
#  [4459, 'PER', 104, 107],
#  [2941, 'PER', 64, 67],
#  [2569, 'PER', 13, 16],
#  [2388, 'PER', 0, 2],
#  [3838, 'PER', 1, 2],
#  [8089, 'PER', 71, 73],
#  [751, 'PER', 28, 30],
#  [208, 'PER', 38, 40],
#  [4891, 'PER', 62, 66],
#  [138, 'PER', 2, 4],
#  [1728, 'PER', 27, 30],
#  [1728, 'PER', 151, 154],
#  [6608, 'PER', 42, 44],
#  [8570, 'PER', 537, 539],
#  [6444, 'PER', 788, 791],
#  [5610, 'PER', 35, 38],
#  [5067, 'PER', 60, 63],
#  [1851, 'PER', 319, 321],
#  [3400, 'PER', 301, 304],
#  [3590, 'PER', 26, 29],
#  [24, 'PER', 88, 91],
#  [289, 'PER', 28, 31],
#  [281, 'PER', 146, 150],
#  [1514, 'PER', 398, 401],
#  [5719, 'PER', 29, 31],
#  [8541, 'PER', 6, 8],
#  [5509, 'PER', 23, 27],
#  [7354, 'PER', 11, 15],
#  [6710, 'PER', 5, 8],
#  [6367, 'PER', 34, 37],
#  [6367, 'PER', 72, 75],
#  [7887, 'PER', 626, 629],
#  [6239, 'PER', 24, 28],
#  [7887, 'PER', 600, 603],
#  [5153, 'PER', 29, 32],
#  [7887, 'PER', 94, 98],
#  [7807, 'PER', 42, 46],
#  [7877, 'PER', 12, 16],
#  [7875, 'PER', 79, 83],
#  [6367, 'PER', 44, 48],
#  [7887, 'PER', 548, 552],
#  [5264, 'PER', 14, 18],
#  [7814, 'PER', 15, 18],
#  [7813, 'PER', 14, 17],
#  [7835, 'PER', 15, 18],
#  [7832, 'PER', 13, 16],
#  [7888, 'PER', 11, 14],
#  [7848, 'PER', 15, 18],
#  [7858, 'PER', 16, 19],
#  [6395, 'PER', 16, 19],
#  [7790, 'PER', 35, 38],
#  [7791, 'PER', 45, 48],
#  [7792, 'PER', 27, 30],
#  [6793, 'PER', 11, 15],
#  [6793, 'PER', 27, 31],
#  [6793, 'PER', 83, 87],
#  [4835, 'PER', 3098, 3099],
#  [5418, 'PER', 0, 2],
#  [7355, 'PER', 119, 123],
#  [6534, 'PER', 1, 4],
#  [7386, 'PER', 37, 39],
#  [7381, 'PER', 10, 12],
#  [8383, 'PER', 26, 28],
#  [5883, 'PER', 0, 2],
#  [6364, 'PER', 24, 26],
#  [7340, 'PER', 10, 14],
#  [7347, 'PER', 10, 14],
#  [8420, 'PER', 43, 47],
#  [5287, 'PER', 0, 2],
#  [5517, 'PER', 0, 2],
#  [5050, 'PER', 1, 3],
#  [5050, 'PER', 6, 8],
#  [5041, 'PER', 1, 4],
#  [8359, 'PER', 8, 12],
#  [7697, 'PER', 10, 12],
#  [5110, 'PER', 9, 11],
#  [6202, 'PER', 8, 11],
#  [7336, 'PER', 13, 18],
#  [7335, 'PER', 13, 16],
#  [6111, 'PER', 10, 14],
#  [8568, 'PER', 63, 66],
#  [5006, 'PER', 41, 44],
#  [8258, 'PER', 1, 4],
#  [5929, 'PER', 20, 23],
#  [5641, 'PER', 8, 11],
#  [7941, 'PER', 53, 56],
#  [7137, 'PER', 250, 253],
#  [7071, 'PER', 26, 29],
#  [7071, 'PER', 5, 8],
#  [7303, 'PER', 0, 3],
#  [7294, 'PER', 0, 3],
#  [7344, 'PER', 13, 16],
#  [7469, 'PER', 37, 40],
#  [5292, 'PER', 70, 73],
#  [7334, 'PER', 13, 16],
#  [6269, 'PER', 23, 26],
#  [8229, 'PER', 10, 13],
#  [6748, 'PER', 12, 15],
#  [7907, 'PER', 13, 16],
#  [4953, 'PER', 34, 38],
#  [6191, 'PER', 8, 12],
#  [2329, 'PER', 299, 300],
#  [2327, 'PER', 2301, 2302],
#  [2325, 'PER', 253, 254],
#  [2330, 'PER', 448, 449],
#  [2310, 'PER', 491, 493],
#  [5395, 'PER', 171, 174],
#  [5395, 'PER', 34, 37],
#  [6020, 'PER', 1, 6],
#  [6810, 'PER', 56, 59],
#  [533, 'PER', 6, 8],
#  [8381, 'PER', 11, 14],
#  [4628, 'PER', 15, 17],
#  [8067, 'PER', 82, 84],
#  [7573, 'PER', 0, 2],
#  [7572, 'PER', 0, 2],
#  [6582, 'PER', 1, 6],
#  [8533, 'PER', 5, 7],
#  [5772, 'PER', 33, 37],
#  [5127, 'PER', 109, 111],
#  [5687, 'PER', 6, 8],
#  [1046, 'PER', 57, 60],
#  [1062, 'PER', 13, 16],
#  [1061, 'PER', 5, 8],
#  [1063, 'PER', 0, 3],
#  [193, 'PER', 6, 8],
#  [507, 'PER', 34, 36],
#  [190, 'PER', 0, 2],
#  [192, 'PER', 6, 8],
#  [879, 'PER', 3, 5],
#  [182, 'PER', 17, 19],
#  [878, 'PER', 22, 24],
#  [2204, 'PER', 171, 173],
#  [2204, 'PER', 204, 206],
#  [2183, 'PER', 17, 21],
#  [189, 'PER', 13, 15],
#  [191, 'PER', 5, 7],
#  [1156, 'PER', 32, 35],
#  [214, 'PER', 49, 52],
#  [2127, 'PER', 7, 9],
#  [2128, 'PER', 693, 697],
#  [2127, 'PER', 697, 699],
#  [509, 'PER', 2, 4],
#  [2126, 'PER', 7, 9],
#  [511, 'PER', 28, 30],
#  [512, 'PER', 12, 14],
#  [2126, 'PER', 441, 443],
#  [2126, 'PER', 254, 257],
#  [3539, 'PER', 8, 9],
#  [6512, 'PER', 37, 41],
#  [6514, 'PER', 40, 44],
#  [351, 'PER', 109, 112],
#  [7468, 'PER', 26, 30],
#  [1244, 'PER', 0, 1],
#  [835, 'PER', 13, 15],
#  [543, 'PER', 15, 19],
#  [1571, 'PER', 14, 18],
#  [7286, 'PER', 12, 14],
#  [5521, 'PER', 6, 8],
#  [5286, 'PER', 4, 6],
#  [5341, 'PER', 106, 110],
#  [5339, 'PER', 87, 91],
#  [1292, 'PER', 0, 2],
#  [403, 'PER', 0, 4],
#  [1077, 'PER', 9, 11],
#  [1079, 'PER', 28, 30],
#  [1072, 'PER', 76, 78],
#  [1080, 'PER', 0, 2],
#  [1072, 'PER', 63, 65],
#  [1076, 'PER', 6, 8],
#  [1071, 'PER', 0, 2],
#  [5639, 'PER', 15, 17],
#  [1291, 'PER', 3, 5],
#  [514, 'PER', 5, 9],
#  [444, 'PER', 2, 5],
#  [1282, 'PER', 0, 3],
#  [416, 'PER', 20, 23],
#  [813, 'PER', 13, 16],
#  [2128, 'PER', 681, 684],
#  [2129, 'PER', 870, 873],
#  [1073, 'PER', 2, 4],
#  [421, 'PER', 18, 19],
#  [2349, 'PER', 139, 141],
#  [2186, 'PER', 1584, 1587],
#  [2185, 'PER', 783, 786],
#  [2349, 'PER', 21, 24],
#  [2351, 'PER', 12, 14],
#  [3138, 'PER', 14, 16],
#  [3070, 'PER', 24, 27],
#  [2989, 'PER', 0, 2],
#  [7529, 'PER', 1, 4],
#  [13, 'PER', 32, 33],
#  [807, 'PER', 6, 7],
#  [1374, 'PER', 12, 13],
#  [1241, 'PER', 9, 10],
#  [1189, 'PER', 3, 4],
#  [142, 'PER', 14, 15],
#  [8452, 'PER', 105, 106],
#  [2199, 'PER', 83, 84],
#  [8080, 'PER', 76, 79],
#  [8087, 'PER', 12, 15],
#  [2330, 'PER', 86, 88],
#  [1920, 'PER', 361, 363],
#  [4950, 'PER', 104, 106],
#  [4950, 'PER', 73, 77],
#  [820, 'PER', 6, 8],
#  [7053, 'PER', 1, 6],
#  [7044, 'PER', 1, 6],
#  [6440, 'PER', 58, 62],
#  [6810, 'PER', 98, 100],
#  [6009, 'PER', 11, 15],
#  [6128, 'PER', 7, 10],
#  [1500, 'PER', 240, 242],
#  [3914, 'PER', 6, 8],
#  [3913, 'PER', 202, 204],
#  [3910, 'PER', 59, 61],
#  [3913, 'PER', 140, 142],
#  [3918, 'PER', 17, 19],
#  [3907, 'PER', 203, 205],
#  [1494, 'PER', 0, 2],
#  [1493, 'PER', 25, 27],
#  [3913, 'PER', 173, 175],
#  [3923, 'PER', 116, 118],
#  [1372, 'PER', 228, 230],
#  [1468, 'PER', 209, 211],
#  [1375, 'PER', 1, 3],
#  [771, 'PER', 17, 19],
#  [1740, 'PER', 1952, 1954],
#  [1470, 'PER', 130, 132],
#  [1499, 'PER', 102, 104],
#  [1376, 'PER', 0, 2],
#  [1500, 'PER', 594, 596],
#  [7906, 'PER', 94, 96],
#  [8570, 'PER', 295, 297],
#  [6155, 'PER', 25, 27],
#  [506, 'PER', 135, 137],
#  [7136, 'PER', 5, 7],
#  [5840, 'PER', 0, 2],
#  [7645, 'PER', 8, 10],
#  [1798, 'PER', 21, 23],
#  [7998, 'PER', 1, 5],
#  [8560, 'PER', 76, 78],
#  [8421, 'PER', 877, 879],
#  [2155, 'PER', 4, 6],
#  [494, 'PER', 10, 12],
#  [491, 'PER', 12, 14],
#  [1573, 'PER', 0, 2],
#  [490, 'PER', 19, 21],
#  [862, 'PER', 8, 10],
#  [55, 'PER', 2987, 2990],
#  [3907, 'PER', 192, 195],
#  [1083, 'PER', 9, 12],
#  [647, 'PER', 12, 15],
#  [159, 'PER', 26, 30],
#  [434, 'PER', 10, 14],
#  [5524, 'PER', 7, 9],
#  [7325, 'PER', 47, 50],
#  [7137, 'PER', 53, 55],
#  [1867, 'PER', 902, 905],
#  [560, 'PER', 0, 2],
#  [5751, 'PER', 56, 60],
#  [1644, 'PER', 18, 20],
#  [559, 'PER', 19, 21],
#  [2322, 'PER', 368, 371],
#  [2322, 'PER', 472, 475],
#  [8570, 'PER', 393, 395],
#  [7083, 'PER', 34, 36],
#  [4972, 'PER', 12, 14],
#  [4930, 'PER', 1067, 1069],
#  [6493, 'PER', 7, 10],
#  [4942, 'PER', 26, 29],
#  [7308, 'PER', 21, 24],
#  [5809, 'PER', 1, 4],
#  [6422, 'PER', 15, 19],
#  [7483, 'PER', 0, 2],
#  [2274, 'PER', 79, 82],
#  [65, 'PER', 0, 2],
#  [3386, 'PER', 16, 18],
#  [64, 'PER', 0, 2],
#  [65, 'PER', 11, 13],
#  [6272, 'PER', 4, 6],
#  [5166, 'PER', 51, 54],
#  [4739, 'PER', 67, 69],
#  [4739, 'PER', 59, 61],
#  [2998, 'PER', 10, 14],
#  [713, 'PER', 9, 11],
#  [742, 'PER', 19, 21],
#  [742, 'PER', 8, 10],
#  [1610, 'PER', 23, 25],
#  [622, 'PER', 31, 33],
#  [6411, 'PER', 86, 88],
#  [8481, 'PER', 0, 3],
#  [7380, 'PER', 24, 26],
#  [7373, 'PER', 10, 13],
#  [7379, 'PER', 9, 12],
#  [696, 'PER', 4, 6],
#  [1555, 'PER', 0, 2],
#  ...]

# %%
for doc, context in docs:
    for line in people2:
        if line[0] == context['id']:
            a = spacy.tokens.Span(doc, line[2],line[3],label = line[1])
            doc.ents = list(doc.ents) + [a]

# %%
docs[0][0].ents
# Out:
# (martin de gaynça,
#  santa iglesia,
#  Sevilla,
#  juan sanchez de caliz,
#  sevilla,
#  rodrigo de cordova,
#  gibraltar,
#  luis de toro,
#  gibraltar,
#  san francisco,
#  monasterio de san francisco,
#  cueva de san cristoval,
#  Gibraltar)

# %%
displacy.render(docs[0][0],style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">...
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     martin de gaynça
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  maestro mayor de las obras de canteria de la
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     santa iglesia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  de
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Sevilla
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  y
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     juan sanchez de caliz
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  maestro mayor de las obras (roto) desta dicha ciudad de
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     sevilla
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# ... otorgamos... que damos todo nuestro poder... a
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     rodrigo de cordova
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  vecino de la ciudad de
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     gibraltar
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# ... para... que por nos... pueda fazer qualquier yguala e convenencia... con
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     luis de toro
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  en nombre de su majestad para fazer un muro de abajo que se a de fazer en la ciudad de
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     gibraltar
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  desde
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     san francisco
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  fasta encima del cuchillo de una sierra que a de ser el dicho muro de grueso de nueve pies desde el dicho
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     monasterio de san francisco
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  fasta la
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     cueva de san cristoval
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  e desde la dicha cueva... fasta el cuchillo de la sierra a de ser de cuatro pies de grueso... e otrosi nos pueda obligar que faremos otras qualesquier obras de canteria e manposteria que fueren menester de se faser en la dicha ciudad de
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Gibraltar
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# </div></span>

# %% [markdown]
# And that's how it's done! Let's export both our people dataframe and our updated pickled docs to work with later. We have to remember to keep the pickled docs on the Gitignore.

# %%
people.to_csv("Files_Cleaning2/PER_tags_clean2_manual22.csv")

# %%
pickle.dump(docs, open( "NER_data_Cleaned22.p", "wb" ))
