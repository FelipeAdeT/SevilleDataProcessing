# %% [markdown]
# # Data Cleaning 2: Correcting Token Spans
#
# In this notebook, we go over "person" tags and clean spans to make sure they reference full names, no more and no less.
#
# We will recover the tags as cleaned in Data Cleaning 1, focusing on those we maintained as 'Remove'= 0.
#
#
#
# # Goal 1: To revise spans that are **too broad**
#
# Create a list of tokens that appear in entities but do not appear in the name lists. We can do this by getting the difference between the name set and the entity tokens set. Mark the tokens that might be considered potentially problematic. Find them and determine if they should be a part of the span. Edit the spans respectively.
#
# We can also add Kinkead's capitalized tokens to the "acceptable" token set.
#
# # Goal 2: To revise spans that are **too short**
#
# Search for tokens to the left and right of a tagged person that appear in the entity list and the name lists and have not been tagged as entities. We can import the spacy docs, each token should have an entity tag = 0.
#
# # Goal 3: Untagged PER entities
#
# Search for strings that match exactly with strings that have been tagged as entities. This should work to pick up untagged people.
#
# ---
# # Goal 1
#
# ## 1 Creating a list of tokens that appear in our entities

# %%
import pandas as pd
people = pd.read_csv('Files_Cleaning1/PER_tags_clean1.csv')

# %%
people.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  Unnamed: 0.1.1.1  \
# 0           0             0               0             57935
# 1           1             1               1             45285
# 2           2             2               2             45173
# 3           3             3               3             45108
# 4           4             4               4             61780
#
#    Unnamed: 0.1.1.1.1  docid          string label  start  end Remove
# 0               57935   6792             NaN   NaN    135  138      1
# 1               45285   4978     - Rodriguez   PER      6    8      0
# 2               45173   4961  -- Gomez Brito   PER     34   38      0
# 3               45108   4952     -- Manrique   PER     11   13      0
# 4               61780   7342      -- Ramirez   PER     29   31      0

# %%
grouped = people.groupby('Remove')
grouped.count()
# Out:
#         Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  Unnamed: 0.1.1.1  \
# Remove
# 0            32442         32442           32442             32442
# 1              561           561             561               561
# D                6             6               6                 6
# L               39            39              39                39
# M                6             6               6                 6
# O               66            66              66                66
#
#         Unnamed: 0.1.1.1.1  docid  string  label  start    end
# Remove
# 0                    32442  32442   32442  32442  32442  32442
# 1                      561    561     558      0    561    561
# D                        6      6       6      6      6      6
# L                       39     39      39     39     39     39
# M                        6      6       6      6      6      6
# O                       66     66      66     66     66     66

# %% [markdown]
# Let's generate a list of tokens that appear in our PER entities. To do this, we are flattening the list of lists that is generated when we split each string by spaces, and we create a set to remove duplicates. Then we store it as a list again.

# %%
tokenlist= people.loc[people['Remove']=='0','string'].str.split().tolist()

# %%
newlist= []
for sublist in tokenlist:
    if type(sublist)==list:
        for item in sublist:
            newlist.append(str(item))
tokenlist=list(set(newlist))

# %%
tokenlist.sort()

# %%
len(tokenlist)
# Out:
# 6692

# %% [markdown]
# Note that this list includes tokens in upper and lowercase. This is because these cases are informative. As Kinkead marked artist names in full uppercase, we can mark uppercase tokens as tokens for true names.

# %%
with open('PersonNameTokenList.csv','w') as file:
    for item in tokenlist:
        file.write(item + "\n")

# %%
print(tokenlist)
# Out:
# ['-', '--', '--de', '--nino', '-basco', '-gaspar', '-geronimo', '-luisa', '-ndo', '-vasco', '2-', '20', '481', 'a', 'abaasquita', 'abaco', 'abadesa', 'abadessa', 'abadia', 'abaeu', 'abalos', 'abaxo', 'abdina', 'abedaria', 'abeis', 'abel', 'abellan', 'abellano', 'abendaria', 'abendaño', 'abila', 'abiles', 'abita', 'abley', 'ablo', 'abraham', 'abrego', 'abreu', 'abril', 'abrue', 'abueda', 'acacio', 'academia', 'acauna', 'acebedo', 'acedo', 'acencio', 'acencion', 'acenfio', 'acensio', 'acer', 'acerdian', 'acero', 'acevedo', 'acha', 'acharte', 'acinto', 'acipres', 'acisclos', 'acle', 'acofta', 'acolina', 'acosser', 'acosta', 'acuna', 'acuña', 'adalid', 'adallo', 'adam', 'adame', 'adan', 'adornio', 'adriaen', 'adrian', 'aduana', 'afan', 'afanador', 'afandor', 'afedo', 'afencio', 'afenfio', 'afeto', 'agais', 'agilon', 'agora', 'agramonte', 'agua', 'aguayo', 'aguero', 'aguftin', 'aguiar', 'aguiere', 'aguila', 'aguilar', 'aguilera', 'aguilla', 'aguillar', 'aguire', 'aguirre', 'aguitar', 'agustin', 'agustina', 'agustino', 'ahumada', 'aia', 'aiala', 'aillon', 'ajuste', 'al', 'ala', 'alamo', 'alanis', 'alaras', 'alaraz', 'alarcon', 'alarcon\x97simon', 'alariz', 'alaua', 'alava', 'alavarre', 'alba', 'albadan', 'albadesa', 'albarada', 'albarado', 'albardo', 'albardon', 'albares', 'albarete', 'albarez', 'albaro', 'albarran', 'alber', 'albero', 'alberro', 'albert', 'alberta', 'alberto', 'albin', 'albino', 'albites', 'albor', 'albornos', 'albornoz', 'albuquerque', 'alca', 'alcala', 'alcaldes', 'alcanse', 'alcantara', 'alcanteies', 'alcantud', 'alcaras', 'alcaraz', 'alcaudete', 'alcayde', 'alcazar', 'alcaçar', 'alcedo', 'alcega\x97franco', 'alcina', 'alcocer', 'alcoger', 'alcor', 'alcosser', 'aldana', 'aldape', 'alderete', 'aldonza', 'aldrete', 'aldrette', 'aleantara', 'alecio', 'alegro', 'alejandro', 'alejo', 'alejos', 'aleman', 'aleola', 'alexandro', 'alexo', 'alexos', 'alfaro', 'alfe', 'alferes', 'alferez', 'alfian', 'alfonsa', 'alfonso', 'algarin', 'algualzil', 'alguazil', 'algun', 'alhondiga', 'ali', 'aliaga', 'alicante', 'aliman', 'alina', 'alja', 'allarran', 'allendano', 'alles', 'allo', 'alma', 'almansa', 'almanssa', 'almanza', 'almança', 'almao', 'almario', 'almas', 'almayda', 'almaçan', 'almeda', 'almedo', 'almeida', 'almeyda', 'almonacid', 'almonacir', 'almonarir', 'almonasir', 'almoneria', 'almonte', 'alo', 'alonffo', 'alonfo', 'alonsa', 'alonso', 'alonsso', 'alonzo', 'alonço', 'alphonsa', 'alrecon', 'alsedo', 'alsega', 'alsicolla', 'alsola', 'alta', 'altamirrano', 'altar', 'altares', 'altas', 'alteri', 'altopica', 'alua', 'aluares', 'aluarez', 'aluaro', 'alunbre', 'alva', 'alvan', 'alvar', 'alvarado', 'alvares', 'alvarez', 'alvareze', 'alvaro', 'alvarran', 'alvira', 'alyne', 'alº', 'amao', 'amaral', 'amaro', 'amarrosta', 'amarrostao', 'amaya', 'amayo', 'ambar', 'amberes', 'ambrofio', 'ambrosio', 'ambrosyo', 'amezqueta', 'amides', 'amor', 'ana', 'anales', 'anamaria', 'anaya', 'anbachts', 'anbos', 'anbrosio', 'andana', 'andino', 'andion', 'andrach', 'andrada', 'andrade', 'andrea', 'andres', 'andujar', 'anduxar', 'anefino', 'anenas', 'angel', 'angela', 'angeles', 'angelino', 'angelo', 'anguas', 'angulo', 'anhular', 'anion', 'anitua', 'anjeles', 'anrriquez', 'anselmo', 'antegana', 'antequera', 'anteçana', 'antolina', 'antolinez', 'anton', 'antonia', 'antonio', 'antono', 'antonyo', 'antto', 'antunes', 'antunez', 'anudo', 'anuncibay', 'anxela', 'anziano', 'aobecios', 'apans', 'aparcio', 'aparicio', 'aparysio', 'aponte', 'apostol', 'apostoles', 'aqua', 'aquelman', 'aquino', 'ara', 'aragon', 'aragones', 'aramburo', 'aramos', 'arana', 'aranburo', 'aranburu', 'aranda', 'arandia', 'aranguibel', 'arangurede', 'araqui', 'araqume', 'araujo', 'araus', 'arauz', 'araz', 'arazola', 'arbas', 'arbizti', 'arbuscody', 'arcadio', 'arcarate', 'arce', 'arcediano', 'arcegani', 'arche', 'arcos', 'arebalo', 'areguas', 'arellano', 'aremo', 'arenales', 'arenas', 'areno', 'arensecallatrada', 'arespe', 'aresti', 'arestui', 'areualo', 'arevalo', 'arfediano', 'arf ...

# %% [markdown]
# Let's turn this into a dataframe with a column that includes a column for "accepted" tokens, where 1 is a name token and 0 is a dubious token. Let's go ahead and assign a 1 value to those tokens that are in uppercase.

# %%
tokens = pd.DataFrame(tokenlist, columns = ['token'])
tokens.loc[tokens['token'].str.isupper(),'is_name']=1

# %%
tokens.groupby('is_name').count()
# Out:
#          token
# is_name
# 1.0        572

# %%
uppers = tokens.loc[tokens['is_name']==1,'token'].tolist()

# %%
uppers
# Out:
# ['A',
#  'ADRIAN',
#  'AFANDOR',
#  'AGUILA',
#  'AGUILAR',
#  'AGUSTIN',
#  'AIALA',
#  'ALA',
#  'ALARCON',
#  'ALAVA',
#  'ALBERTO',
#  'ALCANTEIES',
#  'ALCANTUD',
#  'ALDRETTE',
#  'ALFONSO',
#  'ALMANSA',
#  'ALMANZA',
#  'ALONSO',
#  'ALTA',
#  'ALTERI',
#  'ALVA',
#  'ALVAREZ',
#  'AMARROSTA',
#  'AMARROSTAO',
#  'AMBAR',
#  'AMBROSIO',
#  'ANDRACH',
#  'ANDRES',
#  'ANGELO',
#  'ANTOLINEZ',
#  'ANTONIO',
#  'APARICIO',
#  'ARAGON',
#  'ARANA',
#  'ARANDA',
#  'ARAUS',
#  'ARAZ',
#  'ARCE',
#  'ARCOS',
#  'ARENAS',
#  'ARENSECALLATRADA',
#  'ARIAS',
#  'ARIENZACALATRAVA',
#  'ARMEDIA',
#  'ARRENAS',
#  'ARROYO',
#  'ARTEAGA',
#  'ARTEAGAALFARO',
#  'ARTENSE',
#  'ARTENSECALATADO',
#  'ARTENSECALATRADA',
#  'ARTIAGA',
#  'ARTIGA',
#  'ARUAS',
#  'ARZE',
#  'ASCENCIO',
#  'ASENCIO',
#  'ASINTA',
#  'ATIENZA',
#  'ATIENZACALATRAVA',
#  'AVILA',
#  'AY',
#  'AYALA',
#  'B',
#  'BAL',
#  'BALDEQUIROS',
#  'BALDES',
#  'BALDEZ',
#  'BALLESTEROS',
#  'BALTASAR',
#  'BALTAZAR',
#  'BALTHAZAR',
#  'BAN',
#  'BANMOL',
#  'BARAHONA',
#  'BARAONA',
#  'BARCO',
#  'BARELA',
#  'BARONA',
#  'BARREDA',
#  'BARRERA',
#  'BARTOLOME',
#  'BASQUEZ',
#  'BAUTISTA',
#  'BAZQUEZ',
#  'BEJARANO',
#  'BENJUMEA',
#  'BENJUMEDA',
#  'BERDUGO',
#  'BERGUGO',
#  'BERLANGA',
#  'BERNABE',
#  'BERNAL',
#  'BERNARDINO',
#  'BERNARDO',
#  'BERNAVE',
#  'BILLAVICENCIO',
#  'BLAS',
#  'BOBADILLA',
#  'BOMOL',
#  'BORJA',
#  'BOTELLOS',
#  'BOVADILLA',
#  'BRABO',
#  'BRAVO',
#  'BRAÑA',
#  'CABALLERO',
#  'CABEZA',
#  'CABEZAS',
#  'CALATRAVA',
#  'CALDERON',
#  'CALLE',
#  'CALVETE',
#  'CALVO',
#  'CAMACHO',
#  'CAMARA',
#  'CAMPO',
#  'CAMPOBRIN',
#  'CAMPOLARGO',
#  'CAMPOS',
#  'CAMPROBIN',
#  'CAMPROVIN',
#  'CANCINO',
#  'CANSINO',
#  'CARABAJAL',
#  'CARASCO',
#  'CARBAJAL',
#  'CARDENAS',
#  'CARDOSO',
#  'CARLOS',
#  'CARMANA',
#  'CARO',
#  'CARPIO',
#  'CARRASCO',
#  'CARREÑOMIRANDA',
#  'CARRILLO',
#  'CARVAJAL',
#  'CASALES',
#  'CASARES',
#  'CASAS',
#  'CASTILLO',
#  'CASTRILLO',
#  'CASTRO',
#  'CAZALES',
#  'CESAR',
#  'CESLAR',
#  'CHAMARRO',
#  'CHAMORRO',
#  'CHICO',
#  'CHRISTO',
#  'CHRISTOBAL',
#  'CIPRIANO',
#  'CLEMENTE',
#  'COBOS',
#  'COCA',
#  'COLERA',
#  'COLLANTES',
#  'CONCA',
#  'CONELIO',
#  'CONTERAS',
#  'CONTRERAS',
#  'CORDERO',
#  'CORDOBA',
#  'CORNEIL',
#  'CORNELIO',
#  'CORRALES',
#  'CORREA',
#  'COSME',
#  'COUTO',
#  'CRESPO',
#  'CRISTO',
#  'CRISTOBAL',
#  'CRONELIO',
#  'CRUZ',
#  'D',
#  'DAVILA',
#  'DE',
#  'DEL',
#  'DELAGADO',
#  'DELGADO',
#  'DIAS',
#  'DIAZ',
#  'DIEGO',
#  'DIONISIO',
#  'DOMINGO',
#  'DOMINGUEZ',
#  'DURAN',
#  'ENRIQUE',
#  'ENRIQUEZ',
#  'ERNANDEZ',
#  'ERRERA',
#  'ESCALONA',
#  'ESCHUT',
#  'ESCHUTT',
#  'ESCOBAR',
#  'ESCUT',
#  'ESPINOSA',
#  'ESQUIVEL',
#  'ESTEBAN',
#  'ESTRADA',
#  'F',
#  'FABON',
#  'FAC',
#  'FADRIQUE',
#  'FAIX',
#  'FAJARDO',
#  'FALCONJORDAN',
#  'FALON',
#  'FAMOL',
#  'FAMON',
#  'FAS',
#  'FAX',
#  'FAZ',
#  'FEILPE',
#  'FELIPE',
#  'FERAN',
#  'FERNANDES',
#  'FERNANDEZ',
#  'FERNANDEZTORRES',
#  'FERNANDO',
#  'FERRADO',
#  'FIGUEROA',
#  'FIGUEROATRILLO',
#  'FLAMOL',
#  'FLAMON',
#  'FLORES',
#  'FONSECA',
#  'FRANCISCO',
#  'FRANCO',
#  'FRANCOLEON',
#  'FRUTOS',
#  'FUENTE',
#  'GABALDON',
#  'GABRIEL',
#  'GALAS',
#  'GALLARDO',
#  'GARAY',
#  'GARCIA',
#  'GARZIA',
#  'GARZON',
#  'GASPAR',
#  'GERMAN',
#  'GERONIMO',
#  'GERRA',
#  'GIJON',
#  'GODOYCARVAJAL',
#  'GOMEZ',
#  'GONZALEZ',
#  'GRADILLA',
#  'GREGORIO',
#  'GUADIX',
#  'GUARIN',
#  'GUERRA',
#  'GUIRAL',
#  'GUTIERRES',
#  'GUTIERREZ',
#  'GUZMAN',
#  'H',
#  'HAMON',
#  'HAS',
#  'HASINTE',
#  'HENRIQUEZ',
#  'HEREDIA',
#  'HEREDIANARBAES',
#  'HERESUELO',
#  'HEREZUELO',
#  'HERNANDEZ',
#  'HERNANDO',
#  'HERRERA',
#  'HERRERAAGUILAR',
#  'HIDALGO',
#  'HIERRO',
#  'HIGUERA',
#  'HIPOLITO',
#  'HONORIO',
#  'HOYA',
#  'IGNACIO',
#  'INENASIUS',
#  'INTE',
#  'IPOLITO',
#  'IRIARTE',
#  'ISIDRO',
#  'IV',
#  'IYNASIO',
#  'IÑIGO',
#  'J',
#  'JACINTO',
#  'JACOB',
#  'JACOBS',
#  'JAN',
#  'JARAMILLO',
#  'JERONIMO',
#  'JIMENEZ',
#  'JOAN',
#  'JORDAN',
#  'JOSE',
#  'JOSEPH',
#  'JOSEPHE',
#  'JOSPEH',
#  'JOSPEHE',
#  'JOYA',
#  'JUAN',
#  'JUANES',
#  'JUARES',
#  'JUAREZ',
#  'JUHAN',
#  'JULIAN',
#  'L',
#  'LA',
#  'LARA',
#  'LAS',
#  'LAUREANO',
#  'LAZARO',
#  'LAZO',
#  'LE',
#  'LEAL',
#  'LEANDRO',
#  'LEJALDE',
#  'LEON',
#  'LEONARDO',
#  'LEONSALCEDO',
#  'LLANOBALDES',
#  'LLANOS',
#  'LLANOSBALDES',
#  'LLANOSVALDES',
#  'LLANOVALDES',
#  'LLORENTE',
#  'LOPEZ',
#  'LORENZO',
#  'LORNEZO',
#  'LOS',
#  'LUCAS',
#  'LUCIAN',
#  'LUCIANO',
#  'LUIS',
#  'LUNA',
#  'LUSON',
#  'LUZON',
#  'M',
#  'MACHADO',
#  'MACIAS',
#  'MALABER',
#  'MALGAREJO',
#  'MALLAVER',
#  'MANUEL',
#  'MARCOS',
#  'MARIN',
#  'MARQUEZ',
#  'MARTIE',
#  'MARTIN',
#  'MARTINEZ',
#  'MARTINEZDIMAS',
#  'MASIAS',
#  'MATAMOROS',
#  'MATEIOS',
#  'MATEO',
#  'MATEOS',
#  'MATIAS',
#  'MEDINA',
#  'MEDINABALBUENA',
#  'MEDINAVALBUENA',
#  'MEJIA',
#  'MEJIAS',
#  'MELGAREJO',
#  'MENA',
#  'MENDOZA',
#  'MENESES',
#  'MENESESOSORIO',
#  'MERINO',
#  'MESA',
#  'MESACRUZ',
#  'MIGUEL',
#  'MILLAN',
#  'MOL',
#  'MOLDES',
#  'MOLINA',
#  'MOMPIAN',
#  'MOMPIANBECERRA',
#  'MONSADA',
#  'MONTALVAN',
#  'MONTANO',
#  'MONTAÑES',
#  'MONTERO',
#  'MONTILLA',
#  'MONTILLAVERA',
#  'MONTOYA',
#  'MORALES',
#  'MORANTE',
#  'MORENO',
#  'MORGADO',
#  'MORILLO',
#  'MORO',
#  'MOYNA',
#  'MOYNE',
#  'MURILLO',
#  'MUÑOZ',
#  'N',
#  'NARAVETE',
#  'NARDI',
#  'NARVAEZ',
#  'NARVAL',
#  'NAVARETTE',
#  'NAVARRETE',
#  'NAVARRO',
#  'NEGRON',
#  'NEIRA',
#  'NEYRA',
#  'NICOLAS',
#  'NIETA',
#  'NIETO',
#  'NIETOCASTELLANOS',
#  'NISA',
#  'NUÑEZ',
#  'OCA',
#  'ONORIO',
#  'OROZCO',
#  'ORTEGA',
#  'OSORIO',
#  'P',
#  'PABLO',
#  'PACHECO',
#  'PALENCIA',
#  'PAREDES',
#  'PAREDESSALGADO',
#  'PARILLA',
#  'PARRA',
#  'PARRILLA',
#  'PASSANO',
#  'PAZ',
#  'PEDRO',
#  'PERDO',
#  'PEREA',
#  'PEREZ',
#  'PINA',
#  'PINEDA',
#  'PISARO',
#  'PISARRO',
#  'PIZARRO',
#  'POLANCO',
#  'PRADILLO',
#  'PRIETO',
#  'QUIROS',
#  'R',
#  'RAMIREZ',
#  'RAMOS',
#  'REVES',
#  'REYES',
#  'RIBAS',
#  'RIBASSANDOVAL',
#  'RIBERA',
#  'RIES',
#  'RIOS',
#  'RIOSALCANTUD',
#  'RIS',
#  'RIVAS',
#  'ROBLEDO',
#  'RODRIGUEZ',
#  'RODRIQUEZ',
#  'ROJAS',
#  'ROJASVELASCO',
#  'ROLDAN',
#  'ROMERO',
#  'ROPA',
#  'ROSA',
#  'RUIZ',
#  'S',
#  'SALAZAR',
#  'SALCEDO',
#  'SALCEDOBENJUMEA',
#  'SALINAS',
#  'SALMERON',
#  'SALOSSO',
#  'SALVADOR',
#  'SAMORA',
#  'SAMORATORO',
#  'SANCHEZ',
#  'SANTIAGO',
#  'SANTOS',
#  'SARACOSA',
#  'SARANIEGO',
#  'SARATE',
#  'SARSOSA',
#  'SARSOSSA',
#  'SARZOSA',
#  'SCHUITT',
#  'SCHUT',
#  'SCHUTT',
#  'SCUT',
#  'SCUTT',
#  'SEBASTIAN',
#  'SEGOVIA',
#  'SEGURA',
#  'SEVASTIAN',
#  'SHUTT',
#  'SILVA',
#  'SIMON',
#  'SM',
#  'SOLORSANO',
#  'SOLORZANO',
#  'SORIANO',
#  'SOTO',
#  'SUAREZ',
#  'SUERO',
#  'TAMARIS',
#  'TAMARIZ',
#  'TASSON',
#  'TEJADA',
#  'TEJEDA',
#  'TEJON',
#  'TELLO',
#  'TERAN',
#  'TERRON',
#  'TERRONES',
#  'THOMAS',
#  'TIRADO',
#  'TOBAR',
#  'TOMAS',
#  'TONTERA',
#  'TORIBIO',
#  'TORIJIO',
#  'TORO',
#  'TORRE',
#  'TORRES',
#  'TREVINO',
#  'TRUJILLO',
#  'TYRADO',
#  'V',
#  'VAL',
#  'VALBUENA',
#  'VALDES',
#  'VALDIVIESO',
#  'VALENCIA',
#  'VALLE',
#  'VALLEJO',
#  'VAN',
#  'VANMOL',
#  'VAZQUEZ',
#  'VEGA',
#  'VELA',
#  'VELASCO',
#  'VELAZQUEZ',
#  'VERA',
#  'VERDUGO',
#  'VESTIR',
#  'VEXARANO',
#  'VIENA',
#  'VIGUERA',
#  'VILLAVICENCIO',
#  'VISTAL',
#  'VLDES',
#  'VME',
#  'VOBADILLA',
#  'XIII',
#  'XIMENEZ',
#  'XIV',
#  'XXIIII',
#  'YGNACIO',
#  'YLLARTE',
#  'YNASIUS',
#  'YRIARTE',
#  'YSIDRO',
#  'ZAENS',
#  'ZAMORA',
#  'ZAMORATORO',
#  'ZARATE',
#  'ZARAZOSA',
#  'ZARCOSA',
#  'ZARZOSA',
#  'ZESAR',
#  'ZURBARAN',
#  'ZURIETA',
#  'ÇURBARAN']

# %% [markdown]
# This has identified 572 tokens as acceptable. We can also mark their lowercase equivalents as acceptable.

# %%
tokens.loc[tokens['token'].str.upper().isin(uppers),'is_name']=1

# %%
tokens.groupby('is_name').count()
# Out:
#          token
# is_name
# 1.0       1253

# %% [markdown]
# This has identified 1,253 tokens as acceptable.

# %%
strat1 = tokens.loc[tokens['is_name']==1,'token']

strat1.to_csv("Files_Cleaning2/acceptednametokens2_strat1.csv")

# %% [markdown]
# A look at the .CSV file reveals that the list seems OK. We allow it to include articles (la, lo, el, los) because at this stage we don't think they should be problematic.

# %% [markdown]
# # 2 Creating a list of tokens not in our combined namelists
#
# Other acceptable names may not be in the list of Kinkead tokens. We can rely on tokens from our first and last name lists to be name tokens. (Or, put in other words, we will have reason to suspect tokens not in this list not to be names).

# %%
fnames = open('DBE_Names/firstnames.txt')
lnames = open('DBE_Names/lastnames.txt')

# %%
names = []

for line in fnames:
    names.append(line.rstrip('\n'))
    
for line in lnames:
    names.append(line.rstrip('\n'))

# %%
names = set(names)

# %%
names
# Out:
# {'moraza',
#  'monte',
#  'pichardo',
#  'simeon',
#  'guarinos',
#  'virtus',
#  'mejias',
#  'gertrudis',
#  'filiberto',
#  'letamendi',
#  'aguera',
#  'parcero',
#  'calduch',
#  'echave',
#  'sierra',
#  'bolero',
#  'nurnberger',
#  'lalana',
#  'quintano',
#  'piedras',
#  'castellon',
#  'mortela',
#  'nienguiri',
#  'capo',
#  'eleuterio',
#  'ballinas',
#  'acha',
#  'icoaga',
#  'iturri',
#  'salt',
#  'linaje',
#  'cusi',
#  'insaurralde',
#  'encinas',
#  'labrador',
#  'peral',
#  'bergaigne',
#  'descatllar',
#  'rozas',
#  'jasso',
#  'folguera',
#  'cristofini',
#  'corta',
#  'gausy',
#  'urquinaona',
#  'labart',
#  'carriedo',
#  'urioste',
#  'bernabe',
#  'vallgornera',
#  'welzer',
#  'turell',
#  'grassot',
#  'rosari',
#  'santiago',
#  'leyes',
#  'zabalo',
#  'molinillo',
#  'hermosino',
#  'reding',
#  'fraso',
#  'sanctis',
#  'boltas',
#  'dauventon',
#  'ungo',
#  'nariño',
#  'reinegg',
#  'cochet',
#  'yeregui',
#  'valenti',
#  'hondal',
#  'muxica',
#  'cannizaro',
#  'bru',
#  'benet',
#  'azcune',
#  'oncins',
#  'sarrion',
#  'borsoto',
#  'segade',
#  'haro',
#  'bernuz',
#  'escalona',
#  'fondevila',
#  'langot',
#  'landaluce',
#  'ferrandis',
#  'belluga',
#  'lafita',
#  'osullivan',
#  'malo',
#  'ezequiel',
#  'rabasa',
#  'marqueli',
#  'naygeon',
#  'talayero',
#  'ariz',
#  'madux',
#  'chimalpahin',
#  'velluti',
#  'olarte',
#  'cardellach',
#  'solorzano',
#  'nyssen',
#  'flon',
#  'valera',
#  'sagardia',
#  'travieso',
#  'valtierra',
#  'queralt',
#  'baez',
#  'lepe',
#  'junipero',
#  'remolins',
#  'rebollar',
#  'estuardo',
#  'abd',
#  'lagunas',
#  'moraga',
#  'fitz-gerald',
#  'mazarrasa',
#  'viescas',
#  'ribalta',
#  'balda',
#  'cajiga',
#  'querejazu',
#  'mingo',
#  'noguerol',
#  'catalina',
#  'leguizamo',
#  'abadiano',
#  'bonifaç',
#  'fresno',
#  'aguerre',
#  'rizi',
#  'scidiac',
#  'rocella',
#  'caimo',
#  'oleguer',
#  'maza',
#  'dowling',
#  'quindos',
#  'bela',
#  'vegas',
#  'guiot',
#  'villagra',
#  'rivacoba',
#  'salgado',
#  'casale',
#  'aldama',
#  'arnedo',
#  'valoi',
#  'jorquera',
#  'guiral',
#  'ulman',
#  'paciotto',
#  'laloo',
#  'monjardin',
#  'cistue',
#  'nuceda',
#  'zamalvide',
#  'olawlor',
#  'bermudez',
#  'moreiro',
#  'xama',
#  'conway',
#  'faille',
#  'rotllan',
#  'villasanta',
#  'cabaspre',
#  'reluz',
#  'casiri',
#  'jaen',
#  'ormaza',
#  'perler',
#  'meireles',
#  'agueros',
#  'ovalle',
#  'brea',
#  'villaguisada',
#  'baltazar',
#  'carlos',
#  'amelia',
#  'descartin',
#  'pemartin',
#  'soba',
#  'leal',
#  'arbolanche',
#  'viñas',
#  'santacruz',
#  'pereira',
#  'hermosillo',
#  'arache',
#  'terrazas',
#  'albarracin',
#  'cabanilles',
#  'moci',
#  'gomar',
#  'murillas',
#  'trasierra',
#  'vallo',
#  'merlo',
#  'fontanals',
#  'böhl',
#  'luyando',
#  'alvaro',
#  'pescador',
#  'obregoso',
#  'vosmediana',
#  'yoseph',
#  'faneca',
#  'wittelsbach',
#  'lanas',
#  'aperger',
#  'alfinger',
#  'murua',
#  'reolid',
#  'necolalde',
#  'aldas',
#  'holbeque',
#  'chabot',
#  'ulacia',
#  'bertendona',
#  'kelly',
#  'mainoldi',
#  'avalos',
#  'gordillo',
#  'chirinos',
#  'chacon-manrique',
#  'grillo',
#  'focher',
#  'torcuato',
#  'acorbe',
#  'poago',
#  'rosado',
#  'gavarrer',
#  'compaseur',
#  'vango',
#  'canela',
#  'oconry',
#  'sinforoso',
#  'fabian',
#  'boroa',
#  'fancelli',
#  'canals',
#  'panigo',
#  'anges',
#  'mielgo',
#  'albergotti',
#  'joaquin',
#  'nero',
#  'amuedo',
#  'santisteban',
#  'mariana',
#  'arguero',
#  'restan',
#  'ximen-perez',
#  'ubiña',
#  'enriquez',
#  'hacho',
#  'alix',
#  'perruca',
#  'rui',
#  'sarriet',
#  'aperregui',
#  'montilla',
#  'ausias',
#  'borelli',
#  'cladera',
#  'garayo',
#  'cramer',
#  'argaiz',
#  'collado',
#  'oliveri',
#  'capoche',
#  'oca',
#  'tiburzio',
#  'cruella',
#  'botti',
#  'ramales',
#  'vedel',
#  'chabacier',
#  'urquijo',
#  'gayoso',
#  'estenaga',
#  'rosenbach',
#  'chindurza',
#  'marmolejo',
#  'haurie',
#  'peregrinus',
#  'aviles',
#  'castellot',
#  'morras',
#  'tostado',
#  'lira',
#  'johann',
#  'vicent',
#  'vizcayno',
#  'gaudioso',
#  'canovas',
#  'pelliza',
#  'eugenia',
#  'cevallos',
#  'levi',
#  'oyague',
#  'monrava',
#  'azofra',
#  'almodovar',
#  'valverde',
#  'poechos',
#  'uztariz',
#  'cenedo',
#  'german',
#  'browne',
#  'corio',
#  'proaza',
#  'baus',
#  'canesi',
#  'estrees',
#  'basabilbaso',
#  'tenza',
#  'velasquez',
#  'eulalio',
#  'capacete',
#  'cornide',
#  'gregori',
#  'galdames',
#  'portal',
#  'embun',
#  'ranc',
#  'fray',
#  'moredo',
#  'carrizosa',
#  'piedrahita',
#  'valbuena',
#  'muddin',
#  'beldad',
#  'aymamon',
#  'torron',
#  'caupolica',
#  'justiz',
#  'camaron',
#  'duran',
#  'cabeza',
#  'subira',
#  'arigon',
#  'villagutierre',
#  'bernalte',
#  'humaran',
#  'morelos',
#  'orleans',
#  'ronza',
#  'antunez',
#  'llopiz',
#  'garci-gonzalez',
#  'capilla',
#  'lera',
#  'altamir',
#  'marsilio',
#  'paton',
#  'saureulx',
#  'vilardefrancos',
#  'angele',
#  'demetrio',
#  'belart',
#  'frederich',
#  'mola',
#  'montejo',
#  'ayarzagoitia',
#  'valladoli',
#  'balobesso',
#  'quirio',
#  'josefa',
#  'rendom',
#  'forment',
#  'goya',
#  'agnesio',
#  'bathe',
#  'garos',
#  'sobrarias',
#  'rondeau',
#  'faria',
#  'vicario',
#  'romero',
#  'ubon',
#  'escatron',
#  'manalt',
#  'avalle',
#  'narvaez',
#  'cristian',
#  'spinelli',
#  'rene',
#  'monterroso',
#  'escaregui',
#  'jorgeta',
#  'boisa',
#  'sopeña',
#  'estada',
#  'portichuelo',
#  'melon',
#  'rovida',
#  'berberana',
#  'gimbernat',
#  'eguzquiza',
#  'keating',
#  'azurara',
#  'scarlatti',
#  'hontiveros',
#  'lue',
#  'chalon',
#  'cabanellas',
#  'yolif',
#  'guibas',
#  'lizarazu',
#  'sagui',
#  'peregrinis',
#  'villagomez',
#  'reinaldi',
#  'areas',
#  'filiano',
#  'echaburu',
#  'fierlant',
#  'wendlingen',
#  'tejada',
#  'degollada',
#  'mut',
#  'harduin',
#  'iniesta',
#  'cervello',
#  'meya',
#  'malpartida',
#  'lasarte',
#  'farreras',
#  'samso',
#  'olzina',
#  'bernardin',
#  'villagran',
#  'cibila',
#  'raurell',
#  'capecelatro',
#  'isidro',
#  'henin',
#  'marquet',
#  'villafuerte',
#  'mutiloa',
#  'casasola',
#  'vitorero',
#  'salvo',
#  'cullen',
#  'anciola',
#  'imberto',
#  'valor',
#  'regla',
#  'guyraver',
#  'trasmiera',
#  'arza',
#  'mirabent',
#  'robles',
#  'grimaldi',
#  'sibert',
#  'felipina',
#  'fulgencio',
#  'barcala',
#  'camacho',
#  'figaro',
#  'orrantia',
#  'teodosio',
#  'digueri',
#  'magnin',
#  'cayacoa',
#  'liques',
#  'riezu',
#  'petisco',
#  'ejea',
#  'azcue',
#  'abel',
#  'apoita',
#  'albert-octave',
#  'gavilan',
#  'benavente',
#  'viscomte',
#  'sobrino',
#  'rocco',
#  'tovar',
#  'urria',
#  'cancer',
#  'alcedo',
#  'ribero',
#  'casadevall',
#  'pilar',
#  'ahuitzot',
#  'merlino',
#  'canyet',
#  'usategui',
#  'bañares',
#  'saldivar',
#  'trayllon',
#  'navarro-mas',
#  'yamqui',
#  'puebla',
#  'cantera',
#  'gaztelu',
#  'aguayo',
#  'angela',
#  'uberte',
#  'darcourt',
#  'frayse',
#  'guimat',
#  'martierena',
#  'sansano',
#  'gotardo',
#  'latras',
#  'meñaca',
#  'masgoret',
#  'umu',
#  'constanza',
#  'perpintiey',
#  'encina',
#  'cordon',
#  'zapardiel',
#  'acacio',
#  'arcaya',
#  'partal',
#  'aylmer',
#  'bilbao',
#  'fernandez-bazan',
#  'resendio',
#  'sebastia',
#  'nueva',
#  'valderas',
#  'sales',
#  'cornel',
#  'nuñez',
#  'serafino',
#  'villalba',
#  'santotis',
#  'wadding',
#  'pio',
#  'chinchon',
#  'caserta',
#  'domezain',
#  'torrezar',
#  'combe',
#  'march',
#  'uranzu',
#  'barreda',
#  'alberoni',
#  'lastur',
#  'lobaton',
#  'peñafiel',
#  'puigbonet',
#  'grifo',
#  'ezenarro',
#  'do',
#  'comenares',
#  'campeny',
#  'villasanti',
#  'daban',
#  'vallesa',
#  'basilea',
#  'martiarena',
#  'varea',
#  'pero',
#  'rohan-chabot',
#  'parente',
#  'laisequilla',
#  'troya',
#  'faltos',
#  'villalobos',
#  'lorenzo',
#  'torrellas',
#  'menan',
#  'villaurrutia',
#  'aldonza',
#  'ubilla',
#  'cienfuegos',
#  'mainader',
#  'silverio',
#  'ahumada',
#  'gudelo',
#  'vuelta',
#  'astola',
#  'seneor',
#  'salvany',
#  'albret',
#  'male',
#  'hoyo',
#  'gausi',
#  'lezana',
#  'fausto',
#  'ledesma',
#  'maino',
#  'bruselas',
#  'concha',
#  'ufano',
#  'rossell',
#  'berri',
#  'oleo',
#  'centani',
#  'vilanova',
#  'alal',
#  'esperanza',
#  'asfeld',
#  'vicentelo',
#  'zalvidea',
#  'alborxe',
#  'lanz',
#  'borroto',
#  'coma',
#  'locquet',
#  'linaza',
#  'alberdi',
#  'ducrue',
#  'belloni',
#  'casanova',
#  'roger',
#  'wallpa',
#  'plandolit-targarona',
#  'cocolina',
#  'doris',
#  'barrie',
#  'moguer',
#  'bartolome',
#  'medinilla',
#  'tizon',
#  'andrevi',
#  'polanco',
#  'vergara',
#  'urries',
#  'luis',
#  'mirueña',
#  'cruzat',
#  'epifanio',
#  'rivafrecha',
#  'cayaco',
#  'oms-sentmenat',
#  'clementis',
#  'serapio',
#  'ballesteros',
#  'abul',
#  'gallifa',
#  'sacristan',
#  'ravenet',
#  'valdemoros',
#  'morel',
#  'villaragut',
#  'pazo',
#  'leyte',
#  'oben',
#  'bona',
#  'beytia',
#  'ayerbe',
#  'pachacuti',
#  'baroccio',
#  'garcia-herreros',
#  'terrers',
#  'james',
#  'casas',
#  'muruzabal',
#  'paolo',
#  'aspee',
#  'guardiola',
#  'rocacrespa',
#  'cecilia',
#  'zsigmond',
#  'arrate',
#  'olmo',
#  'abollado',
#  'gallque',
#  'vinuesa',
#  'gasso',
#  'ferreras',
#  'vehena',
#  'celestino',
#  'segunda',
#  'vernacci',
#  'tineo',
#  'urriola',
#  'orrego',
#  'simão',
#  'ibrahim',
#  'buil',
#  'franques',
#  'cantelmo',
#  'melia',
#  'nieves',
#  'peredo',
#  'germa',
#  'bouay',
#  'raxa',
#  'osborne',
#  'seniz',
#  'sarabia',
#  'baranda',
#  'bonavia',
#  'bassols',
#  'argandoña',
#  'cadaval',
#  'guejar',
#  'lezaun',
#  'pechman',
#  'figuera',
#  'dalmau',
#  'anhetan',
#  'martinillo',
#  'mota',
#  'piran',
#  'rojo',
#  'tenesor',
#  'lamoral',
#  'piñon',
#  'llorente',
#  'ayalde',
#  'cota',
#  'espiritu',
#  'bonvalot',
#  'fierro',
#  'barrasa',
#  'arbaizar',
#  'pinheiro',
#  'portella',
#  'haimbhausen',
#  'requesens',
#  'roco',
#  'camposaprani',
#  'gayangos',
#  'churriguera',
#  'martos',
#  'sacosta',
#  'lapuerta',
#  'pieres',
#  'asunsolo',
#  'rifflart',
#  'cabarcas',
#  'lesmes',
#  'hermosilla',
#  'caviedes',
#  'basset',
#  'tuced',
#  'hortigas',
#  'echamorro',
#  'passano',
#  'rivilla',
#  'rissi',
#  'tour',
#  'amich',
#  'añoa',
#  'combes',
#  'lliveria',
#  'ossorio',
#  'sureda',
#  'arenillas',
#  'navascues',
#  'artes',
#  'arizabalo',
#  'balbi',
#  'pingarron',
#  'celis',
#  'dombey',
#  'pierres',
#  'franch',
#  'campero',
#  'navacerrada',
#  'sarraoa',
#  'hennebuise',
#  'feloaga',
#  'guitart',
#  'miravete',
#  'quitano',
#  'valentini',
#  'guevara',
#  'navales',
#  'colcu',
#  'hermida',
#  'marino',
#  'basalenque',
#  'sampso',
#  'clavigero',
#  'canesmas',
#  'rabay',
#  'pacs',
#  'bonells',
#  'magenise',
#  'aizpurua',
#  'marin',
#  'lafora',
#  'sese',
#  'comportaeta',
#  'andueza',
#  'desmaissieres',
#  'valdelomar',
#  'amancio',
#  'arago',
#  'marroquin',
#  'ruy',
#  'gallen',
#  'villamayor',
#  'dorda',
#  'salelles',
#  'rodriguez-arango',
#  'malon',
#  'sotomayor',
#  'pedrol',
#  'carranza',
#  'armasa',
#  'quer',
#  'klein',
#  'polinillo',
#  'barnuevo',
#  'silves',
#  'rafel',
#  'fonsdeviela',
#  'alvaredo',
#  'perot',
#  'limon',
#  'fraga',
#  'mainar',
#  'piñol',
#  'blanes',
#  'segundo',
#  'minuissir',
#  'dupuy',
#  'yoly',
#  'jabat',
#  'escarpenter',
#  'palma',
#  'faez',
#  'sahun',
#  'escaño',
#  'maticorena',
#  'domper',
#  'tellado',
#  'utset',
#  'guarionex',
#  'rosalia',
#  'enyeg',
#  'uribarri',
#  'huici',
#  'ginoves',
#  'konsag',
#  'ocio',
#  'maroja',
#  'amiguet',
#  'muhammad',
#  'crespo]',
#  'tur',
#  'gracia',
#  'arauza',
#  'montealegre',
#  'rosillo',
#  'tollis',
#  'azara',
#  'riba',
#  'vanvitelli',
#  'evangelista',
#  'guillorme',
#  'rioja',
#  'sumaya',
#  'bolea',
#  'lucena',
#  'valderrabano',
#  'oreja',
#  'rotxotxo',
#  'egea',
#  'llull',
#  'amezquita',
#  'gasca',
#  'aichelberg',
#  'calatrava',
#  'donoso',
#  'sampere',
#  'alberico',
#  'bleda',
#  'surga',
#  'mendaña',
#  'luisa',
#  'sallent',
#  'abadia',
#  'fonzi',
#  'foncq',
#  'garraza',
#  'zoilo',
#  'literes',
#  'jean-armand',
#  'oro',
#  'silvela',
#  'olona',
#  'marichalar',
#  'alemanni',
#  'querini',
#  'almanzor',
#  'grillet',
#  'caballero',
#  'tremoille',
#  'siloe',
#  'ucedo',
#  'hannart',
#  'carballo',
#  'asensi',
#  'ottin',
#  'delrio',
#  'cavalleria',
#  'urquizu',
#  'zamorategui',
#  'morros',
#  'corro',
#  'sangronis',
#  'faussat',
#  'herbias',
#  'espadero',
#  'ypanqui',
#  'gasque',
#  'siria',
#  'parada',
#  'barre',
#  'ricardos',
#  'angulo',
#  'esteban',
#  'cidoncha',
#  'loriga',
#  'giusseppangelo',
#  'beyria',
#  'rusca',
#  'villes',
#  'benito',
#  'barradas',
#  'colicheuqu',
#  'dios',
#  'sardinha',
#  'cirilo',
#  'salba',
#  'collazo',
#  'landa',
#  'gastaldo',
#  'rison',
#  'cattaneo',
#  'gallar',
#  'vecquer',
#  'lizundia',
#  'victorio',
#  'garriga',
#  'carasa',
#  'monteseguro',
#  'navia-osorio',
#  'almazan',
#  'golfin',
#  'monzabal',
#  'osona',
#  'mayone',
#  'donlebun',
#  'azeredo',
#  'mier',
#  'ducete',
#  'asensio',
#  'cascallana',
#  'yehuda',
#  'gartia',
#  'guruceta',
#  'taranco',
#  'ferrandiz',
#  'urdinso',
#  'rubian',
#  'gorbalan',
#  'taroncher',
#  'badillos',
#  'colinas',
#  'valvidares',
#  'monegro',
#  'pancorbo',
#  'medeiros',
#  'oramas',
#  'ochoa',
#  'rocaberti',
#  'borica',
#  'manescau',
#  'justiniano',
#  'llorac',
#  'carvallido',
#  'sedano',
#  'borgoñon',
#  'valdeyzcarai',
#  'brancaccio',
#  'isabella',
#  'cascante',
#  'cob',
#  'esclapez',
#  'battista',
#  'revillo',
#  'laurgain',
#  'amate',
#  'leon',
#  'samuel',
#  'calabria',
#  'sanjuanena',
#  'enjuta',
#  'amaru',
#  'castrillo',
#  'gafiero',
#  'senra',
#  'chome',
#  ...}

# %%
len(names)
# Out:
# 10005

# %% [markdown]
# Above, we have created one set of unique names from both our first names and last names file, no overlap. Note that these are all lowercase.
#
# Next, let's find the difference between this list and our tokens found above.

# %%
tokens.loc[tokens['token'].str.lower().isin(names),'is_name']=1

# %%
tokens.groupby('is_name').count()
# Out:
#          token
# is_name
# 1.0       3171

# %%
len(tokens)
# Out:
# 6692

# %% [markdown]
# So far, we have managed to mark 3,171 tokens as reliable names from a list of 6,692. 3,521 remain unaccounted for.

# %%
dubioustokens = tokens.loc[tokens['is_name']!=1,'token'].to_list()

# %%
print(dubioustokens)
# Out:
# ['-', '--', '--Nino', '--de', '-basco', '-gaspar', '-geronimo', '-luisa', '-ndo', '-vasco', '2-', '20', '481', 'Abaasquita', 'Abaco', 'Abadesa', 'Abaeu', 'Abalos', 'Abdina', 'Abedaria', 'Abendaria', 'Abrego', 'Abril', 'Abrue', 'Abueda', 'Academia', 'Acauna', 'Acencion', 'Acenfio', 'Acensio', 'Acerdian', 'Acisclos', 'Acle', 'Acolina', 'Acosser', 'Acuna', 'Adallo', 'Afanador', 'Agilon', 'Agua', 'Aguiere', 'Aguillar', 'Aguire', 'Agustino', 'Aillon', 'Alaras', 'Alarcon\x97Simon', 'Alariz', 'Alavarre', 'Albarada', 'Albarado', 'Albardo', 'Albardon', 'Albares', 'Albarez', 'Albaro', 'Albarran', 'Alber', 'Albero', 'Alberta', 'Alca', 'Alcala', 'Alcega\x97Franco', 'Alcina', 'Alcor', 'Alcosser', 'Aldape', 'Aleantara', 'Alegro', 'Aleola', 'Alexandro', 'Alfian', 'Alfonsa', 'Alhondiga', 'Alicante', 'Alina', 'Alja', 'Allendano', 'Alma', 'Almança', 'Almao', 'Almario', 'Almas', 'Almedo', 'Almonacir', 'Almonarir', 'Almoneria', 'Almonte', 'Alo', 'Alonfo', 'Alonsa', 'Alonsso', 'Alphonsa', 'Alrecon', 'Alsega', 'Alsicolla', 'Alsola', 'Altamirrano', 'Altar', 'Altas', 'Altopica', 'Alua', 'Alvan', 'AlvarezE', 'Alvira', 'Alyne', 'Alº', 'Amao', 'Amaro', 'Amayo', 'Amides', 'Anales', 'Anamaria', 'Anbachts', 'Andana', 'Andion', 'Anduxar', 'Anenas', 'Anhular', 'Anion', 'Anteçana', 'Antto', 'Antunes', 'Anudo', 'Anxela', 'Anziano', 'Apans', 'Aparcio', 'Aqua', 'Aquelman', 'Ara', 'Aramburo', 'Aramos', 'Arangurede', 'Araqume', 'Arazola', 'Arbuscody', 'Arcadio', 'Arcediano', 'Arcegani', 'Arebalo', 'Areguas', 'Aremo', 'Areno', 'Arespe', 'Arestui', 'Arfian', 'Argadona', 'Argames', 'Argia', 'Arguela', 'Arguelo', 'Argunedo', 'Aria', 'Arieta', 'Ariola', 'Arispe', 'Arjuez', 'Arma', 'Armejo', 'Armente', 'Armido', 'Aro', 'Arranegui', 'Arriaga\x97Luis', 'Arrias', 'Arriba', 'Artemio', 'Artifice', 'Arzobispo', 'Arzovispo', 'Ascarate', 'Ascarza', 'Ast', 'Atanacio', 'Ataraque', 'Aubri', 'Audalla', 'Augustina', 'Auila', 'Aunon', 'Auto', 'Autografo', 'Autografo\x97', 'Autos', 'Avete', 'Aviendose', 'Aycona', 'Aygo', 'Ayllan', 'Ayssa', 'Azalidallo', 'Azenedo', 'Ba', 'Babia', 'Bacarrel', 'Bacca', 'Badaraco', 'Badillo', 'Baeça', 'Baias', 'Bajo', 'Balcarses', 'Balder--', 'Balduc', 'Balencian', 'Balera', 'Baleros', 'Balfacon', 'Baliente', 'Balladare', 'Balladares', 'Ballejo', 'Balles', 'Balon', 'Baltanel', 'Balthasar', 'Banbelle', 'Banco', 'Banfraet', 'Banuelos', 'Bao', 'Barbaran', 'Barcansel', 'Bardia', 'Barera', 'Barete', 'Barietos', 'Baron', 'Barragan', 'Barrao', 'Barrete', 'Barro', 'Bartholome', 'Barue', 'Basconcelos', 'Basileo', 'Baslientos', 'Bastan', 'Bastardo', 'Bastas', 'Bastilleros', 'Bastos', 'Batatano', 'Batellos', 'Bauchel', 'Bauptista', 'Bautismo', 'Beana', 'Beatris', 'Beces', 'Bega', 'Begadi', 'Begaro', 'Bejines', 'Belares', 'Belarte', 'Belero', 'Bellarte', 'Belloso', 'Beltanel', 'Beltrano', 'Belzere', 'Bemal', 'Benaberte', 'Benefdo', 'Beneficiado', 'Beneficiados', 'Benega', 'Benites', 'Benitos', 'Benuenucto', 'Benuenuto', 'Benvenuto', 'Bera', 'Berdiel', 'Berdo', 'Beretente', 'Bergara', 'Beri', 'Bermondo', 'Bermudes', 'Bermundo', 'Bernaldino', 'Bernando', 'Bernuda', 'Berobia', 'Berrospe', 'Beruenquel', 'Besere', 'Bet', 'Betancor', 'Betis', 'Bezerra', 'Bias', 'Bicente', 'Bien', 'Biere', 'Bilches', 'Bilchez', 'Billapor', 'Billegas', 'Biller', 'Biquera', 'Birues', 'Biscarra', 'Bitaben', 'Bitero', 'Blaceo', 'Blanquet', 'Blascoen', 'Blasina', 'Blasquez', 'Bme', 'Bobadillo', 'Bogueles', 'Bojorquez', 'Bolanos', 'Bolante', 'Boldoque', 'Bolsa', 'Bordoque', 'Borio', 'Bormes', 'Bormio', 'Borques', 'Borte', 'Bos', 'Bosello', 'Bovis', 'Bozomo', 'Bredembeque', 'Bricio', 'Brigida', 'Brizeño', 'Brunenque', 'Bruñete', 'Bta', 'Buenabentura', 'Buenrostro', 'Bulgo', 'Buraran', 'Burch', 'Bustamente', 'COUTOdieron', 'COUTsic', 'Caballo', 'Cabanos', 'Cabañuela', 'Cabera', 'Cabilles', 'Caftilla', 'Calaverde', 'Calblllo', 'Calbo', 'Calcada', 'Calco', 'Caloña', 'Calus', 'Calvente', 'Calvijo', 'Calzado', 'Calçada', 'Camargas', 'Camian', 'Camila', 'Campania', 'Campaña', 'Campoverde', 'Campoviejo', ...

# %% [markdown]
# How many tags do these dubious tokens affect? Let's calculate this below.

# %% [markdown]
# # Number of records with a token not from our name list

# %%
people.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  Unnamed: 0.1.1.1  \
# 0           0             0               0             57935
# 1           1             1               1             45285
# 2           2             2               2             45173
# 3           3             3               3             45108
# 4           4             4               4             61780
#
#    Unnamed: 0.1.1.1.1  docid          string label  start  end Remove
# 0               57935   6792             NaN   NaN    135  138      1
# 1               45285   4978     - Rodriguez   PER      6    8      0
# 2               45173   4961  -- Gomez Brito   PER     34   38      0
# 3               45108   4952     -- Manrique   PER     11   13      0
# 4               61780   7342      -- Ramirez   PER     29   31      0

# %%
def pattern_searcher(search_str:str, search_list:list):
    
    search_strlist = search_str.lower().split()
    
    check =  any(item in search_strlist for item in search_list)
    
    if check:
        return_str = 1
        
    else:
        return_str = 0
        
    return return_str

# %%
people['matched_str'] = people['string'].apply(lambda x: pattern_searcher(search_str=str(x), search_list=dubioustokens))

# %%
people[people['Remove']=='0'].groupby(['matched_str']).count()
# Out:
#              Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  Unnamed: 0.1.1.1  \
# matched_str
# 0                 23310         23310           23310             23310
# 1                  9132          9132            9132              9132
#
#              Unnamed: 0.1.1.1.1  docid  string  label  start    end  Remove
# matched_str
# 0                         23310  23310   23310  23310  23310  23310   23310
# 1                          9132   9132    9132   9132   9132   9132    9132

# %% [markdown]
# Within our tags that have not been flagged for removal, We have 9132 tags that have a potentially questionable token right now, and 23,310 that are OK.

# %%
len((set(people.loc[(people['Remove']=='0')&(people['matched_str']==1),'string'])))
# Out:
# 5511

# %% [markdown]
# Of these 9132 tags, 5511 are distinct strings.

# %%
len((set(people.loc[(people['Remove']=='0')&(people['matched_str']==0),'string'].to_list())))
# Out:
# 8498

# %% [markdown]
# Of the 23,310 correct tags, 8498 are distinct strings.

# %% [markdown]
# # 3 Fuzzy Matching
#
# Let's also use our results from fuzzy matching and mark any tokens that represent a less than 90% match 90% match with tokens in the lists as dubious.

# %%
fuzzymatches = pd.read_csv('Files_Cleaning1/token_match_scores.csv')

# %%
fuzzymatches.set_index('token', inplace= True)

# %%
fuzzymatches.head()
# Out:
#             Unnamed: 0  score    match
# token
# BENJUMEA             0     71   enjuta
# Prevendado           1     71  revenga
# Lateral              2     77   antera
# MORILLO              3    100  morillo
# Ramon                4    100    ramon

# %%
tokens90 = fuzzymatches[fuzzymatches['score']>=90].index.tolist()

# %%
len(tokens90)
# Out:
# 3717

# %%
print(tokens90)
# Out:
# ['MORILLO', 'Ramon', 'Ruela', 'morante', 'Coello', 'VELAZQUEZ', 'Cardenas', 'TIRADO', 'BORJA', 'quebedo', 'martos', 'Quevedo', 'Teresa', 'Juanes', 'Monero', 'arze', 'Biedma', 'Durango', 'barrionuebo', 'despindola', 'trujillo', 'Ruiz', 'baltasar', 'Tenorio', 'Villens', 'IRIARTE', 'Canto', 'villa', 'Astete', 'AGUSTIN', 'Ruano', 'Trelles', 'Enrique', 'rroelas', 'Grimon', 'Rosal', 'horosco', 'ATIENZA', 'Sala', 'cuesta', 'Espinosa', 'Eraso', 'CARASCO', 'ayllon', 'MENESES', 'Sotto', 'Cipriano', 'Ribadeneira', 'Dimas', 'barrassa', '-geronimo', 'ALONSO', 'Calatayud', 'Salafranca', 'Caro', 'Arnao', 'holgado', 'Pan', 'GOMEZ', 'Morellon', 'Llanes', 'porras', 'muñoz', 'Ruis', 'Mathia', 'GARCIA', 'TORRES', 'Deza', 'siguença', 'Vermondo', 'Solarte', 'Ruesta', 'caraballo', 'Almonacid', 'ALDRETTE', 'florencia', 'Nicolas', 'deza', 'rrojas', 'Hernandez', 'roela', 'carcel', 'Matias', 'pino', 'goncalo', 'maria', 'carrasco', 'Federigui', 'rroldan', 'Torado', 'marcho', 'cuevas', 'arpe', 'ARANA', 'Izaguire', 'franciisco', 'mata', 'bartome', 'Rubira', 'buenabentura', 'olano', 'añasco', 'colmenero', 'Anales', 'Simona', 'grillo', 'Ribas', 'Puerta', 'Cancino', 'ENRIQUE', 'montesinos', 'Carasquila', 'esteban', 'Schutt', 'Arieta', 'GREGORIO', 'Nieves', 'Beltran', 'Sotomayo', 'Carasquilla', 'laines', 'CARABAJAL', 'doñate', 'Consuegra', 'Cristina', 'malpartida', 'palacio', 'Cotan', 'villacastin', 'Valderrama', 'Cuesta', 'collantes', 'FAJARDO', 'Tovar', 'Angulo', 'Higueras', 'CARDOSO', 'CANCINO', 'bellon', 'Chico', 'peralta', 'orellana', 'ramos', 'apostoles', 'Ribadeniera', 'chacon', 'Cañizares', 'lorença', '-gaspar', 'corro', 'uRibaRi', 'atanasio', 'quintanilla', 'enRique', 'çuleta', 'Teran', 'HIDALGO', 'bernaldina', 'gaitan', 'vilchez', 'rrodrigo', 'Escuderos', 'Hermenegildo', 'noguera', 'Salguero', 'cantera', 'frano', 'Pinto', 'texeda', 'mañana', 'Iglesias', 'Agustina', 'Tacon', 'suero', 'PEREA', 'esparragosa', 'barahona', 'Marie', 'morga', 'Corral', 'Acisclos', 'carton', 'Niebla', 'Reyes', 'fernando', 'Thoribio', 'bronçe', 'Vasco', 'porra', 'Frano', 'Maeda', 'LUCIANO', 'MACHADO', 'CORNEIL', 'Bohorquez', 'aguiar', 'gongalo', 'Lazaro', 'Jordan', 'giraldo', 'martin', 'Lejalde', 'Cedillo', 'ponce', 'merida', 'Uriarte', 'carrizoça', 'manuel', 'Velazco', 'ocampos', 'Auila', 'Barrientos', 'Sabastiana', 'bautista', 'illescas', 'valdivieso', 'Jiles', 'Vandelvira', 'pablo', 'Crisostomo', 'Cortez', 'tobar', 'cifuentes', 'tavera', 'Valverde', 'ollero', 'Barba', 'hijar', 'arenas', 'Arespe', 'Susana', 'Mendes', 'josefe', 'jancinto', 'Acolina', 'trinidad', 'carvajal', 'Abellan', 'reynes', 'garay', 'Catalan', 'Chavez', 'Arrenas', 'BERNABE', 'VILLAVICENCIO', 'çarate', 'paula', 'gerardo', 'Moron', 'gutierrez', 'jorge', 'Troya', 'LAUREANO', 'adrian', 'riquelme', 'LORENZO', 'Guerrero', 'lA', 'enrique', 'Villapando', 'Cartagena', 'Bonifaz', 'BALTAZAR', 'Galindo', 'Vidal', 'Texeda', 'jesu', 'henrriquez', 'Aragones', 'Morillas', 'roldan', 'Vega', 'mondragon', 'Ignacia', 'SALMERON', 'sastre', 'Acha', 'subira', 'Morcillo', 'Soto', 'oro', 'Bernal', 'Barrios', 'Gregorio', 'Toscano', 'ospital', 'pedro', 'serpa', 'Perea', 'rramos', 'TRUJILLO', 'coçar', 'Manuel', 'coca', 'Miralles', 'Reina', 'madera', 'Riscos', 'Eusebio', 'rubiales', 'Philipe', 'fadrique', 'palencia', 'Gracia', 'Crispina', 'gallego', 'baleriano', 'Dezcurra', 'Tomas', 'toranço', 'Anton', 'Correa', 'Guillen', 'Montilla', 'carrera', 'Marito', 'obando', 'Ros', 'bohorques', 'duran', 'torres', 'Diez', 'baldra', 'Maria', 'Villafranca', 'Gamboa', 'Joan', 'Matieno', 'rivas', 'escamilla', 'Manrique', 'fuergo', 'Arteaga', 'Pessoa', 'Valdivieso', 'horozco', 'Abel', 'marquez', 'FERNANDES', 'ESCOBAR', 'Rodriguez', 'Tinoco', 'girolamo', 'pando', 'Benitez', 'riuera', 'Talavera', 'Bracho', 'Abraham', 'mayorga', 'Cobos', 'Castellana', 'Ubrien', 'mari', 'desquivel', 'Alejo', 'daza', 'santillana', 'Lorenzana', 'frayle', 'MATIAS', 'Lozano', 'Salzedo', 'Señoria', 'VELASCO', 'Niño', 'Tirando', 'Tornero', 'Sarabia', 'Navaro', 'gadea', 'Cast ...

# %% [markdown]
# Items that appear in this list should also be accepted as name tokens (is_name =1)

# %%
tokens.loc[tokens['token'].str.lower().isin(tokens90),'is_name']=1

# %%
tokens.groupby('is_name').count()
# Out:
#          token
# is_name
# 1.0       3610

# %%
len(tokens)
# Out:
# 6692

# %% [markdown]
# So far, we have managed to mark 3,610 tokens as reliable names from a list of 6,692. 3,082 remain unaccounted for.
#
# Making all lowercase, these are 2,862 unique strings.

# %%
dubioustokens = tokens.loc[tokens['is_name']!=1,'token'].str.lower().to_list()

# %%
len(set(dubioustokens))
# Out:
# 2862

# %%
print(dubioustokens)
# Out:
# ['-', '--', '--Nino', '--de', '-basco', '-gaspar', '-geronimo', '-luisa', '-ndo', '-vasco', '2-', '20', '481', 'Abaasquita', 'Abaco', 'Abadesa', 'Abaeu', 'Abalos', 'Abdina', 'Abedaria', 'Abendaria', 'Abrego', 'Abril', 'Abrue', 'Abueda', 'Academia', 'Acauna', 'Acencion', 'Acenfio', 'Acensio', 'Acerdian', 'Acisclos', 'Acle', 'Acolina', 'Acosser', 'Acuna', 'Adallo', 'Afanador', 'Agilon', 'Agua', 'Aguiere', 'Aguillar', 'Aguire', 'Agustino', 'Aillon', 'Alaras', 'Alarcon\x97Simon', 'Alariz', 'Alavarre', 'Albarada', 'Albarado', 'Albardo', 'Albardon', 'Albares', 'Albarez', 'Albaro', 'Albarran', 'Alber', 'Albero', 'Alberta', 'Alca', 'Alcala', 'Alcega\x97Franco', 'Alcina', 'Alcor', 'Alcosser', 'Aldape', 'Aleantara', 'Alegro', 'Aleola', 'Alexandro', 'Alfian', 'Alfonsa', 'Alhondiga', 'Alicante', 'Alina', 'Alja', 'Allendano', 'Alma', 'Almança', 'Almao', 'Almario', 'Almas', 'Almedo', 'Almonacir', 'Almonarir', 'Almoneria', 'Almonte', 'Alo', 'Alonfo', 'Alonsa', 'Alonsso', 'Alphonsa', 'Alrecon', 'Alsega', 'Alsicolla', 'Alsola', 'Altamirrano', 'Altar', 'Altas', 'Altopica', 'Alua', 'Alvan', 'AlvarezE', 'Alvira', 'Alyne', 'Alº', 'Amao', 'Amaro', 'Amayo', 'Amides', 'Anales', 'Anamaria', 'Anbachts', 'Andana', 'Andion', 'Anduxar', 'Anenas', 'Anhular', 'Anion', 'Anteçana', 'Antto', 'Antunes', 'Anudo', 'Anxela', 'Anziano', 'Apans', 'Aparcio', 'Aqua', 'Aquelman', 'Ara', 'Aramburo', 'Aramos', 'Arangurede', 'Araqume', 'Arazola', 'Arbuscody', 'Arcadio', 'Arcediano', 'Arcegani', 'Arebalo', 'Areguas', 'Aremo', 'Areno', 'Arespe', 'Arestui', 'Arfian', 'Argadona', 'Argames', 'Argia', 'Arguela', 'Arguelo', 'Argunedo', 'Aria', 'Arieta', 'Ariola', 'Arispe', 'Arjuez', 'Arma', 'Armejo', 'Armente', 'Armido', 'Aro', 'Arranegui', 'Arriaga\x97Luis', 'Arrias', 'Arriba', 'Artemio', 'Artifice', 'Arzobispo', 'Arzovispo', 'Ascarate', 'Ascarza', 'Ast', 'Atanacio', 'Ataraque', 'Aubri', 'Audalla', 'Augustina', 'Auila', 'Aunon', 'Auto', 'Autografo', 'Autografo\x97', 'Autos', 'Avete', 'Aviendose', 'Aycona', 'Aygo', 'Ayllan', 'Ayssa', 'Azalidallo', 'Azenedo', 'Ba', 'Babia', 'Bacarrel', 'Bacca', 'Badaraco', 'Badillo', 'Baeça', 'Baias', 'Bajo', 'Balcarses', 'Balder--', 'Balduc', 'Balencian', 'Balera', 'Baleros', 'Balfacon', 'Baliente', 'Balladare', 'Balladares', 'Ballejo', 'Balles', 'Balon', 'Baltanel', 'Balthasar', 'Banbelle', 'Banco', 'Banfraet', 'Banuelos', 'Bao', 'Barbaran', 'Barcansel', 'Bardia', 'Barera', 'Barete', 'Barietos', 'Baron', 'Barragan', 'Barrao', 'Barrete', 'Barro', 'Bartholome', 'Barue', 'Basconcelos', 'Basileo', 'Baslientos', 'Bastan', 'Bastardo', 'Bastas', 'Bastilleros', 'Bastos', 'Batatano', 'Batellos', 'Bauchel', 'Bauptista', 'Bautismo', 'Beana', 'Beatris', 'Beces', 'Bega', 'Begadi', 'Begaro', 'Bejines', 'Belares', 'Belarte', 'Belero', 'Bellarte', 'Belloso', 'Beltanel', 'Beltrano', 'Belzere', 'Bemal', 'Benaberte', 'Benefdo', 'Beneficiado', 'Beneficiados', 'Benega', 'Benites', 'Benitos', 'Benuenucto', 'Benuenuto', 'Benvenuto', 'Bera', 'Berdiel', 'Berdo', 'Beretente', 'Bergara', 'Beri', 'Bermondo', 'Bermudes', 'Bermundo', 'Bernaldino', 'Bernando', 'Bernuda', 'Berobia', 'Berrospe', 'Beruenquel', 'Besere', 'Bet', 'Betancor', 'Betis', 'Bezerra', 'Bias', 'Bicente', 'Bien', 'Biere', 'Bilches', 'Bilchez', 'Billapor', 'Billegas', 'Biller', 'Biquera', 'Birues', 'Biscarra', 'Bitaben', 'Bitero', 'Blaceo', 'Blanquet', 'Blascoen', 'Blasina', 'Blasquez', 'Bme', 'Bobadillo', 'Bogueles', 'Bojorquez', 'Bolanos', 'Bolante', 'Boldoque', 'Bolsa', 'Bordoque', 'Borio', 'Bormes', 'Bormio', 'Borques', 'Borte', 'Bos', 'Bosello', 'Bovis', 'Bozomo', 'Bredembeque', 'Bricio', 'Brigida', 'Brizeño', 'Brunenque', 'Bruñete', 'Bta', 'Buenabentura', 'Buenrostro', 'Bulgo', 'Buraran', 'Burch', 'Bustamente', 'COUTOdieron', 'COUTsic', 'Caballo', 'Cabanos', 'Cabañuela', 'Cabera', 'Cabilles', 'Caftilla', 'Calaverde', 'Calblllo', 'Calbo', 'Calcada', 'Calco', 'Caloña', 'Calus', 'Calvente', 'Calvijo', 'Calzado', 'Calçada', 'Camargas', 'Camian', 'Camila', 'Campania', 'Campaña', 'Campoverde', 'Campoviejo', ...

# %% [markdown]
# How many tags do these dubious tokens affect? Let's calculate this below.

# %% [markdown]
# # Number of records with a token not from our name list

# %%
people.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  Unnamed: 0.1.1.1  \
# 0           0             0               0             57935
# 1           1             1               1             45285
# 2           2             2               2             45173
# 3           3             3               3             45108
# 4           4             4               4             61780
#
#    Unnamed: 0.1.1.1.1  docid          string label  start  end Remove  \
# 0               57935   6792             NaN   NaN    135  138      1
# 1               45285   4978     - Rodriguez   PER      6    8      0
# 2               45173   4961  -- Gomez Brito   PER     34   38      0
# 3               45108   4952     -- Manrique   PER     11   13      0
# 4               61780   7342      -- Ramirez   PER     29   31      0
#
#    matched_str
# 0            0
# 1            1
# 2            1
# 3            1
# 4            1

# %%
people['matched_str'] = people['string'].apply(lambda x: pattern_searcher(search_str=str(x), search_list=dubioustokens))

# %%
people[people['Remove']=='0'].groupby(['matched_str']).count()
# Out:
#              Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  Unnamed: 0.1.1.1  \
# matched_str
# 0                 24717         24717           24717             24717
# 1                  7725          7725            7725              7725
#
#              Unnamed: 0.1.1.1.1  docid  string  label  start    end  Remove
# matched_str
# 0                         24717  24717   24717  24717  24717  24717   24717
# 1                          7725   7725    7725   7725   7725   7725    7725

# %% [markdown]
# Within our tags that have not been flagged for removal, We have 7,725 tags that have a potentially questionable token right now, and 24,717 that are OK.

# %%
len((set(people.loc[(people['Remove']=='0')&(people['matched_str']==1),'string'])))
# Out:
# 4720

# %% [markdown]
# Of these 7,725 tags, 4720 are distinct strings.

# %%
len((set(people.loc[(people['Remove']=='0')&(people['matched_str']==0),'string'].to_list())))
# Out:
# 9289

# %% [markdown]
# Of the 24,717 correct tags, 9289 are distinct strings.

# %% [markdown]
# We could potentially lower the barrier of fuzzy matching, to reduce these 4,720 tags further. But seeing that we only have 3,082 dubious tokens to go through, let's go through these manually and mark the ones we know to be tokens referring to names.
#
# First, let's save these dubious tokens to a file.

# %%
tokens.loc[tokens['is_name']!=1,'token'].to_csv('Files_Cleaning2/Dubioustokens_strat2.csv')

# %%
strat3 = tokens.loc[tokens['is_name']!=1,'token']
strat3.to_csv("Files_Cleaning2/dubiousnametokens2_strat3.csv")

# %% [markdown]
# ## 4 Manual Check of Dubious Tokens
#
# In the file above, we went ahead and marked any tokens that were inequivocally last names with is_name=1. We also marked tokens that were clearly erroneous as is_name=0. These included verbs and numbers. We removed titles and descriptors such as "escribanos" or "fiadores", except if these descriptors might form part of the name ("Arcediano de Niebla").

# %%
dubious_handchecked = pd.read_excel("Files_Cleaning2/dubiousnametokens23_manualcheck.xlsx")

# %%
dubious_handchecked.head()
# Out:
#   tokenlower  is_name
# 0          -      1.0
# 1         --      1.0
# 2     --nino      1.0
# 3       --de      1.0
# 4       -ndo      1.0

# %%
dubious_handchecked.set_index('tokenlower')
dubious_handchecked.head()
# Out:
#   tokenlower  is_name
# 0          -      1.0
# 1         --      1.0
# 2     --nino      1.0
# 3       --de      1.0
# 4       -ndo      1.0

# %% [markdown]
# We will take strings marked as 1 to be names, and strings marked as 0 or blank need to be edited.

# %%
dubiousfinal = dubious_handchecked.loc[dubious_handchecked['is_name']!=1,'tokenlower'].to_list()

# %%
len(dubiousfinal)
# Out:
# 1874

# %%
people['matched_str'] = people['string'].apply(lambda x: pattern_searcher(search_str=str(x), search_list=dubious_handchecked))

# %%
people[people['Remove']=='0'].groupby(['matched_str']).count()
# Out:
#              Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  Unnamed: 0.1.1.1  \
# matched_str
# 0                 32442         32442           32442             32442
#
#              Unnamed: 0.1.1.1.1  docid  string  label  start    end  Remove
# matched_str
# 0                         32442  32442   32442  32442  32442  32442   32442

# %% [markdown]
# # Strategy 2
#
# Check strings with "San, Santo, Santa, Santos, Santas" and other non-person tokens.

# %%
nontokens = ['San ','Santo ','Santa ','Santos ','Santas ']

for token in nontokens:
    people.loc[people['string'].str.contains(token),'Remove']= 'check'

# %%
people.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  docid       string label  start  end Remove
# 0       57935         57935   6792                PER    135  138
# 1       45285         45285   4978    Rodriguez   PER      6    8
# 2       45173         45173   4961  Gomez Brito   PER     34   38
# 3       45108         45108   4952     Manrique   PER     11   13
# 4       61780         61780   7342      Ramirez   PER     29   31

# %%
people.groupby('Remove').count()
# Out:
#         Unnamed: 0  Unnamed: 0.1  docid  string  label  start    end
# Remove
# 0             7076          7076   7076    7076   7076   7076   7076
#              25943         25943  25943   25943  25943  25943  25943
# check          101           101    101     101    101    101    101

# %%
people[people['Remove']=='check']
# Out:
#        Unnamed: 0  Unnamed: 0.1  docid                     string label  \
# 1585        47680         47680   5302      Andrea Santa Trinidad   PER
# 1911        44395         44395   4876          Andres San Martin   PER
# 2452        16350         16350   1783         Antonio Santa Cruz   PER
# 2453        16540         16540   1806         Antonio Santa Cruz   PER
# 2454        16597         16597   1814         Antonio Santa Cruz   PER
# ...           ...           ...    ...                        ...   ...
# 18449        2112          2112    265      Sebastian Santa Maria   PER
# 18635       45302         45302   4979           Señor San Andres   PER
# 18636       66747         66747   8050         Señor San Laureano   PER
# 18639       52425         52425   5990  Señorr San Esteban Martir   PER
# 18678       42239         42239   4558      Sor Maria San Agustin   PER
#
#        start  end Remove
# 1585      62   67  check
# 1911      46   50  check
# 2452      37   41  check
# 2453       0    4  check
# 2454       9   13  check
# ...      ...  ...    ...
# 18449     10   14  check
# 18635    243  246  check
# 18636    122  125  check
# 18639    103  107  check
# 18678     14   19  check
#
# [101 rows x 8 columns]

# %%
# And then go over them one by one. Make list and change tags

# %%
import spacy
from spacy import displacy

# %%
nlp = spacy.load("es_core_news_ml_EMS2")

# %%
from IPython.display import clear_output

# %%
import pickle

file = open("Trained_EMS2_NER_data.p", 'rb')
docs = pickle.load(file)

# %%
for (index, row) in people.iterrows():
    if row['Remove']=='check':
        print(row['string'])
        
        docid = row['docid']
        strstart = int(row['start'])
        fetchend = strstart + 10
        
        for doc in docs:
            if doc[1]['id'] == docid:
                displacy.render(doc[0][strstart:fetchend],style='ent',jupyter=True)
                people.loc[index,'Remove']=input('Remove?')
            if  people.loc[index,'Remove']=='X':
                people.loc[index,'Remove']=''
                if doc[1]['id'] == docid:
                    displacy.render(doc[0],style='ent',jupyter=True)
                    people.loc[index,'Remove']=input('Remove?')
            clear_output(wait=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-fc84913bd8c9> in <module>
# ----> 1 for (index, row) in people.iterrows():
#       2     if row['Remove']=='check':
#       3         print(row['string'])
#       4
#       5         docid = row['docid']
#
# NameError: name 'people' is not defined
