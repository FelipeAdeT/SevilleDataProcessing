# %% [markdown]
# # Data Cleaning 2: Correcting Token Spans
#
# In this notebook, we go over "person" tags and clean spans to make sure they reference full names, no more and no less.
#
# We will recover the tags as cleaned in Data Cleaning 1, focusing on those we maintained as 'Remove'= 0.
#
#
#
# # Strategy 1: To revise spans that are **too broad**
#
# Create a list of tokens that appear in entities but do not appear in the name lists. We can do this by getting the difference between the name set and the entity tokens set. Mark the tokens that might be considered potentially problematic. Find them and determine if they should be a part of the span. Edit the spans respectively.
#
# We can also add Kinkead's capitalized tokens to the "acceptable" token set.
#
# # Strategy 2: To revise spans that are **too short**
#
# Search for tokens to the left and right of a tagged person that appear in the entity list and the name lists and have not been tagged as entities. We can import the spacy docs, each token should have an entity tag = 0.
#
# # Strategy 3: Untagged PER entities
#
# Search for strings that match exactly with strings that have been tagged as entities. This should work to pick up untagged people.
#
# ---
#
# # 1 Creating a list of tokens that appear in our entities

# %%
import pandas as pd
people = pd.read_csv('Files_Cleaning1/PER_tags_clean1.csv')

# %%
people.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  Unnamed: 0.1.1.1  \
# 0           0             0               0             57935
# 1           1             1               1             45285
# 2           2             2               2             45173
# 3           3             3               3             45108
# 4           4             4               4             61780
#
#    Unnamed: 0.1.1.1.1  docid          string label  start  end Remove
# 0               57935   6792             NaN   NaN    135  138      1
# 1               45285   4978     - Rodriguez   PER      6    8      0
# 2               45173   4961  -- Gomez Brito   PER     34   38      0
# 3               45108   4952     -- Manrique   PER     11   13      0
# 4               61780   7342      -- Ramirez   PER     29   31      0

# %%
grouped = people.groupby('Remove')
grouped.count()
# Out:
#         Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  Unnamed: 0.1.1.1  \
# Remove
# 0            32442         32442           32442             32442
# 1              561           561             561               561
# D                6             6               6                 6
# L               39            39              39                39
# M                6             6               6                 6
# O               66            66              66                66
#
#         Unnamed: 0.1.1.1.1  docid  string  label  start    end
# Remove
# 0                    32442  32442   32442  32442  32442  32442
# 1                      561    561     558      0    561    561
# D                        6      6       6      6      6      6
# L                       39     39      39     39     39     39
# M                        6      6       6      6      6      6
# O                       66     66      66     66     66     66

# %% [markdown]
# Let's generate a list of tokens that appear in our PER entities. To do this, we are flattening the list of lists that is generated when we split each string by spaces, and we create a set to remove duplicates. Then we store it as a list again.

# %%
tokenlist= people.loc[people['Remove']=='0','string'].str.split().tolist()

# %%
newlist= []
for sublist in tokenlist:
    if type(sublist)==list:
        for item in sublist:
            newlist.append(str(item).lower())
tokenlist=list(set(newlist))

# %%
tokenlist.sort()

# %%
len(tokenlist)
# Out:
# 5164

# %%
with open('PersonNameTokenList.csv','w') as file:
    for item in tokenlist:
        file.write(item + "\n")

# %%
print(tokenlist)
# Out:
# ['-', '--', '--de', '--nino', '-basco', '-gaspar', '-geronimo', '-luisa', '-ndo', '-vasco', '2-', '20', '481', 'a', 'abaasquita', 'abaco', 'abadesa', 'abadessa', 'abadia', 'abaeu', 'abalos', 'abaxo', 'abdina', 'abedaria', 'abeis', 'abel', 'abellan', 'abellano', 'abendaria', 'abendaño', 'abila', 'abiles', 'abita', 'abley', 'ablo', 'abraham', 'abrego', 'abreu', 'abril', 'abrue', 'abueda', 'acacio', 'academia', 'acauna', 'acebedo', 'acedo', 'acencio', 'acencion', 'acenfio', 'acensio', 'acer', 'acerdian', 'acero', 'acevedo', 'acha', 'acharte', 'acinto', 'acipres', 'acisclos', 'acle', 'acofta', 'acolina', 'acosser', 'acosta', 'acuna', 'acuña', 'adalid', 'adallo', 'adam', 'adame', 'adan', 'adornio', 'adriaen', 'adrian', 'aduana', 'afan', 'afanador', 'afandor', 'afedo', 'afencio', 'afenfio', 'afeto', 'agais', 'agilon', 'agora', 'agramonte
aponte', 'apostol', 'apostoles', 'aqua', 'aquelman', 'aquino', 'ara', 'aragon', 'aragones', 'aramburo', 'aramos', 'arana', 'aranburo', 'aranburu', 'aranda', 'arandia', 'aranguibel', 'arangurede', 'araqui', 'araqume', 'araujo', 'araus', 'arauz', 'araz', 'arazola', 'arbas', 'arbizti', 'arbuscody', 'arcadio', 'arcarate', 'arce', 'arcediano', 'arcegani', 'arche', 'arcos', 'arebalo', 'areguas', 'arellano', 'aremo', 'arenales', 'arenas', 'areno', 'arensecallatrada', 'arespe', 'aresti', 'arestui', 'areualo', 'arevalo', 'arfediano', 'arf ...

# %% [markdown]
# # 2 Creating a list of tokens not in our combined namelists

# %%
fnames = open('DBE_Names/firstnames.txt')
lnames = open('DBE_Names/lastnames.txt')

# %%
names = []

for line in fnames:
    names.append(line.rstrip('\n'))
    
for line in lnames:
    names.append(line.rstrip('\n'))

# %%
names = set(names)

# %%
names
# Out:
# {'arenzana',
#  'altamirano',
#  'bruneau',
#  'riego',
#  'batlle',
#  'menendez-lavandera',
#  'avinent',
#  'balaguer',
#  'johann',
#  'alsedo',
#  'lores',
#  'rufino',
#  'mazo',
#  'german',
#  'blumen',
#  'obrador',
#  'comallonga',
#  'ruiz-bravo',
#  'rechaule',
#  'sesvilles',
#  'baçan',
#  'foz',
#  'trastamar',
#  'jacot',
#  'poyo',
#  'gazola',
#  'ibero',
#  'arrivillaga',
#  'caamaño',
#  'manjon',
#  'yandiola',
#  'buey',
#  'bonanat',
#  'nogueira',
#  'francesc',
#  'beraton',
#  'fernandez-rajo',
#  'texeda',
#  'adsor',
#  'ambrosio',
#  'monge',
#  'leaegui',
#  'marzo',
#  'olavide',
#  'bergosa',
#  'caunedo',
#  'ciscar',
#  'landaburu',
#  'mirabent',
#  'tramulles',
#  'buach',
#  'abadal',
#  'centella',
#  'torrella',
#  'cienfuegos',
#  'danese',
#  'ohiggins',
#  'ferry',
#  'crispin',
#  'presno',
#  'fuensalida',
#  'nordenflicht',
#  'monteros',
#  'salelles',
#  'malvar',
#  'tirry',
#  'vicenç',
#  'dupire',
#  'mancio',
#  'langarica',
#  'cramer',
#  'villagrassa',
#  'giro',
#  'zamalloa',
#  'terrazas',
#  'manuela',
#  'taboada',
#  'thubieres',
#  'coleti',
#  'deverez',
#  'frontaura',
#  'estuard',
#  'limia',
#  'bouchard',
#  'carmine',
#  'cantillana',
#  'guilarte',
#  'clavigero',
#  'borgoñon',
#  'ruy',
#  'acorbe',
#  'capellin',
#  'carocci',
#  'lira',
#  'chilli',
#  'diz',
#  'necoechea',
#  'peinado',
#  'lubice',
#  'babot',
#  'occina',
#  'cavia',
#  'fumo',
#  'pendones',
#  'landecho',
#  'moraleja',
#  'solanot',
#  'rohde',
#  'mancelli',
#  'mc',
#  'pingarron',
#  'rocacrespa',
#  'salsete',
#  'viescas',
#  'corrientes',
#  'acedo',
#  'roger',
#  'leroy',
#  'bermejo',
#  'luschner',
#  'sinues',
#  'dennetieres',
#  'eder',
#  'jerez',
#  'maille-breze',
#  'iglesia',
#  'camba',
#  'sola',
#  'valgoma',
#  'ignacio',
#  'bihuesca',
#  'isaac',
#  'loaces',
#  'alcocer',
#  'moyachoque',
#  'eudald',
#  'langa',
#  'massot',
#  'vertiz',
#  'mendavia',
#  'loizaga',
#  'burges',
#  'reinegg',
#  'jacint',
#  'villasante',
#  'dhoutlier',
#  'varillas',
#  'folguera',
#  'galacian',
#  'amado',
#  'morones',
#  'tesillo',
#  'eguzquiza',
#  'lelio',
#  'artieda',
#  'garcia-ojeda',
#  'trullo',
#  'rigoni',
#  'seguin',
#  'savila',
#  'serena',
#  'sigler',
#  'torrigiano',
#  'filippo',
#  'barajas',
#  'abbeville',
#  'castellote',
#  'eudaldo',
#  'davin',
#  'montaner',
#  'renovales',
#  'ocrouley',
#  'serpa',
#  'serafin',
#  'lopidana',
#  'quevedo',
#  'krets',
#  'horozco',
#  'irujo',
#  'longinos',
#  'reula',
#  'celma',
#  'hoefnagel',
#  'rufo',
#  'rubio',
#  'olloniego',
#  'roberto',
#  'drument',
#  'burke',
#  'olmo',
#  'bertran',
#  'janer',
#  'castellot',
#  'colodro',
#  'ricafort',
#  'rubiños',
#  'argos',
#  'fernandez-valdes',
#  'gallard',
#  'jorquera',
#  'cañal',
#  'porcia',
#  'frias',
#  'arburola',
#  'osorio',
#  'cabanyes',
#  'lasauca',
#  'cabaspre',
#  'magaña',
#  'ron',
#  'cruchaga',
#  'ribalta',
#  'altoaguirre',
#  'cloostermans',
#  'requena',
#  'evangelista',
#  'montiano',
#  'mut',
#  'jeronima',
#  'carafa',
#  'manca',
#  'casayau',
#  'coig',
#  'alzaibar',
#  'maturana',
#  'ramonet',
#  'rosell',
#  'mellid',
#  'cregenzan',
#  'vinyes',
#  'ardemans',
#  'valles',
#  'villaguisada',
#  'taxonera',
#  'collazo',
#  'cambi',
#  'babil',
#  'arigorri',
#  'ibando',
#  'pinto',
#  'ezarra',
#  'elcano',
#  'labiades',
#  'suau',
#  'veintimiglia',
#  'miserol',
#  'yoly',
#  'manco',
#  'sitoni',
#  'agnesio',
#  'briz',
#  'lemoyne',
#  'aspiazu',
#  'barry',
#  'ferreres',
#  'silveyra',
#  'lascurain',
#  'gomes',
#  'calar',
#  'lizaur',
#  'parreño',
#  'kuhl',
#  'barreda',
#  'vandadas',
#  'gervasio',
#  'just',
#  'fortunato',
#  'gayola',
#  'fleitas',
#  'gabriele',
#  'cristobalina',
#  'brouchoven',
#  'bails',
#  'goxenechea',
#  'caja',
#  'lucas',
#  'ferraz',
#  'mercator',
#  'zalduendo',
#  'guell',
#  'barra',
#  'adurza',
#  'aycart',
#  'grillo',
#  'escucha',
#  'trueba',
#  'comella',
#  'echaburu',
#  'echavarri',
#  'caxal',
#  'arenas',
#  'roura',
#  'urbani',
#  'juliana',
#  'bastida',
#  'rosado',
#  'valdermont',
#  'marrades',
#  'guarinos',
#  'aymamo',
#  'guirior',
#  'tiedra',
#  'grandi',
#  'iguanzo',
#  'proaza',
#  'salomon',
#  'fort',
#  'holbeque',
#  'fragoso',
#  'germana',
#  'corio',
#  'galarza',
#  'emigdio',
#  'verrua',
#  'fontes',
#  'blasino',
#  'castelblanco',
#  'amelot',
#  'amolaz',
#  'pernas',
#  'sancho',
#  'moldes',
#  'mostaros',
#  'pachacuti',
#  'albear',
#  'sanguesa',
#  'penne',
#  'seigne',
#  'brusi',
#  'savona',
#  'rouvroy',
#  'lago',
#  'mascardi',
#  'villafranca',
#  'urbain',
#  'lacasa',
#  'arimon',
#  'camaleño',
#  'gual-moix',
#  'roman',
#  'calcuchima',
#  'marie-anne',
#  'testera',
#  'asuncion',
#  'escandon',
#  'ibarrondo',
#  'agapito',
#  'mayoralgo',
#  'tuyru',
#  'dicart',
#  'gangotena',
#  'valdestairo',
#  'hortun',
#  'comino',
#  'falck',
#  'barquero',
#  'onofre',
#  'atau',
#  'niza',
#  'echeandia',
#  'anguissola',
#  'garino',
#  'januario',
#  'nieva',
#  'porto',
#  'maure',
#  'balandra',
#  'garland',
#  'campoy',
#  'maximiliano',
#  'silverio',
#  'dowel',
#  'macdonnell',
#  'danis',
#  'davila',
#  'echandi',
#  'hoyos',
#  'dreveton',
#  'corominas',
#  'encima',
#  'trigona',
#  'amescua',
#  'courbes',
#  'aznar',
#  'hernando',
#  'frisa',
#  'lamuela',
#  'escala',
#  'romano',
#  'bojadors',
#  'meliluppi',
#  'hinojosos',
#  'juanich',
#  'vizcayno',
#  'bolide',
#  'cascante',
#  'casedron',
#  'magdaleno',
#  'camin',
#  'lecaros',
#  'picazo',
#  'alpuche',
#  'autillo',
#  'vaguer',
#  'casco',
#  'celestre',
#  'rubi',
#  'oliva',
#  'possi',
#  'nicanor',
#  'aste',
#  'chaperon',
#  'pradanos',
#  'jalon',
#  'donato',
#  'bonastre',
#  'talamantes',
#  'gamir',
#  'fausto',
#  'blanque',
#  'izquierdo',
#  'conchillos',
#  'cortada',
#  'eguiazabal',
#  'dardon',
#  'herzellez',
#  'gaviria',
#  'mompurdo',
#  'ubecar',
#  'ramirez',
#  'mauro',
#  'bordas',
#  'jimena',
#  'rouco',
#  'ginoves',
#  'collaert',
#  'bandera',
#  'godin',
#  'garci-aguirre',
#  'encarnacion',
#  'murillas',
#  'goyri',
#  'montoya',
#  'mourelle',
#  'castilho',
#  'pompeo',
#  'ruzola',
#  'gavarrer',
#  'bisbal',
#  'satayol',
#  'monserrat',
#  'borghini',
#  'cagigal',
#  'gironza',
#  'gamboa',
#  'william',
#  'matis',
#  'felipe',
#  'nario',
#  'beitia',
#  'apostol',
#  'real',
#  'vidaurreta',
#  'micheo',
#  'esbarroya',
#  'escalante',
#  'mandura',
#  'pelayo',
#  'abul',
#  'ussel',
#  'valdivieso',
#  'cuero',
#  'reginaldo',
#  'arenzano',
#  'cornieles',
#  'hubert-guillaume',
#  'solares',
#  'bibiana',
#  'busto',
#  'morillo',
#  'yedra',
#  'geronima',
#  'xavier',
#  'foncalda',
#  'langara',
#  'planellas',
#  'centellas',
#  'gras',
#  'florensa',
#  'valdivielso',
#  'arpide',
#  'brocar',
#  'mestanza',
#  'almanza',
#  'arco-aguero',
#  'hortensio',
#  'pineau',
#  'vernacci',
#  'verdad',
#  'benitez',
#  'carro',
#  'castañeda',
#  'musa',
#  'uribe',
#  'bardalonga',
#  'valladares',
#  'nini',
#  'bartolomeo',
#  'villalonga',
#  'padilla',
#  'merode',
#  'guaman',
#  'ortells',
#  'ollauri',
#  'souto',
#  'curupirati',
#  'estevao',
#  'pablos',
#  'ameijeiras',
#  'valois',
#  'trotti',
#  'falconi',
#  'bordick',
#  'magro',
#  'malaver',
#  'bebecolarrea',
#  'gorrevod',
#  'ladrillero',
#  'vidania',
#  'apostoles',
#  'soloa',
#  'gravina',
#  'correas',
#  'madan',
#  'tortosa',
#  'ordoño',
#  'estevez',
#  'florentino',
#  'perola',
#  'apostole',
#  'giraud',
#  'moragues',
#  'perdomo',
#  'xocoyot',
#  'john',
#  'oncins',
#  'ezquiaga',
#  'varas',
#  'libadote',
#  'alas',
#  'armenteros',
#  'indalecio',
#  'auguet',
#  'bayle',
#  'covarrubias',
#  'olano',
#  'castella',
#  'destefanis',
#  'ballesteros',
#  'vicent',
#  'bivar',
#  'desprat',
#  'massanes',
#  'benit',
#  'frisia',
#  'manera',
#  'alamos',
#  'antolin',
#  'escriva',
#  'guazo',
#  'murcia',
#  'modenes',
#  'biada',
#  'pradilla',
#  'torrecillas',
#  'mohedano',
#  'vazquez',
#  'buerens',
#  'guantanab',
#  'soares',
#  'rami',
#  'junquera',
#  'interian',
#  'canencia',
#  'doray',
#  'barroeta-aldamar',
#  'mercado',
#  'lazcaibar',
#  'sequeira',
#  'zacagnini',
#  'martins',
#  'guitart',
#  'moureau',
#  'apaolaza',
#  'mina',
#  'ehinger',
#  'vides',
#  'jimenez-cebadera',
#  'lacunza',
#  'oloriz',
#  'chao',
#  'laines',
#  'cannizaro',
#  'eguiarreta',
#  'cayetano',
#  'arance',
#  'villachica',
#  'valero',
#  'gelzen',
#  'barcia',
#  'ascanio',
#  'capuz',
#  'nadal',
#  'romo',
#  'biriteca',
#  'gricci',
#  'bernat',
#  'irene',
#  'darcourt',
#  'pages-vallgornera',
#  'la',
#  'nepomuceno',
#  'mencia',
#  'gascon',
#  'jaraquemada',
#  'lacasta',
#  'carleval',
#  'mitre',
#  'taraval',
#  'lorenz',
#  'burgues',
#  'terre',
#  'boteller',
#  'gomila',
#  'masia',
#  'galan',
#  'tebes',
#  'arbolanche',
#  'barnola',
#  'firmat',
#  'serveto',
#  'feliciano',
#  'toral',
#  'victoriano',
#  'auli',
#  'grimosachs',
#  'cobertores',
#  'pardines',
#  'cadrecha',
#  'blancaflor',
#  'filicaia',
#  'rechac',
#  'amigo',
#  'cañizo',
#  'poggini',
#  'dios',
#  'cardano',
#  'gallarati',
#  'cornet',
#  'rivamartin',
#  'barthe',
#  'fabrizio',
#  'picardo',
#  'ocll',
#  'lunel',
#  'centani',
#  'barcenas',
#  'fleyres',
#  'sanmamed',
#  'ardila',
#  'uriola',
#  'alcañiz',
#  'melgares',
#  'utges',
#  'nemesio',
#  'pui',
#  'sarrava',
#  'frances',
#  'arenales',
#  'vizcaino',
#  'corrionero',
#  'victores',
#  'orellana',
#  'verganza',
#  'aduarte',
#  'barrio',
#  'castell',
#  'rovirosa',
#  'sinforoso',
#  'veitia',
#  'gaston',
#  'carniado',
#  'abengoechea',
#  'virrey',
#  'juancho',
#  'dufresne',
#  'nambayu',
#  'yosef',
#  'veiria',
#  'latoner',
#  'parragues',
#  'laviña',
#  'crisostomo',
#  'pampin',
#  'serres',
#  'hatuey',
#  'cassani',
#  'urrelo',
#  'escalada',
#  'botti',
#  'jonte',
#  'castriato',
#  'partearroyo',
#  'balbuena',
#  'eladio',
#  'andrevi',
#  'verdesoto',
#  'damas',
#  'arosa',
#  'granada-venegas',
#  'alemani',
#  'caracciolo',
#  'franques',
#  'pectorelli',
#  'castellnovo',
#  'travieso',
#  'guill',
#  'angelino',
#  'ruffo',
#  'utrera',
#  'vicente',
#  'orrantia',
#  'canton',
#  'brozas',
#  'espino',
#  'marques',
#  'borica',
#  'spina',
#  'fraile',
#  'arroita',
#  'andrana',
#  'laboraria',
#  'damia',
#  'bremond',
#  'llorente',
#  'loarte',
#  'arrunduaga',
#  'miron',
#  'morlanes',
#  'samunde',
#  'vivas',
#  'gimenez',
#  'alzamora',
#  'charles-alexandre',
#  'lupo',
#  'weld',
#  'romeu',
#  'feliciana',
#  'arbulo',
#  'faing',
#  'palma',
#  'fabian',
#  'casabona',
#  'magarola',
#  'bucareli',
#  'girbal',
#  'guntin',
#  'tordehumos',
#  'milan',
#  'suris',
#  'tresguerras',
#  'faustino',
#  'juana',
#  'valle',
#  'garralon',
#  'prada',
#  'clemencia',
#  'narvaez',
#  'rovere',
#  'wittelsbach',
#  'aztiguieta',
#  'gasque',
#  'albacar',
#  'tudelilla',
#  'grimaldo',
#  'kramer',
#  'malvarez',
#  'filipe',
#  'amigant',
#  'carduchi',
#  'granollachs',
#  'legasa',
#  'senseve',
#  'arrona',
#  'almenar',
#  'heredia',
#  'andre',
#  'marien',
#  'galeazzo',
#  'iraizoz',
#  'bucheli',
#  'diez',
#  'duaso',
#  'olamendi',
#  'jacinto',
#  'costanzo',
#  'chirino',
#  'monphaon',
#  'bañuelos',
#  'amatriain',
#  'ruiz',
#  'bolduque',
#  'bergamo',
#  'gorvea',
#  'canto',
#  'hipolito',
#  'ainsa',
#  'mello',
#  'naygeon',
#  'besora',
#  'rubiano',
#  'llaneras',
#  'cochet',
#  'coello',
#  'arauza',
#  'ursino',
#  'baratta',
#  'bas',
#  'saragossa',
#  'soriano',
#  'visitacio',
#  'commeg',
#  'jean-marie',
#  'guezzi',
#  'ducete',
#  'montijo',
#  'basarrate',
#  'lavarces',
#  'alda',
#  'quint',
#  'magenise',
#  'acitores',
#  'schor',
#  'morenes',
#  'navarrete',
#  'combe',
#  'badaran',
#  'darregueyra',
#  'gonzalvez',
#  'subiras',
#  'pane',
#  'justa',
#  'perena',
#  'rabasquino',
#  'campoblanco',
#  'perille',
#  'fages',
#  'santangel',
#  'pueyrredon',
#  'giginta',
#  'almansa',
#  'salceda',
#  'pastora',
#  'cistue',
#  'sota',
#  'ledesma',
#  'ormaza',
#  'treviño',
#  'quepuant',
#  'alameda',
#  'añorbe',
#  'ganzabal',
#  'hipenza',
#  'laiseca',
#  'eminente',
#  'considyn',
#  'anglasell',
#  'porter',
#  'settala',
#  'trejo',
#  'onderiz',
#  'saubidet',
#  'taranco',
#  'haurie',
#  'hijosa',
#  'inguanzo',
#  'horta',
#  'navarro',
#  'blanch',
#  'baglietto',
#  'herrero',
#  'fabregas',
#  'hans',
#  'tofiño',
#  'panana',
#  'berdejo',
#  'arbues',
#  'dolgas',
#  'roma',
#  'estenaga',
#  'rudecindo',
#  'lalaing',
#  'risueño',
#  'whittingham',
#  'pertusato',
#  'rech',
#  'fitz-gerald',
#  'azcuitia',
#  'forte',
#  'cerain',
#  'bienvengud',
#  'cabezas',
#  'cardona-anglesola',
#  'ripoli',
#  'santelices',
#  'ines',
#  'mesia',
#  'augusto',
#  'das',
#  'abollado',
#  'carrafa',
#  'orosz',
#  'bona',
#  'ostabat',
#  'morazan',
#  'vinuesa',
#  'spinola',
#  'garoz',
#  'habaqui',
#  'foguet',
#  'lleopart',
#  'artiga',
#  'chavaneau',
#  'veytia',
#  'carasa',
#  'merchante',
#  'mayora',
#  'romarate',
#  'romanillos',
#  'dostrel',
#  'camacho',
#  'vieyra',
#  'cucalon',
#  'telesforo',
#  'otano',
#  'elorduy',
#  'sorapan',
#  'salavarrieta',
#  'falla',
#  'arcaya',
#  'parodi',
#  'accursio',
#  'villareal',
#  'teres',
#  'gerbaut',
#  'vozmediano',
#  'giaquinto',
#  'justus',
#  'giraldez',
#  'lanzos',
#  'cantoral',
#  'courselle',
#  'goyena',
#  'pabon',
#  'emasabel',
#  'darder',
#  'orbea',
#  'num',
#  'pedro-luis',
#  'trapoli',
#  'fors',
#  'bayles',
#  'salmon',
#  'muniain',
#  'alzaybar',
#  'buisson',
#  'avalos',
#  'illescas',
#  'iraizos',
#  'argumosa',
#  'arroyuelo',
#  'vique',
#  'rivacoba',
#  'coloma',
#  'mainoldi',
#  'pechman',
#  'maiquez',
#  'alemany',
#  'campana',
#  'desnaux',
#  'chilche',
#  'arles',
#  'navaz',
#  'llançol',
#  'olaya',
#  'monrava',
#  'angles',
#  'galloso',
#  'landivar',
#  'ambulodi',
#  ...}

# %%
len(names)
# Out:
# 10005

# %% [markdown]
# Above, we have created one set of unique names from both our first names and last names file, no overlap.
#
# Next, let's find the difference between this list and our tokens found above.

# %%
tokset = set(tokenlist)
potential_non_names = list(tokset - names)

# %%
len(potential_non_names)
# Out:
# 3477

# %%
acceptedtokens = list(tokset & names)

# %%
len(acceptedtokens)
# Out:
# 1687

# %%
print(acceptedtokens)
# Out:
# 0               57935   6792             NaN   NaN    135  138      1
# 1               45285   4978     - Rodriguez   PER      6    8      0
# 2               45173   4961  -- Gomez Brito   PER     34   38      0
# 3               45108   4952     -- Manrique   PER     11   13      0
# 4               61780   7342      -- Ramirez   PER     29   31      0
#
#   matched_str
# 0           n
# 1           -
# 2          --
# 3          --
# 4          --

# %%
import re
def pattern_searcher(search_str:str, search_list:str):

    search_obj = re.search(search_list, search_str)
    if search_obj:
        return_str = 1
    else:
        return_str = 0
    return return_str

# %%
pattern = '|'.join(potential_non_names)

# %%
people['matched_str'] = people['string'].apply(lambda x: pattern_searcher(search_str=str(x), search_list=pattern))

# %%
people[people['matched_str']==1].count()
# Out:
# Unnamed: 0            27102
# Unnamed: 0.1          27102
# Unnamed: 0.1.1        27102
# Unnamed: 0.1.1.1      27102
# Unnamed: 0.1.1.1.1    27102
# docid                 27102
# string                27099
# label                 26541
# start                 27102
# end                   27102
# Remove                27102
# matched_str           27102
# dtype: int64

# %% [markdown]
# We have 27,102 tags that have a potentially questionable token right now.

# %% [markdown]
# # 2 Fuzzy Matching
#
# Let's use our results from fuzzy matching and accept those tokens that represent a 90% match with tokens in the lists.

# %%
fuzzymatches = pd.read_csv('Files_Cleaning1/token_match_scores.csv')

# %%
fuzzymatches.set_index('token', inplace= True)

# %%
fuzzymatches.head()
# Out:
#             Unnamed: 0  score    match
# token
# BENJUMEA             0     71   enjuta
# Prevendado           1     71  revenga
# Lateral              2     77   antera
# MORILLO              3    100  morillo
# Ramon                4    100    ramon

# %%
tokens90 = fuzzymatches[fuzzymatches['score']>=90].index.str.lower().tolist()

# %%
len(tokens90)
# Out:
# 3717

# %%
print(tokens90)
# Out:
# ['morillo', 'ramon', 'ruela', 'morante', 'coello', 'velazquez', 'cardenas', 'tirado', 'borja', 'quebedo', 'martos', 'quevedo', 'teresa', 'juanes', 'monero', 'arze', 'biedma', 'durango', 'barrionuebo', 'despindola', 'trujillo', 'ruiz', 'baltasar', 'tenorio', 'villens', 'iriarte', 'canto', 'villa', 'astete', 'agustin', 'ruano', 'trelles', 'enrique', 'rroelas', 'grimon', 'rosal', 'horosco', 'atienza', 'sala', 'cuesta', 'espinosa', 'eraso', 'carasco', 'ayllon', 'meneses', 'sotto', 'cipriano', 'ribadeneira', 'dimas', 'barrassa', '-geronimo', 'alonso', 'calatayud', 'salafranca', 'caro', 'arnao', 'holgado', 'pan', 'gomez', 'morellon', 'llanes', 'porras', 'muñoz', 'ruis', 'mathia', 'garcia', 'torres', 'deza', 'siguença', 'vermondo', 'solarte', 'ruesta', 'caraballo', 'almonacid', 'aldrette', 'florencia', 'nicolas', 'deza', 'rrojas', 'hernandez', 'roela', 'carcel', 'matias', 'pino', 'goncalo', 'maria', 'carrasco', 'federigui', 'rroldan', 'torado', 'marcho', 'cuevas', 'arpe', 'arana', 'izaguire', 'franciisco', 'mata', 'bartome', 'rubira', 'buenabentura', 'olano', 'añasco', 'colmenero', 'anales', 'simona', 'grillo', 'ribas', 'puerta', 'cancino', 'enrique', 'montesinos', 'carasquila', 'esteban', 'schutt', 'arieta', 'gregorio', 'nieves', 'beltran', 'sotomayo', 'carasquilla', 'laines', 'carabajal', 'doñate', 'consuegra', 'cristina', 'malpartida', 'palacio', 'cotan', 'villacastin', 'valderrama', 'cuesta', 'collantes', 'fajardo', 'tovar', 'angulo', 'higueras', 'cardoso', 'cancino', 'bellon', 'chico', 'peralta', 'orellana', 'ramos', 'apostoles', 'ribadeniera', 'chacon', 'cañizares', 'lorença', '-gaspar', 'corro', 'uribari', 'atanasio', 'quintanilla', 'enrique', 'çuleta', 'teran', 'hidalgo', 'bernaldina', 'gaitan', 'vilchez', 'rrodrigo', 'escuderos', 'hermenegildo', 'noguera', 'salguero', 'cantera', 'frano', 'pinto', 'texeda', 'mañana', 'iglesias', 'agustina', 'tacon', 'suero', 'perea', 'esparragosa', 'barahona', 'marie', 'morga', 'corral', 'acisclos', 'carton', 'niebla', 'reyes', 'fernando', 'thoribio', 'bronçe', 'vasco', 'porra', 'frano', 'maeda', 'luciano', 'machado', 'corneil', 'bohorquez', 'aguiar', 'gongalo', 'lazaro', 'jordan', 'giraldo', 'martin', 'lejalde', 'cedillo', 'ponce', 'merida', 'uriarte', 'carrizoça', 'manuel', 'velazco', 'ocampos', 'auila', 'barrientos', 'sabastiana', 'bautista', 'illescas', 'valdivieso', 'jiles', 'vandelvira', 'pablo', 'crisostomo', 'cortez', 'tobar', 'cifuentes', 'tavera', 'valverde', 'ollero', 'barba', 'hijar', 'arenas', 'arespe', 'susana', 'mendes', 'josefe', 'jancinto', 'acolina', 'trinidad', 'carvajal', 'abellan', 'reynes', 'garay', 'catalan', 'chavez', 'arrenas', 'bernabe', 'villavicencio', 'çarate', 'paula', 'gerardo', 'moron', 'gutierrez', 'jorge', 'troya', 'laureano', 'adrian', 'riquelme', 'lorenzo', 'guerrero', 'la', 'enrique', 'villapando', 'cartagena', 'bonifaz', 'baltazar', 'galindo', 'vidal', 'texeda', 'jesu', 'henrriquez', 'aragones', 'morillas', 'roldan', 'vega', 'mondragon', 'ignacia', 'salmeron', 'sastre', 'acha', 'subira', 'morcillo', 'soto', 'oro', 'bernal', 'barrios', 'gregorio', 'toscano', 'ospital', 'pedro', 'serpa', 'perea', 'rramos', 'trujillo', 'coçar', 'manuel', 'coca', 'miralles', 'reina', 'madera', 'riscos', 'eusebio', 'rubiales', 'philipe', 'fadrique', 'palencia', 'gracia', 'crispina', 'gallego', 'baleriano', 'dezcurra', 'tomas', 'toranço', 'anton', 'correa', 'guillen', 'montilla', 'carrera', 'marito', 'obando', 'ros', 'bohorques', 'duran', 'torres', 'diez', 'baldra', 'maria', 'villafranca', 'gamboa', 'joan', 'matieno', 'rivas', 'escamilla', 'manrique', 'fuergo', 'arteaga', 'pessoa', 'valdivieso', 'horozco', 'abel', 'marquez', 'fernandes', 'escobar', 'rodriguez', 'tinoco', 'girolamo', 'pando', 'benitez', 'riuera', 'talavera', 'bracho', 'abraham', 'mayorga', 'cobos', 'castellana', 'ubrien', 'mari', 'desquivel', 'alejo', 'daza', 'santillana', 'lorenzana', 'frayle', 'matias', 'lozano', 'salzedo', 'señoria', 'velasco', 'niño', 'tirando', 'tornero', 'sarabia', 'navaro', 'gadea', 'cast ...

# %%
tok90set = set(tokens90)

# %%
acceptedtokens= list(set(tokset & (names.union(tok90set))))

# %%
len(acceptedtokens)
# Out:
# 2416

# %%
potential_non_names2 = list(tokset - names - tok90set)

# %%
len(potential_non_names2)
# Out:
# 2748

# %% [markdown]
# This is still too long

# %% [markdown]
# # Number of records with a token not from our name list

# %%
people.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  Unnamed: 0.1.1.1  \
# 0           0             0               0             57935
# 1           1             1               1             45285
# 2           2             2               2             45173
# 3           3             3               3             45108
# 4           4             4               4             61780
#
#    Unnamed: 0.1.1.1.1  docid          string label  start  end Remove  \
# 0               57935   6792             NaN   NaN    135  138      1
# 1               45285   4978     - Rodriguez   PER      6    8      0
# 2               45173   4961  -- Gomez Brito   PER     34   38      0
# 3               45108   4952     -- Manrique   PER     11   13      0
# 4               61780   7342      -- Ramirez   PER     29   31      0
#
#    matched_str
# 0            1
# 1            1
# 2            1
# 3            1
# 4            1

# %%
pattern = ''
pattern = '|'.join(potential_non_names2)

# %%
people['matched_str'] = people['string'].apply(lambda x: pattern_searcher(search_str=str(x), search_list=pattern))

# %%
people[people['matched_str']==1].count()
# Out:
# Unnamed: 0            27102
# Unnamed: 0.1          27102
# Unnamed: 0.1.1        27102
# Unnamed: 0.1.1.1      27102
# Unnamed: 0.1.1.1.1    27102
# docid                 27102
# string                27099
# label                 26541
# start                 27102
# end                   27102
# Remove                27102
# matched_str           27102
# dtype: int64

# %% [markdown]
# We have 27,102 tags that have a potentially questionable token right now.

# %%
fuzzymatches.loc['SCHUITT']
# Out:
# Unnamed: 0     3668
# score            83
# match         schut
# Name: SCHUITT, dtype: object

# %%
tok83set = set(fuzzymatches[(fuzzymatches['score']>83) &(fuzzymatches['score']<90)].index.str.lower().to_list())

# %%
len(tok83set)
# Out:
# 981

# %%
fuzzymatches.loc['becino']
# Out:
# Unnamed: 0      5042
# score             83
# match         benino
# Name: becino, dtype: object

# %%
print(tok83set)
# Out:
# {'rodrygo', 'zarcosa', 'libera', 'chamarro', 'lucente', 'rruiz', 'fugoso', 'graendes', 'jerusalen', 'reymundo', 'ferino', 'bartolo', 'pora', 'leonarda', 'kernandez', 'hespa', 'sayz', 'consecion', 'galbez', 'myranda', 'costança', 'fria', 'sauzedo', 'sal', 'beatris', 'fraucisco', 'espinera', 'mañan', 'rreal', 'andrach', 'cotte', 'antonyo', 'sausedo', 'u¡llalobos', 'gueuara', 'benabides', 'arguela', 'juhan', 'dotores', 'vrrutia', 'corbachino', 'cueba', 'guarin', 'monrroi', 'bejines', 'amarrosta', 'roças', 'moyna', 'mansano', 'lodobico', 'ase', 'cifneros', 'abalos', 'salbago', 'bernandes', 'barea', 'ala', 'hoya', 'altar', 'montearroyo', 'caruajal', 'merced\x97', 'forteza', 'loro', 'hinoxosa', 'lansa', 'hordones', 'faustina', 'anduxar', 'serabia', 'trabieso', 'montejer', 'ponse', 'rrio', 'jhoan', 'aya', 'escaraza', 'faucedo', 'malaves', 'tres', 'domingues', 'jasinto', 'cuia', 'alrecon', 'yniesta', 'argadona', 'reynalte', 'requadros', 'tamares', 'bouadilla', 'bos', 'malgarida', 'cauello', 'caña', 'bellarte', 'coello\x97en', 'saya', 'mill', 'los', 'cristoual', 'cuadros', 'velas', 'tamaris', 'sarcilla', 'liano', 'saitores', 'loxo', 'bergara-', 'josue', 'yvañes', 'gonsalez', 'albarran', 'garrasin', 'pie', 'dionifio', 'nabarrete', 'uriano', 'palles', 'nauarro', 'benites', 'albardo', 'ybarrola', 'pescados', 'escurra', 'coltrera', 'jossephe', 'zanbrano', 'siriaco', 'ssalzedo', 'fifontes', 'ceprian', 'cauildo', 'bobadillo', 'argunedo', 'bexarano', 'herrados', 'billabicencio', 'salto', 'vegua', 'las', 'bezerra', 'daniella', 'cena', 'belasquez', 'isola', 'sevastian', 'lunan', 'corregio', 'hitta', 'mandara', 'jiralte', 'narbaez', 'benditos', 'rut', 'asis', 'caruallo', 'salbador', 'barlolome', 'constancia', 'silbestre', 'monterda', 'zaucedo', 'torines', 'altares', 'cerigo', 'panyagua', 'moscofo', 'sarauia', 'yugo', 'seuerino', 'thome', 'nunez', 'vallexo', 'baeça', 'cartaxena', 'bicario', 'torcano', 'mol', 'caluo', 'trenidad', 'sedo', 'jacquez', 'balverde', 'sanguino', 'basquez', 'arranegui', 'claramate', 'antunes', 'polar', 'arma', 'tiscareño', 'balderas', 'llaegui', 'reja', 'carbera', 'marqueses', 'bien', 'esquives', 'menezes', 'vena', 'aze', 'peso', 'felis', 'raton', 'fao', 'fulgencia', 'cordoda', 'luareano', 'torrada', 'fuentes\x97en', 'corderito', 'albares', 'canpo', 'cornexo', 'anjeles', 'roja', 'apremisa', 'seba', 'aria', 'granillo', 'lavando', 'calvijo', 'viscarra', 'seuilla', 'garzaran', 'cristoval', 'azenedo', 'betancor', 'saltillo', 'principe', 'sambrano', 'cera', 'aruas', 'uelazquez', 'bias', 'estado', 'jironimo', 'origuela', 'lorenco', 'orti', 'parecera', 'narvaes', 'ontiueros', 'dunquer', 'sartien', '--nino', 'ascarate', 'loannis', 'mantañes', 'alma', 'rfos', 'fide', 'crestina', 'una', 'sabriana', 'onofrio', 'candil', 'martires', 'uan', 'colonbres', 'ambrofio', 'herado', 'galderon', 'men', 'bernave', 'calzado', 'caribalo', 'cronelio', 'varnuevo', 'boldoque', 'casa', 'bauda', 'vares', 'chaveri', 'melgarexo', 'vas', 'eclada', 'aramburo', 'çarzuela', 'ffray', 'rrodero', 'varcenas', 'canzino', 'esquibel', 'laureana', 'caloña', 'oliuares', 'cerbantes', 'cuvillana', 'seuastian', 'rubias', 'belazque', 'mandadas\x97', 'frejenal', 'monsalue', 'escovar', 'ygnacio', 'pantoxa', 'lena', 'mandaua', 'pradillo', 'faz', 'celedon', 'aleantara', 'velazques', 'hortis', 'grachet', 'mayda', 'leais', 'pedrozo', 'sab', 'sor', 'jaramielo', 'largo', 'bortolome', 'tontera', 'veza', 'asada', 'montedo', 'vexarano', 'pizarra', 'ochandia', 'sarate', 'pila', 'guebara', 'bacca', 'prevº', 'saladar', 'bicentelo', 'guijarra', 'maldonodo', 'echaberri', 'merced', 'zervantes', 'aver', 'fanchez', 'algualzil', 'sevilla\x97juan', 'almonasir', 'gilberto', 'silizeo', 'valduque', 'vobadilla', 'seliceo', 'daça', 'francisso', 'pulgarin', 'cobarubias', 'albarez', 'fuentas', 'burch', 'muriana', 'vidas', 'siluestre', 'banegas', 'borte', 'cardenas\x97las', 'ambrosyo', 'biarte', 'calcada', 'vasques', 'betancur', 'platero', 'maitines', 'garrida', 'moço', 'faxardo', 'juli', 'lazegui' ...

# %%
potential_non_names = list(tokset - names - tok90set - tok83set)

# %%
len(potential_non_names)
# Out:
# 1841

# %%
print(potential_non_names)
# Out:
# %% [markdown]
# # Strategy 2
#
# Check strings with "San, Santo, Santa, Santos, Santas" and other non-person tokens.

# %%
nontokens = ['San ','Santo ','Santa ','Santos ','Santas ']

for token in nontokens:
    people.loc[people['string'].str.contains(token),'Remove']= 'check'

# %%
people.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  docid       string label  start  end Remove
# 0       57935         57935   6792                PER    135  138
# 1       45285         45285   4978    Rodriguez   PER      6    8
# 2       45173         45173   4961  Gomez Brito   PER     34   38
# 3       45108         45108   4952     Manrique   PER     11   13
# 4       61780         61780   7342      Ramirez   PER     29   31

# %%
people.groupby('Remove').count()
# Out:
#         Unnamed: 0  Unnamed: 0.1  docid  string  label  start    end
# Remove
# 0             7076          7076   7076    7076   7076   7076   7076
#              25943         25943  25943   25943  25943  25943  25943
# check          101           101    101     101    101    101    101

# %%
people[people['Remove']=='check']
# Out:
#        Unnamed: 0  Unnamed: 0.1  docid                     string label  \
# 1585        47680         47680   5302      Andrea Santa Trinidad   PER
# 1911        44395         44395   4876          Andres San Martin   PER
# 2452        16350         16350   1783         Antonio Santa Cruz   PER
# 2453        16540         16540   1806         Antonio Santa Cruz   PER
# 2454        16597         16597   1814         Antonio Santa Cruz   PER
# ...           ...           ...    ...                        ...   ...
# 18449        2112          2112    265      Sebastian Santa Maria   PER
# 18635       45302         45302   4979           Señor San Andres   PER
# 18636       66747         66747   8050         Señor San Laureano   PER
# 18639       52425         52425   5990  Señorr San Esteban Martir   PER
# 18678       42239         42239   4558      Sor Maria San Agustin   PER
#
#        start  end Remove
# 1585      62   67  check
# 1911      46   50  check
# 2452      37   41  check
# 2453       0    4  check
# 2454       9   13  check
# ...      ...  ...    ...
# 18449     10   14  check
# 18635    243  246  check
# 18636    122  125  check
# 18639    103  107  check
# 18678     14   19  check
#
# [101 rows x 8 columns]

# %%
# And then go over them one by one. Make list and change tags

# %%
import spacy
from spacy import displacy

# %%
nlp = spacy.load("es_core_news_ml_EMS2")

# %%
from IPython.display import clear_output

# %%
import pickle

file = open("Trained_EMS2_NER_data.p", 'rb')
docs = pickle.load(file)

# %%
for (index, row) in people.iterrows():
    if row['Remove']=='check':
        print(row['string'])
        
        docid = row['docid']
        strstart = int(row['start'])
        fetchend = strstart + 10
        
        for doc in docs:
            if doc[1]['id'] == docid:
                displacy.render(doc[0][strstart:fetchend],style='ent',jupyter=True)
                people.loc[index,'Remove']=input('Remove?')
            if  people.loc[index,'Remove']=='X':
                people.loc[index,'Remove']=''
                if doc[1]['id'] == docid:
                    displacy.render(doc[0],style='ent',jupyter=True)
                    people.loc[index,'Remove']=input('Remove?')
            clear_output(wait=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-fc84913bd8c9> in <module>
# ----> 1 for (index, row) in people.iterrows():
#       2     if row['Remove']=='check':
#       3         print(row['string'])
#       4
#       5         docid = row['docid']
#
# NameError: name 'people' is not defined
