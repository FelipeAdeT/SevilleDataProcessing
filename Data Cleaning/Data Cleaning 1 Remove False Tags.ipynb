# %% [markdown]
# # Data Cleaning 1. Removing False Matches (Person Tags)
#
# Data cleaning will comprise of three phases:
# 1. Removing false matches (tags that do not refer to an entity at all)
# 1. Correcting miscategorized labels (tags that misinterpret the entity category, ex. assign "PER" to a location)
# 1. Correcting truncated or extended spans (tags which are correct but whose extent is wrong, incorporating irrelevant tokens or ignoring relevant ones).
# 1. Identifying untagged entities
#
# Perfect tagging might be impossible, but we can improve model results significantly by taking these measures.
# This is an iterative process that will improve results as we go through the phases.
#
# ## Strategy 1. Capitalized names
#     Duncan Kinkead capitalized all artist names in his documents, so any tags that have picked up capitalized strings are true names.
#     Any strings that are the lowercase equivalent of those capitalized names are also person names.
#
# ## Strategy 2 .First and last name lists
#     We have developed a list of first and last names from 1400-1800 from a historical biographical dictionary. Using these, we can accept that any tags that incorporate a token from these lists refer to an actual person.
#
#     Because we do not want to be to broad, we will accept tokens with a first name AND last name token that correspond to a word in the list.
#     Strings that do not include both a first name and a last name will have to be manually checked, which includes strings that have only one token.
#
# ## Strategy 3.  Fuzzy Matching
#
# ## Strategy 4 Visual check of remaining person tags in CSV
#
# ## Strategy 5 Visual check of remaining tags against documents
#
# Visual check of remaining person tags
#     If strategies 1 and 2 discard enough PER tags, check the other ones manually.
#
# ## Strategy 4. Removing literary and religious references
#     Some documents refer to ahistorical persons. This is especially important because the names of certain locations and associations take the names of Saints and other religious figures. (move this to "correcting miscategorized labels")

# %%
import pandas as pd
import re
import string

# %%
tagsDF = pd.read_csv('../Text Mining (NER)/EntitiesEMSModel2.csv')

# %%
tagsDF.head()
# Out:
#    Unnamed: 0  docid                 string label  start  end
# 0           0      1       martin de gaynça   PER      1    4
# 1           1      1          santa iglesia   ORG     13   15
# 2           2      1                Sevilla   LOC     16   17
# 3           3      1  juan sanchez de caliz   PER     18   22
# 4           4      1                sevilla   LOC     34   35

# %%
tagsDF.groupby('label').count()
# Out:
#        Unnamed: 0  docid  string  start    end
# label
# DATE         6001   6001    6001   6001   6001
# LOC         16578  16578   16578  16578  16578
# MON         10365  10365   10365  10365  10365
# ORG          5778   5778    5778   5778   5778
# PER         33120  33120   33120  33120  33120

# %% [markdown]
# # 1. Create a list of PER tags with IDS
#
# We are creating a list of person tags with their unique ids. We remove stop words, excess whitespace and punctuation to reduce variation between strings.

# %%
# Test: PER tags
a = tagsDF.loc[tagsDF["label"] == "PER"] #select PER tags
b = a.sort_values('string') #sort alphabetically
#b['string'] = b['string'].str.lower()  #lowercase all strings

# %% [markdown]
# More data cleaning: removing punctuation and accents

# %%
people=b

people.head()
# Out:
#        Unnamed: 0  docid             string label  start  end
# 57935       57935   6792                """   PER    135  138
# 45285       45285   4978        - Rodríguez   PER      6    8
# 45173       45173   4961  -- Gómez de Brito   PER     34   38
# 45108       45108   4952        -- Manrique   PER     11   13
# 61780       61780   7342         -- Ramírez   PER     29   31

# %% [markdown]
# # 2 Clean strings to remove stopwords and accents

# %%
remove = string.punctuation
remove = remove.replace("-", "")

# %%
def clean_iter (line):
    result = re.sub(' del ', ' ', line) #remove stopwords
    result = re.sub(' de ',' ',result)
    result = re.sub(' la ',' ',result)
    
    #result = re.sub(\s\s, \s, result) #remove extra spaces
    
    result= re.sub('á','a',result) #remove accents
    result= re.sub('é','e',result)
    result= re.sub('í','i',result)
    result= re.sub('ó','o',result)
    result= re.sub('ú','u',result)
    result= re.sub('ü','u',result)
    result= re.sub('à','a',result)
    result= re.sub('è','e',result)
    result= re.sub('ì','i',result)
    result= re.sub('ò','o',result)
    result= re.sub('ù','u',result)
    result= re.sub('Á','A',result)
    result= re.sub('É','E',result)
    result= re.sub('Í','I',result)
    result= re.sub('Ó','O',result)
    result= re.sub('Ú','U',result)
    result= re.sub('Ü','U',result)
    result= re.sub('À','A',result)
    result= re.sub('È','E',result)
    result= re.sub('Ì','I',result)
    result= re.sub('Ò','O',result)
    result= re.sub('Ù','U',result)
    result= result.strip()
    
    #result = result.translate(str.maketrans('', '', string.punctuation)) #remove punctuation
    table = str.maketrans('', '', remove)
    result = result.translate(table)
    
    return result
    
clean_series=[]

for index, row in people.iterrows():
    clean_series.append(clean_iter(row['string']))
people['string']= clean_series

# %%
people.head()
# Out:
#        Unnamed: 0  docid          string label  start  end
# 57935       57935   6792                   PER    135  138
# 45285       45285   4978     - Rodriguez   PER      6    8
# 45173       45173   4961  -- Gomez Brito   PER     34   38
# 45108       45108   4952     -- Manrique   PER     11   13
# 61780       61780   7342      -- Ramirez   PER     29   31

# %% [markdown]
# # 3 Create an attribute for checking process called 'Remove'

# %% [markdown]
# Then we insert a column for a dummy variable for "remove" or "keep". We will use this to mark the false tags that have to be removed with a 1. Tags that should be kept will have a 0 value. Blank values must be double-checked manually before being assigned a 0 or 1.

# %%
people.insert(6,"Remove","")

# %%
people.head()
# Out:
#        Unnamed: 0  docid          string label  start  end Remove
# 57935       57935   6792                   PER    135  138
# 45285       45285   4978     - Rodriguez   PER      6    8
# 45173       45173   4961  -- Gomez Brito   PER     34   38
# 45108       45108   4952     -- Manrique   PER     11   13
# 61780       61780   7342      -- Ramirez   PER     29   31

# %% [markdown]
# Then we create a list of unique person tags.

# %%
uniquepers = people['string'].value_counts(sort=True)
uniquepers
# Out:
# juan martinez montañes    354
# ALONSO PEREZ              268
# andres ocanpo             206
# JUAN DE VALDES            191
# juan obiedo               191
#                          ...
# Catalina Maria              1
# Joseph Martinez             1
# Gutierrez Machuca           1
# baltasar becerra            1
# diego hurtado               1
# Name: string, Length: 14517, dtype: int64

# %% [markdown]
# There are 14517 unique strings.

# %% [markdown]
# # Strategy 1. Mark all Capitalized words and their lowecase equivalents as true names
#
# Kinkead set all artist (painter, architect, goldbeater, gilder, etc) names in All-Caps. We can identify these strings and their lowercase equivalents as true names.

# %%
perscaps = people.loc[people['string'].str.isupper()==True]
perscaps.head()
# Out:
#        Unnamed: 0  docid            string label  start  end Remove
# 66787       66787   8056    AGUSTIN FRANCO   PER      7    9
# 71698       71698   8579  AGUSTIN DE PEREA   PER    101  104
# 45413       45413   4999  AGUSTIN DE PEREA   PER     16   19
# 45421       45421   5000  AGUSTIN DE PEREA   PER     49   52
# 45397       45397   4997  AGUSTIN DE PEREA   PER     26   29

# %% [markdown]
# We can get an idea of what these strings are with a unique list.

# %%
uniqueperscaps = perscaps['string'].value_counts(sort=True)
uniqueperscaps
# Out:
# ALONSO PEREZ           268
# JUAN DE VALDES         191
# BARTOLOME MURILLO      176
# CARLOS DE ZARATE       166
# MATIAS DE ARTEAGA      119
#                       ...
# JOAN DE ARRENAS          1
# JUHAN MOL                1
# DIEGO DE LAS CASAS       1
# PEDRO DE OSORIO          1
# FRANCISCO DE BARONA      1
# Name: string, Length: 892, dtype: int64

# %%
UPCapslist = list(uniqueperscaps.index.values)

# %% [markdown]
# Using this list of unique capitalized strings, we can set Remove='0' for any strings that match an uppercase name.

# %%
for ind in people.index:
    if people.loc[ind,'string'] in UPCapslist:
        people.loc[ind,'Remove']=0

# %%
grouped = people.groupby('Remove')

grouped.count()
# Out:
#         Unnamed: 0  docid  string  label  start    end
# Remove
#              27101  27101   27101  27101  27101  27101
# 0             6019   6019    6019   6019   6019   6019

# %% [markdown]
# This process has marked 6019 instances of a true name, which should be equivalent to the artists found in Kinkead's Pintores y Doradores en Sevilla.
#
# Now we mark any lowercase strings equivalent to the uppercase tags we know are correct as 0 as well:

# %%
for ind in people.index:
    if people.loc[ind,'string'].upper() in UPCapslist:
        people.loc[ind,'Remove']=0

# %%
grouped = people.groupby('Remove')
grouped.count()
# Out:
#         Unnamed: 0  docid  string  label  start    end
# Remove
# 0             7065   7065    7065   7065   7065   7065
#              26055  26055   26055  26055  26055  26055

# %% [markdown]
# Below is a shorter way of achieving the same goal:

# %%
perscaps = people['string'][people['string'].str.isupper()==True].unique().tolist()

# %%
people.loc[people['string'].str.upper().isin(perscaps),'Remove'] = 0

# %% [markdown]
# These approaches have identified a total 7065 tags as acceptable. That is, an additional 1046 tags corresponded to the same artists found in Kinkead.
#
# (Note: we will need to remove any documents that appear in Kinkead and other sources. This should be easy because Kinkead gives references as to where texts were published.)

# %% [markdown]
# # Strategy 2. Name Dictionary

# %% [markdown]
# In another notebook, we web scraped and cleaned the contents of the Spanish Royal History Academy's Spanish Biographical Dictionary (for persons born between 1400-1800). The process resulted in a list of first names and last names, which we revised to remove some problematic tokens (articles that would have picked up too many matches, as well as some words that appear often outside of naming).
#
# Let's load these in the notebook:

# %%
firstnames = open('DBE_Names/firstnames.txt','r')
lastnames = open('DBE_Names/lastnames.txt','r')

# %%
fnames = []
fnames = [line.rstrip('\n') for line in open('firstnames.txt')]

# %%
lnames = []
lnames = [line.rstrip('\n') for line in open('lastnames.txt')]

# %%
fnames
# Out:
# ['abd',
#  'abdo',
#  'aben',
#  'abraham',
#  'abu',
#  'abul',
#  'acisclo',
#  'adamo',
#  'adan',
#  'adaucto',
#  'adria',
#  'adriaen',
#  'adrian',
#  'adriano',
#  'adrien',
#  'advincula',
#  'afan',
#  'afonso',
#  'agapito',
#  'agesilao',
#  'agostinho',
#  'agostino',
#  'agusti',
#  'agustin',
#  'agustina',
#  'ahmad',
#  'ahuitzotl',
#  'aime-jacques',
#  'al-basti',
#  'al-garnati',
#  'al-hayari',
#  'al-malik',
#  'al-manzari',
#  'al-qalasadi',
#  'al-titwani',
#  'alal',
#  'alberico',
#  'albert-octave',
#  'alberti',
#  'alberto',
#  'albino',
#  'albret',
#  'alcantara',
#  'alcocer',
#  'aldonza',
#  'aleix',
#  'aleixo',
#  'alejandrino',
#  'alejandro',
#  'alejo',
#  'alemania',
#  'alessandro',
#  'alex',
#  'alexander',
#  'alexandre',
#  'alexo',
#  'alexos',
#  'alfonso',
#  'ali',
#  'almanzor',
#  'almidez',
#  'alonso',
#  'alvar',
#  'alvarado',
#  'alvaro',
#  'amadeo',
#  'amador',
#  'amalia',
#  'amancio',
#  'amaneo',
#  'amaru',
#  'ambrosia',
#  'ambrosio',
#  'amelia',
#  'amerigo',
#  'amparo',
#  'ana',
#  'anacaona',
#  'anacleto',
#  'anastasio',
#  'andre',
#  'andrea',
#  'andres',
#  'andresa',
#  'andreu',
#  'anello',
#  'angel',
#  'angela',
#  'angeles',
#  'angelina',
#  'angelino',
#  'angelo',
#  'angulema',
#  'anibal',
#  'aniceto',
#  'aniello',
#  'anielo',
#  'anna',
#  'annibale',
#  'anselmo',
#  'antera',
#  'anthoine',
#  'anthonius',
#  'anthony',
#  'antich',
#  'antoine',
#  'antolin',
#  'anton',
#  'antoni',
#  'antonia',
#  'antonieta',
#  'antonino',
#  'antonio',
#  'anunciacion',
#  'apolinar',
#  'apostol',
#  'apostoles',
#  'aragon',
#  'arborio',
#  'arcangel',
#  'arevalo',
#  'arias',
#  'armando',
#  'arnaldo',
#  'arnao',
#  'arnau',
#  'arnoldo',
#  'arnould',
#  'arroyuelo',
#  'artal',
#  'arthur',
#  'arturo',
#  'ascanio',
#  'ascencio',
#  'ascension',
#  'asensio',
#  'asuncion',
#  'atanasio',
#  'atau',
#  'atilano',
#  'atlacatl',
#  'augusto',
#  'aurele',
#  'aureliano',
#  'aurelio',
#  'ausias',
#  'austria',
#  'avelino',
#  'aymamon',
#  'babil',
#  'bacio',
#  'baldassare',
#  'baldiri',
#  'baldomero',
#  'baleriano',
#  'baltasar',
#  'baltasara',
#  'baltazar',
#  'baptista',
#  'baptiste',
#  'barbara',
#  'barros',
#  'bartolina',
#  'bartolome',
#  'bartolomeo',
#  'bartolomeu',
#  'bartomeu',
#  'basilio',
#  'batistta',
#  'battista',
#  'baustista',
#  'bautista',
#  'beata',
#  'beato',
#  'beatriz',
#  'beda',
#  'behechio',
#  'belchior',
#  'beltran',
#  'benedetto',
#  'benedicto',
#  'benedito',
#  'benet',
#  'benicio',
#  'benigno',
#  'benita',
#  'benito',
#  'benjamin',
#  'bento',
#  'bentura',
#  'berengario',
#  'berenguel',
#  'berenguer',
#  'bernabe',
#  'bernal',
#  'bernard',
#  'bernarda',
#  'bernardina',
#  'bernardino',
#  'bernardo',
#  'bernat',
#  'bezon',
#  'bibiana',
#  'biriteca',
#  'blai',
#  'blanca',
#  'blas',
#  'blasco',
#  'boix',
#  'bonaparte',
#  'bonaventura',
#  'bonaventure',
#  'bonifacio',
#  'borbon',
#  'borbon-orleans',
#  'borges',
#  'borja',
#  'boudoin',
#  'braganza',
#  'brahem',
#  'brauli',
#  'braulio',
#  'brianda',
#  'bruno',
#  'brunswick-wolfenbuttel',
#  'buenaventura',
#  'buenventura',
#  'cacamatzin',
#  'calcuchimac',
#  'caldeira',
#  'calixto',
#  'camaquiri',
#  'camilo',
#  'candelaria',
#  'candido',
#  'canek',
#  'caonabo',
#  'capac',
#  'careta',
#  'carles',
#  'carlo',
#  'carlos',
#  'carlota',
#  'carmela',
#  'carmen',
#  'carmine',
#  'carolina',
#  'casiano',
#  'casilda',
#  'casildo',
#  'casimiro',
#  'casiodoro',
#  'casta',
#  'castilla',
#  'casto',
#  'catalina',
#  'caunaboa',
#  'caupolican',
#  'cayacoa',
#  'cayetana',
#  'cayetano',
#  'caynos',
#  'cayo',
#  'cebrian',
#  'cecilia',
#  'cecilio',
#  'ceferina',
#  'ceferino',
#  'celedonio',
#  'celestino',
#  'cesar',
#  'cesare',
#  'cesareo',
#  'charles',
#  'charles-alexandre',
#  'charles-marie',
#  'chi',
#  'christian',
#  'cid',
#  'cipriano',
#  'ciriaco',
#  'cirilo',
#  'ciro',
#  'clara',
#  'claros',
#  'claude',
#  'claude-francois',
#  'claudi',
#  'claudio',
#  'clemencia',
#  'clemente',
#  'clementina',
#  'cleto',
#  'climaco',
#  'coaza',
#  'cobos',
#  'cocori',
#  'colcur',
#  'colicheuque',
#  'colocolo',
#  'concepcion',
#  'conrado',
#  'consolacion',
#  'constantin',
#  'constantino',
#  'constanza',
#  'corella',
#  'cornelio',
#  'cornieles',
#  'corpus',
#  'corrado',
#  'correia',
#  'corrohore',
#  'cosme',
#  'cotubanama',
#  'crisogono',
#  'crisostom',
#  'crisostomo',
#  'crispin',
#  'cristian',
#  'cristiano',
#  'cristina',
#  'cristo',
#  'cristobal',
#  'cristobalina',
#  'cristofol',
#  'cristophe',
#  'cristovao',
#  'cuauhtemoc',
#  'curi',
#  'cusi',
#  'custodio',
#  'dalmau',
#  'damasa',
#  'damasio',
#  'damaso',
#  'damia',
#  'damian',
#  'danese',
#  'daniel',
#  'dario',
#  'das',
#  'daud',
#  'david',
#  'davide',
#  'demetrio',
#  'deogracias',
#  'dermot',
#  'diego',
#  'dimas',
#  'diogo',
#  'dionisia',
#  'dionisio',
#  'dobele',
#  'dolores',
#  'domenec',
#  'domenico',
#  'domenicos',
#  'dominga',
#  'domingo',
#  'dominico',
#  'dominque',
#  'donato',
#  'donoso',
#  'doroteo',
#  'duarte',
#  'dulcehe',
#  'duplicio',
#  'edmundo',
#  'eduardo',
#  'efraim',
#  'egas',
#  'egidio',
#  'eladio',
#  'elena',
#  'eleno',
#  'eleuterio',
#  'elias',
#  'elio',
#  'eliodoro',
#  'elionor',
#  'eliseo',
#  'elisio',
#  'eloy',
#  'elvira',
#  'emanuele',
#  'emeterio',
#  'emigdio',
#  'emmanuel',
#  'encarnacion',
#  'engracia',
#  'enrique',
#  'enriquez',
#  'enriquillo',
#  'enyego',
#  'epifanio',
#  'erardo',
#  'erasmo',
#  'ernesto',
#  'escolastica',
#  'escolastico',
#  'esperandeu',
#  'esperanza',
#  'espiritu',
#  'estanislao',
#  'esteban',
#  'estefania',
#  'estevao',
#  'esteve',
#  'estuardo',
#  'etienne',
#  'ettore',
#  'eudald',
#  'eudaldo',
#  'eufrasia',
#  'eufrasio',
#  'eugenia',
#  'eugenio',
#  'eulalia',
#  'eulalio',
#  'eulogio',
#  'eusebio',
#  'eustaquio',
#  'evangelista',
#  'evaristo',
#  'everardo',
#  'eximen',
#  'ezequiel',
#  'fabian',
#  'fabiana',
#  'fabio',
#  'fabricio',
#  'fabrizio',
#  'facundo',
#  'fadrique',
#  'farag',
#  'farnesio',
#  'faustino',
#  'fausto',
#  'febos',
#  'federico',
#  'felice',
#  'feliciana',
#  'feliciano',
#  'felicio',
#  'felicitas',
#  'felip',
#  'felipa',
#  'felipe',
#  'felipillo',
#  'felipina',
#  'felix',
#  'fermin',
#  'fernan',
#  'fernanda',
#  'fernando',
#  'fernao',
#  'ferran',
#  'ferrando',
#  'ferrante',
#  'ferrer',
#  'ferry',
#  'fidalgo',
#  'fidel',
#  'fidencio',
#  'filiberto',
#  'filipe',
#  'filippo',
#  'fitzgerald',
#  'flavia',
#  'florence',
#  'florencio',
#  'florent',
#  'florentino',
#  'florian',
#  'floris',
#  'floristan',
#  'foix',
#  'fortun',
#  'frances',
#  'francesc',
#  'francesch',
#  'francesco',
#  'francia',
#  'francico',
#  'francisca',
#  'francisco',
#  'franscisco',
#  'françois',
#  'fray',
#  'froilan',
#  'fructuoso',
#  'frutos',
#  'fulgencio',
#  'fulvio',
#  'furtado',
#  'gabino',
#  'gabriel',
#  'gabriela',
#  'gabriele',
#  'galacian',
#  'galcera',
#  'galceran',
#  'galeazzo',
#  'garabito',
#  'garci',
#  'garcia',
#  'garcilaso',
#  'gaspar',
#  'gaspard',
#  'gaspare',
#  'gaston',
#  'gaudioso',
#  'gavino',
#  'gedeon',
#  'genaro',
#  'gentil',
#  'georg',
#  'george',
#  'gerard',
#  'gerardo',
#  'gerhard',
#  'german',
#  'germana',
#  'gerolamo',
#  'geroni',
#  'geronima',
#  'geronimo',
#  'gertrudis',
#  'gervasio',
#  'giacomo',
#  'giampaolo',
#  'gian',
#  'gil',
#  'gilles',
#  'ginebra',
#  'gines',
#  'giocacchino',
#  'giorgio',
#  'giovan',
#  'giovani',
#  'giovanni',
#  'giraldo',
#  'giralte',
#  'girolamo',
#  'gispert',
#  'giuliano',
#  'giulio',
#  'giuseppe',
#  'giusseppangelo',
#  'godfredo',
#  'gomes',
#  'gomez',
#  'gonzalo',
#  'gonçalo',
#  'gotardo',
#  'goujaud',
#  'gracian',
#  'graciliano',
#  'gregori',
#  'gregoria',
#  'gregorio',
#  'grimanesa',
#  'guacanagari',
#  'guadalupe',
#  'gualberto',
#  'guama',
#  'guantanabo',
#  'guarambare',
#  'guarco',
#  'guarionex',
#  'guerau',
#  'guido',
#  'guidobaldo',
#  'guillaume',
#  'guillaume-albert',
#  'guillem',
#  'guillen',
#  'guillermo',
#  'guiomar',
#  'guiot',
#  'gustaf',
#  'gutierre',
#  'guyravera',
#  'guzman',
#  'habsburgo',
#  'hamet',
#  'hamete',
#  'hans',
#  'hasekura',
#  'hatuey',
#  'hector',
#  'heinrich',
#  'heitor',
#  'hendrick',
#  'henri',
#  'henrique',
#  'henriquo',
#  'hermenegildo',
#  'hernan',
#  'hernandillo',
#  'hernando',
#  'hiacynthe-marie',
#  'hilario',
#  'hilarion',
#  'hipolita',
#  'hipolito',
#  'hojeda',
#  'honorato',
#  'honorio',
#  'horacio',
#  'hortensio',
#  'hortun',
#  'hoyer',
#  'huallpa',
#  'huascar',
#  'huaylas',
#  'huayna',
#  'hubert-guillaume',
#  'huberto',
#  'hug',
#  'hugh',
#  'hugo',
#  'hungria',
#  'hurtado',
#  'ibando',
#  'ibn',
#  'ibrahim',
#  'idelfonso',
#  'ignacia',
#  'ignacio',
#  'ignasi',
#  'ildefonso',
#  'illa',
#  'illan',
#  'imox',
#  'inca',
#  'indalecio',
#  'ines',
#  'inga',
#  'inocencio',
#  'ioannis',
#  'irene',
#  'isaac',
#  'isabel',
#  'isabella',
#  'isidoro',
#  'isidra',
#  'isidro',
#  'iñigo',
#  'jacint',
#  'jacinta',
#  'jacinto',
#  'jacob',
#  'jacoba',
#  'jacobe',
#  'jacobo',
#  'jacome',
#  'jacopo',
#  'jacques',
#  'jacques-françois',
#  'jaime',
#  'james',
#  'jan',
#  'januario',
#  'jaume',
#  'javier',
#  'javiera',
#  'jean',
#  'jean-armand',
#  'jean-baptiste',
#  'jean-charles',
#  'jean-marie',
#  'jehan',
#  'jeroni',
#  'jeronima',
#  'jeronimo',
#  'jesus',
#  'jesusa',
#  'joachim',
#  'joan',
#  'joanes',
#  'joannes',
#  'joanot',
#  'joao',
#  'joaquim',
#  'joaquin',
#  'joaquina',
#  'jodoco',
#  'jofre',
#  'johann',
#  'johannes',
#  'john',
#  'jordan',
#  'jordi',
#  'jorge',
#  'joris',
#  'jose',
#  'jose-anselmo',
#  'jose-armesto',
#  'josef',
#  'josefa',
#  'josefina',
#  'josep',
#  'josep-miquel',
#  'joseph',
#  'josse',
#  'juan',
#  'juana',
#  'juancho',
#  'juanes',
#  'juanoto',
#  'judas',
#  'julia',
#  'julian',
#  'juliana',
#  'julio',
#  'jusepa',
#  'jusepe',
#  'justa',
#  'juste',
#  'justiniano',
#  'justino',
#  'justo',
#  'justus',
#  'kahi',
#  'l-hasan',
#  'ladislao',
#  'lambare',
#  'lamberto',
#  'lamoral',
#  'laszlo',
#  'laura',
#  'laureano',
#  'laurencio',
#  'laurent',
#  'lautaro',
#  'lazaro',
#  'leandro',
#  'legallois',
#  'lelio',
#  'leon',
#  'leona',
#  'leonardo',
#  'leoncio',
#  'leone',
#  'leonel',
#  'leonis',
#  'leonor',
#  'leopolda',
#  'leopoldo',
#  'lesmes',
#  'liberata',
#  'liborio',
#  'licenciado',
#  'liciniano',
#  'liropeya',
#  'lisandro',
#  'livinio',
#  'llorenç',
#  'lluis',
#  'lodovico',
#  'longinos',
#  'lope',
#  'lopez',
#  'lorenza',
#  'lorenzo',
#  'loreto',
#  'louis',
#  'louis-antoine',
#  'louis-michel',
#  'lourenço',
#  'luca',
#  'lucas',
#  'lucena',
#  'lucia',
#  'luciana',
#  'luciano',
#  'lucio',
#  'lucrecia',
#  'ludovica',
#  'ludwig',
#  'luigi',
#  'luis',
#  'luisa',
#  'luke',
#  'lupercio',
#  'macario',
#  'macia',
#  'macias',
#  'maciel',
#  'madux',
#  'maduz',
#  'maestre',
#  'maestro',
#  'maffeo',
#  'magdalena',
#  'magin',
#  'mahoma',
#  'malaquias',
#  'mamerto',
#  'mames',
#  'mancebo',
#  'mancio',
#  'manco',
#  'manel',
#  'manrique',
#  'manuel',
#  'manuela',
#  'marcela',
#  'marcelino',
#  'marcelo',
#  'marcial',
#  'marciano',
#  'marco',
#  'marcos',
#  'margarita',
#  'marguerite',
#  'maria',
#  'mariana',
#  'mariangelo',
#  'mariano',
#  'marie',
#  'marie-anne',
#  'marin',
#  'marina',
#  'marino',
#  'mario',
#  'marsilio',
#  'marta',
#  'marti',
#  'martim',
#  'martin',
#  'martina',
#  'martinez',
#  'martiniano',
#  'martinillo',
#  'martir',
#  'mata',
#  'mateo',
#  'mateu',
#  'mateus',
#  'matheo',
#  'matias',
#  'mauri',
#  'mauricia',
#  'mauricio',
#  'mauro',
#  'mawlay',
#  'maximiliana',
#  'maximiliano',
#  'maximilien',
#  'maximo',
#  'maymon',
#  'melchior',
#  'melchor',
#  'melquiades',
#  'mencia',
#  'mendo',
#  'mequenum',
#  'mercedes',
#  'mercurino',
#  'mercurio',
#  'merin',
#  'mestre',
#  'micael',
#  'micaela',
#  'michael',
#  'michel',
#  'michel-jean',
#  'michele',
#  'michimalongo',
#  'miguel',
#  'millan',
#  'miquel',
#  'moctezuma',
#  'modesto',
#  'moises',
#  'monserrat',
#  'morejon',
#  'mucio',
#  'muddin',
#  'muhamad',
#  'muhammad',
#  'muley',
#  'muzio',
#  'nadal',
#  'narcis',
#  'narciso',
#  'natuera',
#  'naucopillan',
#  'navarra',
#  'nazario',
#  'nemesio',
#  'neoburgo',
#  'nepomuceno',
#  'nicanor',
#  'nicasio',
#  'niccolo',
#  'niceto',
#  'nicolas',
#  'nicolasa',
#  'nicolau',
#  'nicolaus',
#  'nicolosio',
#  'niculoso',
#  'nieves',
#  'niza',
#  'nizzola',
#  'nolasco',
#  'norberto',
#  'nuflo',
#  'num',
#  'nuno',
#  'nuñez',
#  'nuño',
#  'obera',
#  'obregon',
#  'ocllo',
#  'octaviano',
#  'octavio',
#  'olegario',
#  'oleguer',
#  'oliva',
#  'oliverio',
#  'ometochtzin',
#  'onesimo',
#  'onofre',
#  'onorato',
#  'opechancanough',
#  'orazio',
#  'ordoño',
#  'orleans',
#  'ortega',
#  'ortuño',
#  'osvaldo',
#  'oton',
#  'ottavio',
#  'ottone',
#  'pablillo',
#  'pablo',
#  'pablos',
#  'pacifico',
#  'padua',
#  'panfilo',
#  'pantaleon',
#  'paolo',
#  'parma',
#  'pascacio',
#  'pascasio',
#  'pascual',
#  'pascuala',
#  'pasqual',
#  'pastor',
#  'patricio',
#  'pau',
#  'paul',
#  'paula',
#  'paulino',
#  'paullu',
#  'paulo',
#  'payo',
#  'pecador',
#  'pedralvares',
#  'pedrarias',
#  'pedro',
#  'pedro-luis',
#  'pedrosa',
#  'pedroso',
#  'pehr',
#  'pelai',
#  'pelayo',
#  'pellegrino',
#  'penne',
#  'per',
#  'pere',
#  'pere-joan',
#  'peregrinus',
#  'pereira',
#  'perez',
#  'perfecto',
#  'pero',
#  'perot',
#  'peter',
#  'petrona',
#  'petronila',
#  'phelipe',
#  'philibert',
#  'philipp',
#  'philippe',
#  'piedad',
#  'pierre',
#  'pierre-ernest',
#  'pierres',
#  'pietro',
#  'pilar',
#  'pinheiro',
#  'pio',
#  'placido',
#  'poechos',
#  ...]

# %%
lnames
# Out:
# ['olim',
#  'alava',
#  'ab-ach',
#  'abad',
#  'abadal',
#  'abadia',
#  'abadiano',
#  'abadie',
#  'abadin',
#  'abarca',
#  'abaria',
#  'abarrategui',
#  'abascal',
#  'abasolo',
#  'abastas',
#  'abat',
#  'abbeville',
#  'abd',
#  'abduladin',
#  'abel',
#  'abella',
#  'abellan',
#  'abello',
#  'aben',
#  'abenaxara',
#  'abengoechea',
#  'abiancos',
#  'abianelo',
#  'ablanque',
#  'ablitas',
#  'aboab',
#  'abollado',
#  'aborim',
#  'abraha',
#  'abraham',
#  'abranches',
#  'abravanel',
#  'abreu',
#  'abrich',
#  'abu',
#  'abuin',
#  'aburruza',
#  'acacio',
#  'acassuso',
#  'accursio',
#  'acebal',
#  'acebedo',
#  'acebes',
#  'acebo',
#  'acedo',
#  'aceites',
#  'acero',
#  'acevedo',
#  'acha',
#  'achutegui',
#  'acitores',
#  'acorbe',
#  'acorda',
#  'acosta',
#  'acquaviva',
#  'acuña',
#  'adalid',
#  'adam',
#  'adame',
#  'adan',
#  'adaro',
#  'adarzo',
#  'adell',
#  'adeva',
#  'adrada',
#  'adrian',
#  'adriano',
#  'adsor',
#  'aduart',
#  'aduarte',
#  'adurza',
#  'aedo',
#  'aerts',
#  'afan',
#  'afferden',
#  'afonso',
#  'aganduru',
#  'agar',
#  'agnesio',
#  'agoiz',
#  'agramont',
#  'agramonte',
#  'agraz',
#  'agreda',
#  'agrelo',
#  'aguado',
#  'agualongo',
#  'aguar',
#  'aguas',
#  'aguayo',
#  'aguazil',
#  'agud',
#  'agudo',
#  'aguera',
#  'aguero',
#  'agueros',
#  'aguerre',
#  'aguerri',
#  'aguesca',
#  'aguiar',
#  'aguila',
#  'aguilar',
#  'aguilera',
#  'aguilo',
#  'aguilon',
#  'aguinaga',
#  'aguiriano',
#  'aguirre',
#  'aguirre-solarte',
#  'aguirrebengoa',
#  'agullana',
#  'agullo',
#  'agullona',
#  'agurto',
#  'agusti',
#  'agustin',
#  'aheran',
#  'ahmad',
#  'ahuitzot',
#  'ahumada',
#  'aibar',
#  'aichelberg',
#  'aingo',
#  'ainsa',
#  'aizkibel',
#  'aizpiri',
#  'aizpitarte',
#  'aizpuru',
#  'aizpurua',
#  'ajuria',
#  'al-bast',
#  'al-garnati',
#  'al-hayari',
#  'al-malik',
#  'al-manzari',
#  'al-mawsili',
#  'al-qalasad',
#  'al-titwan',
#  'alaba',
#  'alafont',
#  'alagon',
#  'alaix',
#  'alaja',
#  'alal',
#  'alaman',
#  'alamanzon',
#  'alameda',
#  'alamin',
#  'alaminos',
#  'alamo',
#  'alamos',
#  'alanis',
#  'alanya',
#  'alapont',
#  'alarcon',
#  'alarcos',
#  'alas',
#  'alava',
#  'alavall',
#  'alba',
#  'albacar',
#  'albanell',
#  'albano',
#  'albarellos',
#  'albariño',
#  'albarracin',
#  'albaspi',
#  'albear',
#  'albelda',
#  'albelo',
#  'albendea',
#  'albeniz',
#  'alberch',
#  'alberdi',
#  'albergotti',
#  'albernas',
#  'alberni',
#  'alberoni',
#  'alberro',
#  'albert',
#  'alberti',
#  'albertino',
#  'alberto',
#  'albertos',
#  'albin',
#  'albis',
#  'albistur',
#  'albites',
#  'albiturria',
#  'albiz',
#  'albizu',
#  'albiñana',
#  'albo',
#  'albor',
#  'albornoz',
#  'albors',
#  'alborxe',
#  'albotodo',
#  'alboy',
#  'albre',
#  'albuerne',
#  'albujar',
#  'albuquerque',
#  'alburquerque',
#  'alcala-galiano',
#  'alcala-zamora',
#  'alcanyis',
#  'alcaraz',
#  'alcarria',
#  'alcastiel',
#  'alcaya',
#  'alcayde',
#  'alcayna',
#  'alcayne',
#  'alcazar',
#  'alcañiz',
#  'alcedo',
#  'alcega',
#  'alcoba',
#  'alcobendas',
#  'alcocer',
#  'alcoholado',
#  'alcon',
#  'alconchel',
#  'alcoriza',
#  'alcover',
#  'alcoverro',
#  'alcubierre',
#  'alda',
#  'aldama',
#  'aldana',
#  'aldao',
#  'aldas',
#  'aldasoro',
#  'aldave',
#  'alday',
#  'aldaz',
#  'aldazabal',
#  'aldecoa',
#  'aldehuela',
#  'alderete',
#  'aldovera',
#  'aldrete',
#  'aldunate',
#  'alduncin',
#  'aledo',
#  'alejandre',
#  'alejandro',
#  'alejos',
#  'aleman',
#  'alemani',
#  'alemanni',
#  'alemans',
#  'alemany',
#  'alemcastre',
#  'alencastre',
#  'alentorn',
#  'alençon',
#  'alepuz',
#  'alesio',
#  'aleson',
#  'alfaro',
#  'alfeiran',
#  'alferio',
#  'alfinger',
#  'alfonsin',
#  'alfonso',
#  'alfonso-pimentel',
#  'alfonso-villagomez',
#  'alfranca',
#  'algarin',
#  'ali',
#  'aliaga',
#  'aliguer',
#  'alix',
#  'allende',
#  'allende-salazar',
#  'allendesalazar',
#  'alli',
#  'alloitiz',
#  'allonville',
#  'alloytiz',
#  'allue',
#  'almagro',
#  'almandoz',
#  'almansa',
#  'almanza',
#  'almanzor',
#  'almaraz',
#  'almarza',
#  'almazan',
#  'almazor',
#  'almazul',
#  'almedina',
#  'almeida',
#  'almela',
#  'almella',
#  'almenar',
#  'almenara',
#  'almendras',
#  'almesto',
#  'almeyda',
#  'almira',
#  'almodovar',
#  'almogaver',
#  'almoguera',
#  'almonacid',
#  'almonaster',
#  'almugaber',
#  'alomar',
#  'alonso',
#  'alos',
#  'aloy',
#  'alpin',
#  'alpizcueta',
#  'alpont',
#  'alpuche',
#  'alpuente',
#  'alquiza',
#  'alquizar',
#  'alsedo',
#  'alsina',
#  'alsinet',
#  'alta',
#  'altafulla',
#  'altamir',
#  'altamira',
#  'altamirano',
#  'altarriba',
#  'altarriva',
#  'altemiz',
#  'altoaguirre',
#  'altolaguirre',
#  'altue',
#  'altuna',
#  'alva',
#  'alvarado',
#  'alvarado-bracamonte',
#  'alvaredo',
#  'alvarenga',
#  'alvares',
#  'alvarez',
#  'alvarnaez',
#  'alvaro',
#  'alvarrachi',
#  'alvear',
#  'alvia',
#  'alviz',
#  'alvizu',
#  'alzaga',
#  'alzaibar',
#  'alzamora',
#  'alzate',
#  'alzaybar',
#  'alzedo',
#  'alzina',
#  'alzola',
#  'alzua',
#  'amadeo',
#  'amado',
#  'amador',
#  'amalia',
#  'amar',
#  'amargos',
#  'amarilla',
#  'amarita',
#  'amasa',
#  'amat',
#  'amate',
#  'amato',
#  'amatriain',
#  'amaya',
#  'amberes',
#  'ambiela',
#  'ambros',
#  'ambulodi',
#  'ameijeiras',
#  'amell',
#  'ameller',
#  'amelot',
#  'amengual',
#  'amescua',
#  'ametller',
#  'amezaga',
#  'amezcua',
#  'amezqueta',
#  'amezquita',
#  'amich',
#  'amici',
#  'amiconi',
#  'amigant',
#  'amigo',
#  'amiguet',
#  'amileta',
#  'amills',
#  'amirola',
#  'amo',
#  'amolaz',
#  'amor',
#  'amorim',
#  'amoros',
#  'amphoux',
#  'ampies',
#  'ampudia',
#  'ampuero',
#  'amuedo',
#  'amunariz',
#  'amusco',
#  'amutio',
#  'ana',
#  'anacaon',
#  'anadon',
#  'anasco',
#  'anastasio',
#  'anaya',
#  'anchia',
#  'anchieta',
#  'anchorena',
#  'ancilla',
#  'ancillo',
#  'anciola',
#  'anda',
#  'andagoya',
#  'andeyro',
#  'andia',
#  'andicano',
#  'andino',
#  'andonaegui',
#  'andosilla',
#  'andraca',
#  'andrada',
#  'andrade',
#  'andrana',
#  'andre',
#  'andrea',
#  'andres',
#  'andreu',
#  'andrevi',
#  'andriani',
#  'anduaga',
#  'andueza',
#  'andujar',
#  'anduza',
#  'anejo',
#  'aner',
#  'angel',
#  'angela',
#  'angele',
#  'angelin',
#  'angera',
#  'anges',
#  'anglasell',
#  'angleria',
#  'angles',
#  'anglesola',
#  'anguciana',
#  'anguiano',
#  'anguissola',
#  'anguita',
#  'angulema',
#  'angulo',
#  'anhetan',
#  'ania',
#  'aniñon',
#  'anjou',
#  'anneux',
#  'anoz',
#  'ansa',
#  'ansalone',
#  'ansay',
#  'anso',
#  'ansotegui',
#  'ansurez',
#  'antelo',
#  'antequera',
#  'antillon',
#  'antist',
#  'antolinez',
#  'anton',
#  'antona',
#  'antonelli',
#  'antoni',
#  'antonia',
#  'antonio',
#  'antunez',
#  'antuña',
#  'antuñano',
#  'anunciacio',
#  'anuncibay',
#  'anvers',
#  'anza',
#  'anzano',
#  'anzoategui',
#  'anzorena',
#  'aoiz',
#  'aozaraza',
#  'apaolaza',
#  'aparici',
#  'aparicio',
#  'apaza',
#  'apeolaza',
#  'aperger',
#  'aperregui',
#  'apezteguia',
#  'apodaca',
#  'apoita',
#  'aponte',
#  'apostole',
#  'aquiles',
#  'aquino',
#  'arabi',
#  'arache',
#  'araciel',
#  'aracil',
#  'aragall',
#  'arago',
#  'aragon',
#  'aragon-moncada',
#  'aragona',
#  'aragones',
#  'aragorri',
#  'aragues',
#  'araiz',
#  'arambari',
#  'arambarri',
#  'aramburu',
#  'arana',
#  'aranalde',
#  'aranaz',
#  'arance',
#  'aranda',
#  'arandia',
#  'arandiga',
#  'arango',
#  'arangoyti',
#  'aranguiz',
#  'aranguren',
#  'aranibar',
#  'arano',
#  'aransay',
#  'aranza',
#  'aranzazu',
#  'araoz',
#  'araque',
#  'aras',
#  'arasqueta',
#  'araucho',
#  'arauco',
#  'araujo',
#  'arauxo',
#  'arauz',
#  'arauza',
#  'aravaca',
#  'aravalles',
#  'arañes',
#  'arañon',
#  'arbaizar',
#  'arbasia',
#  'arbelaiz',
#  'arbeza',
#  'arbieto',
#  'arbiol',
#  'arbizu',
#  'arbolanche',
#  'arboleda',
#  'arboleya',
#  'arboreda',
#  'arbos',
#  'arbues',
#  'arbulo',
#  'arburola',
#  'arbustante',
#  'arbuthnot',
#  'arcaya',
#  'arce',
#  'arceo',
#  'archer',
#  'archidona',
#  'archiga',
#  'arciniega',
#  'arco',
#  'arco-aguero',
#  'arcos',
#  'ardanaz',
#  'ardemans',
#  'ardena',
#  'ardi',
#  'ardid',
#  'ardila',
#  'ardiles',
#  'ardison',
#  'arduino',
#  'areas',
#  'arechaga',
#  'arechavala',
#  'areche',
#  'arechederra',
#  'arechua',
#  'areizaga',
#  'arejula',
#  'arellano',
#  'arenales',
#  'arenas',
#  'arenaza',
#  'arenillas',
#  'arenzana',
#  'arenzano',
#  'ares',
#  'arese',
#  'arespacochaga',
#  'aresti',
#  'areta',
#  'areval',
#  'arevalo',
#  'arevo',
#  'areyzaga',
#  'arfe',
#  'argaez',
#  'argain',
#  'argaiz',
#  'argandoña',
#  'argañaraz',
#  'argensola',
#  'argençola',
#  'argerich',
#  'argos',
#  'argote',
#  'arguedas',
#  'arguelles',
#  'arguello',
#  'arguero',
#  'argueta',
#  'arguibel',
#  'arguijo',
#  'arguimbau',
#  'argumosa',
#  'arias',
#  'arias-davila',
#  'aribau',
#  'aries',
#  'arigon',
#  'arigorri',
#  'arilla',
#  'arimon',
#  'arintero',
#  'arinyo',
#  'ariosto',
#  'aristegui',
#  'aristeguieta',
#  'aristizabal',
#  'aristondo',
#  'ariz',
#  'ariza',
#  'arizabalo',
#  'arizaga',
#  'arizala',
#  'arizcun',
#  'arizmendi',
#  'arizpe',
#  'ariño',
#  'arjona',
#  'arlegui',
#  'arles',
#  'arlovi',
#  'armada',
#  'armadams',
#  'armadans',
#  'armas',
#  'armasa',
#  'armaña',
#  'armendariz',
#  'armendia',
#  'armengol',
#  'armengual',
#  'armenta',
#  'armenteros',
#  'armentia',
#  'armero',
#  'armesto',
#  'armida',
#  'armijo',
#  'armona',
#  'arnaez',
#  'arnaiz',
#  'arnal',
#  'arnaldin',
#  'arnao',
#  'arnau',
#  'arnauto',
#  'arnaya',
#  'arnedo',
#  'arnolfini',
#  'aroche',
#  'arosa',
#  'arosemena',
#  'arostegui',
#  'aroza',
#  'arpayon',
#  'arpe',
#  'arpide',
#  'arquellada',
#  'arquer',
#  'arques',
#  'arrais',
#  'arrambide',
#  'arramendia',
#  'arrate',
#  'arratia',
#  'arrayza',
#  'arrazola',
#  'arredondo',
#  'arregui',
#  'arria',
#  'arriada',
#  'arriaga',
#  'arriaza',
#  'arribas',
#  'arribillaga',
#  'arrieta',
#  'arriete',
#  'arrigoni',
#  'arrillaga',
#  'arriola',
#  'arriquibar',
#  'arrivillaga',
#  'arrizala',
#  'arroita',
#  'arrona',
#  'arroniz',
#  'arrospide',
#  'arroyabe',
#  'arroyal',
#  'arroyo',
#  'arroyuel',
#  'arrubal',
#  'arrufat',
#  'arrunduaga',
#  'arruti',
#  'artazu',
#  'artea',
#  'arteaga',
#  'arteaga-lazcano',
#  'artes',
#  'artesero',
#  'arteta',
#  'artieda',
#  'artiga',
#  'artigas',
#  'artigues',
#  'artiguez',
#  'artorrasagasti',
#  'arviza',
#  'arxo',
#  'arza',
#  'arzadum',
#  'arzamendi',
#  'arzans',
#  'arze',
#  'arzueta',
#  'arzão',
#  'asanza',
#  'asarau',
#  'ascanio',
#  'ascargorta',
#  'ascaso',
#  'ascensio',
#  'ascension',
#  'ascorbe',
#  'ascucha',
#  'asejas',
#  'asensi',
#  'asensio',
#  'asfeld',
#  'asiain',
#  'asiego',
#  'asmodeo',
#  'aso',
#  'aspas',
#  'aspee',
#  'aspiazu',
#  'asprer',
#  'asseliers',
#  'assin',
#  'asso',
#  'assolenville',
#  'asta',
#  'astarloa',
#  'aste',
#  'asteguieta',
#  'astengo',
#  'astete',
#  'astigarraga',
#  'astiria',
#  'astiz',
#  'asto',
#  'astola',
#  'astor',
#  'astorch',
#  'astorga',
#  'astorquiza',
#  'astrandi',
#  'astraudi',
#  'astudillo',
#  'asturiano',
#  'asturias',
#  'asua',
#  'asuncio',
#  'asunsolo',
#  'atahualpa',
#  'ataide',
#  'atanasio',
#  'atau',
#  'atencia',
#  'atero',
#  'ateza',
#  'atienza',
#  'atlacat',
#  'atocha',
#  'atondo',
#  'atorrasagasti',
#  'attendolo',
#  'aubarede',
#  'audije',
#  'auguerolas',
#  'auguet',
#  'augusta',
#  'aulestia',
#  'auli',
#  'aurel',
#  'aurioles',
#  'ausa',
#  'austri',
#  'austria',
#  'auther',
#  'autillo',
#  'auñon',
#  'avalle',
#  'avalos',
#  'avedillo',
#  'avellan',
#  'avellaneda',
#  'avello',
#  'avendaño',
#  'avengochea',
#  'avila',
#  'aviles',
#  'avina',
#  'avinent',
#  'aviraneta',
#  'avis',
#  'aviñon',
#  'axcana',
#  'axpe',
#  'ayala',
#  'ayalde',
#  'ayanz',
#  'ayanz-arbizu',
#  'ayardi',
#  'ayarzagoitia',
#  'aybar',
#  'aycart',
#  'aycinena',
#  'aydie',
#  'ayensa',
#  'ayerbe',
#  'ayerdi',
#  'ayerra',
#  'ayesa',
#  'ayestaran',
#  'ayesteran',
#  'ayet',
#  'ayguals',
#  'ayllon',
#  'aylmer',
#  'aymamo',
#  'aymerich',
#  'ayolas',
#  'ayora',
#  'ayos',
#  'aysa',
#  'aytes',
#  'ayuso',
#  'ayuste',
#  'azagra',
#  'azailla',
#  'azamor',
#  'azanza',
#  'azao',
#  'azaola',
#  'azara',
#  'azas',
#  'azcarate',
#  'azcona',
#  'azcue',
#  'azcuenaga',
#  'azcueta',
#  'azcuitia',
#  'azcune',
#  'azeredo',
#  'azevedo',
#  'azlor',
#  'aznar',
#  'aznarez',
#  'azoca',
#  'azofra',
#  'azopardo',
#  'azor',
#  'azpeitia',
#  'azpeolaza',
#  'azpeytia',
#  'azpilcueta',
#  'azpilicueta',
#  'azpiroz',
#  'azpuru',
#  'azque',
#  'aztal',
#  'aztiguieta',
#  'azua',
#  'azuaga',
#  'azuara',
#  'azuola',
#  'azurara',
#  'azurduy',
#  'azzaro',
#  'añas',
#  'añasco',
#  'añaya',
#  'añoa',
#  'añorbe',
#  'añoza',
#  'babot',
#  'baca',
#  'bacallar',
#  'bacas',
#  'baccaro',
#  'bachiller',
#  'baciero',
#  'bada',
#  'badajoz',
#  'badaran',
#  'badenas',
#  'badenes',
#  'badia',
#  'badiano',
#  'badillos',
#  'badin',
#  'badiola',
#  'bado',
#  'baegert',
#  'baena',
#  'baez',
#  'baeza',
#  'baga',
#  'baget',
#  'baglietto',
#  'bago',
#  'baguena',
#  'baguer',
#  'bagues',
#  'bahamonde',
#  'bahi',
#  'baiges',
#  'baigorri',
#  'bailen',
#  'baillo',
#  'bailo',
#  'bailon',
#  'bails',
#  'baio',
#  'balaguer',
#  'balandra',
#  'balanza',
#  'balanzat',
#  'balbas',
#  'balbastro',
#  'balbes',
#  'balbi',
#  'balbin',
#  'balbo',
#  'balboa',
#  'balbontin',
#  'balbuena',
#  'balcarce',
#  'balcells',
#  'balcera',
#  'balda',
#  'baldasano',
#  'baldrich',
#  'balduque',
#  'balenchana',
#  'balenzegui',
#  'balerdi',
#  'balet',
#  'balle',
#  'ballester',
#  ...]

# %% [markdown]
# One issue is when certain names appear in both lists - then the string can have only one token belonging to both lists.
#
# But let's remove names that are repeated in the two lists. First we will make a list of the shared elements:

# %%
f = set(fnames)
l = set(lnames)

if (f & l): 
        f_and_l = list(f & l)
        print(f_and_l)
# Out:
# ['borja', 'lopez', 'ordoño', 'justiniano', 'ali', 'ramiro', 'matias', 'rui', 'victor', 'agustin', 'rodriguez', 'leon', 'clemente', 'paullu', 'maximiliano', 'fabian', 'suero', 'austria', 'conrado', 'james', 'rubin', 'al-manzari', 'huascar', 'jacome', 'juste', 'arias', 'camaquiri', 'severino', 'corella', 'camilo', 'guerau', 'tito', 'tome', 'hernandillo', 'amadeo', 'angel', 'lope', 'fadrique', 'antonio', 'elio', 'mata', 'esteve', 'das', 'floris', 'morejon', 'bernardo', 'estefania', 'fortun', 'vidal', 'alcocer', 'rufo', 'afonso', 'madux', 'domingo', 'baltasar', 'yupanqui', 'muley', 'ortega', 'tomasa', 'claudio', 'clara', 'benito', 'aragon', 'nuño', 'asensio', 'marco', 'gregorio', 'beatriz', 'correia', 'jordan', 'ortuño', 'dalmau', 'joaquin', 'bernat', 'enriquez', 'gabriel', 'robert', 'antonia', 'cacamatzin', 'jeronimo', 'poechos', 'abd', 'fermin', 'ana', 'romeu', 'valeriano', 'rosa', 'obregon', 'abu', 'cayetano', 'toribio', 'mauro', 'pedroso', 'valentin', 'hurtado', 'teodoro', 'andres', 'zacarias', 'rodrigo', 'garcilaso', 'giralte', 'duarte', 'gertrudis', 'catalina', 'cuauhtemoc', 'claros', 'ferrer', 'borbon-orleans', 'marie', 'amador', 'blanca', 'egas', 'regalado', 'felip', 'maestro', 'adriano', 'jaime', 'maestre', 'pereira', 'marina', 'manuel', 'luis', 'custodio', 'fernanda', 'abraham', 'simeon', 'simon', 'inca', 'caunaboa', 'luisa', 'inga', 'marciano', 'curi', 'valladolid', 'soriano', 'david', 'gregori', 'carlos', 'juan', 'corrado', 'bonaventura', 'gomez', 'leopoldo', 'santiago', 'frutos', 'gracian', 'pascual', 'julia', 'hamet', 'borbon', 'marta', 'ines', 'anastasio', 'leonor', 'jose', 'l-hasan', 'garabito', 'braganza', 'bonifacio', 'pastor', 'felix', 'caonabo', 'ferran', 'joan', 'alfonso', 'mendo', 'nieves', 'jorge', 'adrian', 'pedrosa', 'mancio', 'segundo', 'hernan', 'alonso', 'alberto', 'gines', 'enrique', 'zacut', 'andreu', 'eduardo', 'al-garnati', 'matheo', 'al-malik', 'salvador', 'farnesio', 'magdalena', 'tupac', 'jesus', 'monserrat', 'hernando', 'ramon', 'andre', 'tristan', 'boix', 'bernal', 'xavier', 'gaspar', 'samuel', 'pio', 'castilla', 'chi', 'valero', 'cipriano', 'jacinto', 'ferrando', 'teresa', 'mawlay', 'ricart', 'barbara', 'espiritu', 'baptista', 'giraldo', 'gomes', 'barros', 'muhammad', 'roberto', 'esteban', 'ildefonso', 'mariana', 'diego', 'perez', 'luca', 'llorenç', 'galceran', 'alejandro', 'francisco', 'tutul', 'germana', 'atau', 'ignacio', 'isabel', 'mancebo', 'donoso', 'buenaventura', 'moctezuma', 'selim', 'blas', 'macias', 'bernard', 'casta', 'navarra', 'manco', 'frances', 'elvira', 'guadalupe', 'marti', 'richard', 'rosario', 'aben', 'fernando', 'javier', 'von', 'francia', 'almanzor', 'benedicto', 'margarita', 'yves', 'corpus', 'victoria', 'francisca', 'iñigo', 'lazaro', 'felipa', 'alberti', 'cebrian', 'ascension', 'valois', 'santisima', 'sancho', 'ursula', 'nicolas', 'vivar', 'vasco', 'mateu', 'isabella', 'afan', 'gil', 'andrea', 'pelayo', 'berenguer', 'carles', 'angela', 'bartomeu', 'oliva', 'gispert', 'soares', 'orleans', 'tomas', 'ram', 'gentil', 'pablos', 'vicente', 'german', 'huallpa', 'hojeda', 'siri', 'villagomez', 'serafin', 'guillermo', 'martinillo', 'martir', 'mauri', 'ahmad', 'guzman', 'legallois', 'agusti', 'ruiz', 'adan', 'sebastian', 'bernabe', 'bezon', 'cesareo', 'mateo', 'ventura', 'cobos', 'arnao', 'pere', 'cid', 'pasqual', 'candido', 'cusi', 'bento', 'melchor', 'nazario', 'michel', 'pablo', 'nadal', 'cristobal', 'bartolome', 'jaume', 'pedro', 'sixto', 'titu', 'carolina', 'villac', 'furtado', 'leonardo', 'juana', 'miguel', 'thomas', 'parma', 'lorenzo', 'cesar', 'roque', 'maduz', 'sagipa', 'farag', 'lucena', 'guido', 'cecilia', 'elias', 'pau', 'gabriela', 'martinez', 'antoni', 'alvaro', 'beltran', 'marcos', 'mestre', 'lucio', 'felipe', 'blasco', 'solano', 'alal', 'julian', 'paula', 'velasco', 'martin', 'guillen', 'miquel', 'ponsich', 'saboya', 'sales', 'foix', 'roman', 'ascanio', 'jofre', 'bautista', 'carlota', 'millan', 'ferrante', 'marin', 'maria', 'amalia', 'sajonia', 'ernesto', 'silves ...

# %% [markdown]
# And we will drop them all from the lnames list (our function does not actually make a semantic difference between both lists).

# %%
lnames = list(l-(f&l))

# %%
lnames
# Out:
# ['lugo',
#  'moxica',
#  'jacas',
#  'ocon',
#  'mojica',
#  'armenteros',
#  'asso',
#  'chover',
#  'saraza',
#  'peinado',
#  'gariot',
#  'tendilla',
#  'isabe',
#  'sangronis',
#  'marquesado',
#  'tamarid',
#  'vial',
#  'gaona',
#  'gironella',
#  'garcia-herreros',
#  'macazaga',
#  'casale',
#  'conti',
#  'buzo',
#  'laloo',
#  "d'aragona",
#  'abrich',
#  'tablares',
#  'jofreu',
#  'morante',
#  'spannocchi',
#  'bassadona',
#  'pinar',
#  'portu',
#  'casedron',
#  'bentallol',
#  'bazcardo',
#  'connoch',
#  'hungri',
#  'teruel',
#  'masdovelles',
#  'evreux',
#  'piran',
#  'xaso',
#  'haedo',
#  'horna',
#  'fuenmayor',
#  'lema',
#  'meya',
#  'burunda',
#  'bollo',
#  'sanclemente',
#  'araucho',
#  'bissech',
#  'hovyne',
#  'pezzi',
#  'balaguer',
#  'arbasia',
#  'belloni',
#  'castellvi',
#  'conyngham',
#  'ruedas',
#  'carmitg',
#  'tarrega',
#  'eztenaga',
#  'contero',
#  'lencastre',
#  'lucero',
#  'creswell',
#  'silva',
#  'isniel',
#  'comalada',
#  'lastra',
#  'moy',
#  'gervete',
#  'bocanegra',
#  'seijas',
#  'basilis',
#  'paravicino',
#  'ponzoa',
#  'calar',
#  'monteros',
#  'conesa',
#  'seneca',
#  'ville',
#  'federmann',
#  'burgundia',
#  'albizu',
#  'viu',
#  'yebar',
#  'brochero',
#  'siuri',
#  'sabot',
#  'tutavila',
#  'manalt',
#  'inchauste',
#  'troncoso',
#  'enrich',
#  'blondeaux',
#  'coci',
#  'moron',
#  'almandoz',
#  'verrio',
#  'entraigues',
#  'rebentu',
#  'aurioles',
#  'posse',
#  'azao',
#  'sanjuanena',
#  'valgoma',
#  'balsa',
#  'iturzaeta',
#  'otamendi',
#  'taviel',
#  'gueruela',
#  'leruela',
#  'cervigon',
#  'gasco',
#  'ortes',
#  'peckius',
#  'valenzuela',
#  'tenamaztle',
#  'ortal',
#  'porta',
#  'amileta',
#  'esteller',
#  'rieras',
#  'victorica',
#  'arribillaga',
#  'ranz',
#  'cambronero',
#  'esbarroya',
#  'martini',
#  'centurion',
#  'escatron',
#  'erquicia',
#  'magnin',
#  'mari',
#  'noguerol',
#  'sidron',
#  'canellas',
#  'chaburu',
#  'fraile',
#  'normante',
#  'sacanell',
#  'arangoyti',
#  'piccolomini',
#  'cuadra',
#  'bruna',
#  'guirao',
#  'pitano',
#  'barnola',
#  'achutegui',
#  'cubillana',
#  'lloris',
#  'truq',
#  'tosantos',
#  'corachan',
#  'cegama',
#  'bethencourt',
#  'panzano',
#  'azanza',
#  'gysser',
#  'tocco',
#  'ribayaz',
#  'riaza',
#  'linaje',
#  'eixala',
#  'escanes',
#  'intriago',
#  'ibarrola',
#  'la',
#  'oñate',
#  'caprara',
#  'albertos',
#  'solares',
#  'cadena',
#  'francisquete',
#  'arimon',
#  'luccini',
#  'paleari',
#  'pardo',
#  'aparicio',
#  'adrada',
#  'lacarra',
#  'queipo',
#  'saureulx',
#  'meabe',
#  'sanponts',
#  'doral',
#  'santapau',
#  'cerviño',
#  'focher',
#  'bohorquez',
#  'lecina',
#  'viguera',
#  'panel',
#  'urrizola',
#  'verrua',
#  'montengon',
#  'perdriel',
#  'menendez-lavandera',
#  'pabon',
#  'caiche',
#  'esteva',
#  'gallardo',
#  'reula',
#  'segui',
#  'muxica',
#  'vilchez',
#  'avalle',
#  'lasarte',
#  'ortelius',
#  'oyanguren',
#  'retamal',
#  'ducrue',
#  'villouta',
#  'wendlingen',
#  'rohde',
#  'cafranga',
#  'seso',
#  'croce',
#  'parrado',
#  'pichardo',
#  'cereceda',
#  'broschi',
#  'rivafrecha',
#  'godos',
#  'gamio',
#  'arbaizar',
#  'barriada',
#  'alferio',
#  'malibran',
#  'alemans',
#  'saiz',
#  'luengo',
#  'pobladura',
#  'modenes',
#  'aguero',
#  'canelas',
#  'roben',
#  'pagola',
#  'rioja',
#  'rogier',
#  'arnolfini',
#  'cascales',
#  'guerra',
#  'hibernon',
#  'alaja',
#  'muscat',
#  'fernandini',
#  'cañete',
#  'ocio-salamanca',
#  'borbo',
#  'tizon',
#  'beck',
#  'marva',
#  'berrio',
#  'carquizano',
#  'bojadors',
#  'sada',
#  'parragues',
#  'torrejon',
#  'mallea',
#  'morales',
#  'hijas',
#  'bartolache',
#  'bargallo',
#  'colinas',
#  'matrera',
#  'ramirez',
#  'hazen',
#  'vazquez-montenegro',
#  'baquero',
#  'harrach',
#  'soloa',
#  'cariñena',
#  'pizcueta',
#  'mazas',
#  'fabrega',
#  'rami',
#  'comoto',
#  'haya',
#  'colcu',
#  'corio',
#  'cambier',
#  'perelli',
#  'donadeu',
#  'ezeyza',
#  'villes',
#  'marçal',
#  'moxo',
#  'kempeneer',
#  'veyre',
#  'ilarduy',
#  'comella',
#  'espinos',
#  'domezain',
#  'sangran',
#  'sigler',
#  'courbes',
#  'ripando',
#  'asua',
#  'lopez-pintado',
#  'gonzalez',
#  'alborxe',
#  'oneca',
#  'tardesillas',
#  'villamar',
#  'brieva',
#  'arguello',
#  'viar',
#  'vieyra',
#  'gatica',
#  'goycoa',
#  'almazor',
#  'castro',
#  'dorantes',
#  'pradez',
#  'urzainqui',
#  'utset',
#  'valledor',
#  'fraye',
#  'anguiano',
#  'steinhöffer',
#  'meca',
#  'lenguas',
#  'foraster',
#  'soberal',
#  'carceres',
#  'brimbeuf',
#  'valmaseda',
#  'oñez',
#  'sande',
#  'decio',
#  'garandal',
#  'solana',
#  'quecedo',
#  'santalinea',
#  'habsburgo-lorena',
#  'saplana',
#  'pou',
#  'quebedo',
#  'apezteguia',
#  'lannoy',
#  'lançari',
#  'halcon',
#  'campserver',
#  'cepeda',
#  'munebraga',
#  'basurco',
#  'cotera',
#  'thevalle',
#  'piñon',
#  'arriola',
#  'cardillo',
#  'cirerols',
#  'seguin',
#  'suche',
#  'solis',
#  'gassol',
#  'herran',
#  'faneca',
#  'temes',
#  'scio',
#  'camaño',
#  'oco',
#  'mirabent',
#  'jiles',
#  'laferriere',
#  'posadas',
#  'sumaya',
#  'marmolejo',
#  'furnari',
#  'thompson',
#  'aracil',
#  'orosz',
#  'zaldibia',
#  'berdusan',
#  'ribeira',
#  'arguedas',
#  'franqueza',
#  'cancio',
#  'pared',
#  'galavert',
#  'berberana',
#  'ressa',
#  'cartagena',
#  'mourin',
#  'mor',
#  'taverner',
#  'aquiles',
#  'elizondo',
#  'teixeira',
#  'barazabal',
#  'guinea',
#  'mira',
#  'rivera',
#  'ferruzzo',
#  'mansfeld',
#  'descos',
#  'saint-maxent',
#  'landivar',
#  'valdeyzcarai',
#  'ondategui',
#  'bamba',
#  'crehuet',
#  'badaran',
#  'leoni',
#  'limpias',
#  'germi',
#  'ayalde',
#  'armentia',
#  'larrasa',
#  'peyret',
#  'pantigoso',
#  'almodovar',
#  'susana',
#  'ferrus',
#  'uriburu',
#  'nalda',
#  'mercadillo',
#  'orcasitas',
#  'astola',
#  'torni',
#  'arrizala',
#  'bou',
#  'gaztañeta',
#  'rebollida',
#  'derretz',
#  'caramany',
#  'dauventon',
#  'proust',
#  'creuet',
#  'roncaño',
#  'parra',
#  'portilla',
#  'barberan',
#  'gauna',
#  'doria',
#  'argensola',
#  'altue',
#  'lax',
#  'maitre',
#  'perotin',
#  'mociño',
#  'aroza',
#  'lagrava',
#  'beretta',
#  'houndancourt',
#  'ateza',
#  'salla',
#  'varangot',
#  'butron-mugica',
#  'gualba',
#  'roda',
#  'amado',
#  'casillas',
#  'boisa',
#  'buelta',
#  'albujar',
#  'saint-just',
#  'arroniz',
#  'teixeiro',
#  'ubilla',
#  'celles',
#  'berriz',
#  'pinilla',
#  'tegell',
#  'pillarte',
#  'mestas',
#  'lagunez',
#  'montañez',
#  'lamuela',
#  'velandia',
#  'casado',
#  'aperregui',
#  'payan',
#  'domecq',
#  'montoro',
#  'giraldes',
#  'dicastillo',
#  'ometochtzi',
#  'bound',
#  'flon',
#  'sorrondegui',
#  'mainoldi',
#  'mozo',
#  'celada',
#  'carrena',
#  'bustillo',
#  'herrero',
#  'lexalde',
#  'cala',
#  'jaspe',
#  'melia',
#  'montalbo',
#  'estigarribia',
#  'guntin',
#  'nombre',
#  'collaert',
#  'noseret',
#  'cordoba',
#  'balerdi',
#  'gonzaga',
#  'soroeta',
#  'tous',
#  'havela',
#  'conejares',
#  'muñagorri',
#  'rustan',
#  'gomara',
#  'doms',
#  'helguero',
#  'verdier',
#  'caniego',
#  'mariategui',
#  'arguibel',
#  'allende-salazar',
#  'celestre',
#  'mayans',
#  'mezcorta',
#  'calbet',
#  'manteli',
#  'mantino',
#  'tagle',
#  'gallissa',
#  'añas',
#  'millau',
#  'barbero',
#  'renard',
#  'perchet',
#  'rueda',
#  'gainza',
#  'joaniz',
#  'potuliet',
#  'leoz',
#  'helguera',
#  'arechua',
#  'cortines',
#  'jaren',
#  'carroç',
#  'tolsa',
#  'eguren',
#  'aztiguieta',
#  'colonna',
#  'corchado',
#  'sansano',
#  'bracho',
#  'driget',
#  'aste',
#  'montejo',
#  'faing',
#  'ablanque',
#  'artiguez',
#  'cañes',
#  'escarsaga',
#  'azuara',
#  'cavero',
#  'abel',
#  'argote',
#  'provecho',
#  'massana',
#  'eldoz',
#  'bataglioli',
#  'caramuel',
#  'grijalba',
#  'alzina',
#  'carratala',
#  'baquijano',
#  'ristori',
#  'sangro',
#  'berrotaran',
#  'larraga',
#  'llampillas',
#  'peon',
#  'presa',
#  'honcala',
#  'cob',
#  'albano',
#  'taybili',
#  'adaro',
#  'colsa',
#  'galdoche',
#  'torremocha',
#  'mazarredo',
#  'sanjuan',
#  'arce',
#  'llanzol',
#  'grimaldo',
#  'vinuesa',
#  'percaz',
#  'galañena',
#  'esparza',
#  'becour',
#  'pagazaurtundua',
#  'veytia',
#  'adam',
#  'lemoyne',
#  'maroto',
#  'piña',
#  'ponzoni',
#  'legaspi',
#  'obejero',
#  'guarc',
#  'mangino',
#  'abuin',
#  'lombardo',
#  'gaytan',
#  'orozco',
#  'interian',
#  'grant',
#  'torrezar',
#  'juanini',
#  'becerro',
#  'icis',
#  'samanez',
#  'cueto',
#  'carasa',
#  'urdaniz',
#  'aranzazu',
#  'benit',
#  'aguirre-solarte',
#  'perrot',
#  'mardones',
#  'moliner',
#  'navel',
#  'ricafort',
#  'bebecolarrea',
#  'beldad',
#  'alaba',
#  'tarrago',
#  'dengo',
#  'laparra',
#  'herrezuelo',
#  'carballo',
#  'cavo',
#  'ortegon',
#  'gener',
#  'carreto',
#  'landeras',
#  'cairasco',
#  'casquete',
#  'pontac',
#  'molina',
#  'mendavia',
#  'otaduy',
#  'creus',
#  'toreno',
#  'capobianco',
#  'argos',
#  'barrantes',
#  'gautier',
#  'bastidas',
#  'galtiez',
#  'cabrer',
#  'montalto',
#  'valverde',
#  'caparroso',
#  'meireles',
#  'ubach',
#  'omaña',
#  'regules',
#  'nobal',
#  'dardon',
#  'lindner',
#  'gabin',
#  'sobralde',
#  'liniers',
#  'castelvi',
#  'tarrius',
#  'pielago',
#  'cuneo',
#  'olabarri',
#  'cistue',
#  'moraga',
#  'astengo',
#  'axpe',
#  'fernandez-maldonado',
#  'valderrama',
#  'groot',
#  'joyes',
#  'cabrerizo',
#  'peellart',
#  'arauxo',
#  'timboni',
#  'uriondo',
#  'astraudi',
#  'diosdado',
#  'fos',
#  'lalanne',
#  'manteca',
#  'chacho',
#  'luschner',
#  'gayon',
#  'labarca',
#  'foruria',
#  'trilles',
#  'faralt',
#  'riofrio',
#  'purificacio',
#  'castaños',
#  'suelves',
#  'vaguer',
#  'viñals',
#  'echezarreta',
#  'longo',
#  'castrejon',
#  'ascorbe',
#  'chavacier',
#  'bordonave',
#  'breze',
#  'echeberz',
#  'vallebrera',
#  'beamonte',
#  'astiria',
#  'porlier',
#  'marcue-erquiaga',
#  'vertisberea',
#  'vehena',
#  'forte',
#  'ruzola',
#  'lobkowitz',
#  'craywinckel',
#  'polinillo',
#  'forcadell',
#  'carbonell',
#  'ezquerro',
#  'guardia',
#  'figueroa',
#  'checa',
#  'perola',
#  'manosalvas',
#  'eslava',
#  'ponton',
#  'cerero',
#  'almogaver',
#  'evans',
#  'sirera',
#  'vedel',
#  'beira',
#  'cristofini',
#  'bassas',
#  'cuyas',
#  'courtewille',
#  'alta',
#  'nazareno',
#  'santponç',
#  'gallo',
#  'villaizan',
#  'guezzi',
#  'cogolludo',
#  'morras',
#  'mieg',
#  'agoiz',
#  'egusquiza',
#  'gandia',
#  'seixas',
#  'cascallana',
#  'amatriain',
#  'ramo',
#  'duruelo',
#  'arrambide',
#  'ochoteco',
#  'morazan',
#  'munilla',
#  'bocalan',
#  'saliquet',
#  'alemcastre',
#  'fetino',
#  'larraya',
#  'minuissir',
#  'vicentelo',
#  'mencos',
#  'cocolina',
#  'valdivieso',
#  'moñiz',
#  'oraeta',
#  'marquez',
#  'arrais',
#  'yrolo',
#  'borja-llançol',
#  'gonzalez-salmon',
#  'orduña',
#  'rosado',
#  'falck',
#  'morquecho',
#  'merican',
#  'sicre',
#  'frechilla',
#  'davin',
#  'lebrija',
#  'ipas',
#  'viedma',
#  'mendez',
#  'cabriada',
#  'goribar',
#  'jacobsen',
#  'bauça',
#  'marujan',
#  'soberon',
#  'villar',
#  'talaverano',
#  'marchioti',
#  'ravenet',
#  'rancaño',
#  'aheran',
#  'figuerola',
#  'guam',
#  'barzana',
#  'arellano',
#  'rondero',
#  'añoa',
#  'picoaga',
#  'ginart',
#  'manzano',
#  'bada',
#  'sanchez',
#  'marcellano',
#  'casayau',
#  'espino',
#  'magenise',
#  'casalbon',
#  'madariaga',
#  'lopes',
#  'ostolaza',
#  'redonda',
#  'doblas',
#  'castelo-branco',
#  'nurrieta',
#  'duval',
#  'autillo',
#  'renaud',
#  'chalez',
#  'amo',
#  'mayorga',
#  'paisan',
#  'wallparrimachi',
#  'cagigal',
#  'morote',
#  'targa',
#  'lidon',
#  'casales',
#  'mejandre',
#  'freses',
#  'escobedo',
#  'conget',
#  'sanchez-barriga',
#  'fitz-james',
#  'fragueiro',
#  'portillo',
#  'preux',
#  'ricardos',
#  'tutllo',
#  'auther',
#  'gemmir',
#  'mayone',
#  'ortusaustegui',
#  'oyuela',
#  'bonifaç',
#  'labarrieta',
#  'uiña',
#  'ternero',
#  'leiguarda',
#  'riega',
#  'caaveiro',
#  'bonpland',
#  'arrazola',
#  'orlandis',
#  'balandra',
#  'fors',
#  'escoriaza',
#  'quirant',
#  'vidaurreta',
#  'arrigoni',
#  'cladera',
#  'presas',
#  'bagues',
#  'carafa',
#  'tevar',
#  'montemayor',
#  'reguilon',
#  'rech',
#  'mayers',
#  'galiana',
#  'parrilla',
#  'alcañiz',
#  'pinelo',
#  'cabot',
#  'moyua',
#  'gimeno',
#  'rouvroy',
#  'veciana',
#  'moriz',
#  'penayo',
#  'rocamora',
#  'cattaneo',
#  'moreiro',
#  'tamon',
#  'fontcuberta',
#  'estuard',
#  'breço',
#  'moredo',
#  'neumann',
#  'orry',
#  'rutiner',
#  'salvo',
#  'triviño',
#  'toro-zambrano',
#  'amunariz',
#  'moles',
#  'lisperguer',
#  'berganza',
#  'arcos',
#  'manzanos',
#  'laurel',
#  'superna',
#  'reluz',
#  'manjon',
#  'secano',
#  'cabarcas',
#  'flor',
#  'gomez-benitez',
#  'lombardero',
#  'alfinger',
#  'hontiveros',
#  'amigant',
#  'fernandez-montañes',
#  'peris',
#  'loynaz',
#  'arbizu',
#  'grimoard',
#  'sesma',
#  'flecha',
#  'falconi',
#  'yegros',
#  'cardoso',
#  'salaya',
#  'guitarte',
#  'cort',
#  'mojares',
#  'cieza',
#  'carbicia',
#  'tudanca',
#  'pilo',
#  'labrada',
#  'cabrera',
#  'colonia',
#  'galindez',
#  'missonet',
#  'sardina',
#  'queinoge',
#  'aldao',
#  'colodrero',
#  'pallon',
#  'gari',
#  'sentenach',
#  'pery',
#  'vildosola',
#  'harcourt',
#  'almazul',
#  'hubert',
#  'domonte',
#  'allonville',
#  'olibes',
#  'trogner',
#  'montaño',
#  'margariño',
#  'arramendia',
#  'llarena',
#  'nuceda',
#  'behechi',
#  'matos',
#  'maliz',
#  'centurione-oltramarino',
#  'calzadilla',
#  'linaz',
#  'morelos',
#  'majo',
#  'lizola',
#  'albariño',
#  'huete',
#  'siloe',
#  'mingo',
#  'alberoni',
#  'aristizabal',
#  'junoy',
#  'flandro',
#  'pambley',
#  'lizaurzabal',
#  'hermes',
#  'camara',
#  'winthuysen',
#  'ibar',
#  'o’doyle',
#  'barraquer',
#  'mingot',
#  'malabia',
#  'inchaurregui',
#  'veri',
#  ...]

# %% [markdown]
# Below: We create a function that results in True for any string that contains one token from each list, and apply it to the dataframe.

# %%
any_in = lambda a, b, c: any(i.lower() in b for i in a) and any(i.lower() in c for i in a)

# %%
people['Remove'] = people.apply(lambda x: 0 if any_in(x['string'].split(),fnames,lnames) and len(x['string'].split())>1 else x['Remove'], axis=1)

# %% [markdown]
# The function above checks every row in the dataframe, assigning people['Remove'] = 0 whenever there is at least one token from the string in both the first name and last name lists.
#
# The added condition of length string.split() being greater than one at least weeds out names that have only one token. This is useful particularly for removing names of saints, likely from descriptions of paintings or images.

# %%
grouped = people.groupby('Remove')
grouped.count()
# Out:
#         Unnamed: 0  docid  string  label  start    end
# Remove
# 0            20750  20750   20750  20750  20750  20750
#              12370  12370   12370  12370  12370  12370

# %%
len(people['string'].unique())
# Out:
# 14517

# %% [markdown]
# Number of unique strings identified:

# %%
len(people.loc[people['Remove']==0,'string'].unique())
# Out:
# 7794

# %% [markdown]
# Number of unique strings not yet identified:

# %%
len(people.loc[people['Remove']=='','string'].unique())
# Out:
# 6723

# %% [markdown]
# Let's export both lists of unique strings (confirmed and unconfirmed) to print them out, look at them and try to identify patterns for further work.

# %%
a= people.loc[people['Remove']==0,'string'].str.lower()
a= a.unique()
a= pd.Series(a)
len(a)
# Out:
# 6752

# %%
b= people.loc[people['Remove']=='','string'].str.lower()
b= b.unique()
b= pd.Series(b)
len(b)
# Out:
# 6271

# %%
a.to_csv("acceptedpersnames.csv")
b.to_csv("remainingpersnames.csv")

# %% [markdown]
# Will also export the intermediate people table to work with them in different sessions:

# %%
people.to_csv("Files_Cleaning1/people_strat2.csv")

# %% [markdown]
# # Strategy 3: Fuzzy Matching
#
# Many of the unmatched tags above are variations of real names with approximate matches in the list.  We can use fuzzy matching to further find names.

# %%
from fuzzywuzzy import fuzz
from fuzzywuzzy import process

# %% [markdown]
# Generate a unique dataframe of tokens from our strings:

# %%
tokens = pd.DataFrame()

# %%
tokens['token']=''
tokens['score']=''
tokens['match']=''

# %%
tokens
# Out:
# Empty DataFrame
# Columns: [token, score, match]
# Index: []

# %%
a = list(people['string'].str.split())

# %%
a
# Out:
# [[],
#  ['Rodriguez'],
#  ['Gomez', 'Brito'],
#  ['Manrique'],
#  ['Ramirez'],
#  ['Sarabia'],
#  ['Velas'],
#  ['Velasco'],
#  ['Herrera', 'Ortiz'],
#  ['Pinta', 'y', 'Collantes'],
#  ['Abrego'],
#  ['Nino', 'Guevara'],
#  ['de', 'Vega'],
#  ['geronimo', 'hernandez'],
#  ['luisa', 'ordoñes'],
#  ['basco', 'perea'],
#  ['gaspar', 'aguila'],
#  ['vasco', 'pereyra'],
#  ['gaspar', 'nuñes', 'delgado'],
#  [],
#  [],
#  ['alonso', 'padilla'],
#  ['las'],
#  ['su'],
#  ['A', 'Lopez'],
#  ['AGUSTIN', 'FRANCO'],
#  ['AGUSTIN', 'DE', 'PEREA'],
#  ['AGUSTIN', 'DE', 'PEREA'],
#  ['AGUSTIN', 'DE', 'PEREA'],
#  ['AGUSTIN', 'DE', 'PEREA'],
#  ['AGUSTIN', 'DE', 'PEREA'],
#  ['AGUSTIN', 'FRANCO'],
#  ['AGUSTIN', 'FRANCO'],
#  ['AGUSTIN', 'FRANCO'],
#  ['AGUSTIN', 'FRANCO'],
#  ['AGUSTIN', 'FRANCO'],
#  ['AGUSTIN', 'FRANCO'],
#  ['AGUSTIN', 'GONZALEZ'],
#  ['AGUSTIN', 'GONZALEZ'],
#  ['AGUSTIN', 'PEREZ'],
#  ['AGUSTIN', 'PEREZ'],
#  ['AGUSTIN', 'PEREZ', 'ROMERO'],
#  ['AGUSTIN', 'PEREZ', 'ROMERO'],
#  ['AGUSTIN', 'PEREZ', 'ROMERO'],
#  ['ALBERTO', 'JUANES'],
#  ['ALFONSO', 'FAJARDO'],
#  ['ALFONSO', 'FAJARDO'],
#  ['ALFONSO', 'FAJARDO'],
#  ['ALFONSO', 'FAJARDO'],
#  ['ALFONSO', 'FAJARDO'],
#  ['ALFONSO', 'FAJARDO'],
#  ['ALFONSO', 'MARTIN'],
#  ['ALFONSO', 'MARTIN'],
#  ['ALFONSO', 'MARTIN'],
#  ['ALFONSO', 'MARTINEZ'],
#  ['ALFONSO', 'MARTINEZ'],
#  ['ALFONSO', 'MARTINEZ'],
#  ['ALFONSO', 'MARTINEZ'],
#  ['ALFONSO', 'MARTINEZ'],
#  ['ALFONSO', 'MARTINEZ'],
#  ['ALFONSO', 'MARTINEZ'],
#  ['ALFONSO', 'MARTINEZ'],
#  ['ALFONSO', 'MARTINEZ'],
#  ['ALFONSO', 'MARTINEZ'],
#  ['ALFONSO', 'MARTINEZ'],
#  ['ALFONSO', 'MARTINEZ'],
#  ['ALFONSO', 'MARTINEZ'],
#  ['ALFONSO', 'MARTINEZ'],
#  ['ALFONSO', 'MARTINEZ'],
#  ['ALFONSO', 'MARTINEZ'],
#  ['ALFONSO', 'MARTINEZ'],
#  ['ALFONSO', 'MARTINEZ'],
#  ['ALFONSO', 'MARTINEZ'],
#  ['ALFONSO', 'MARTINEZ'],
#  ['ALFONSO', 'MARTINEZ'],
#  ['ALFONSO', 'MARTINEZ'],
#  ['ALFONSO', 'MARTINEZ'],
#  ['ALFONSO', 'MARTINEZnos'],
#  ['ALONSO', 'CORDERO'],
#  ['ALONSO', 'CORDERO'],
#  ['ALONSO', 'CORDERO'],
#  ['ALONSO', 'CORDERO'],
#  ['ALONSO', 'CORDERO'],
#  ['ALONSO', 'CORDERO'],
#  ['ALONSO', 'CORDERO'],
#  ['ALONSO', 'DE', 'ARAUS'],
#  ['ALONSO', 'DE', 'ARTEAGA'],
#  ['ALONSO', 'DE', 'ARTIAGA'],
#  ['ALONSO', 'DE', 'ARUAS'],
#  ['ALONSO', 'DE', 'FLORES'],
#  ['ALONSO', 'DE', 'FLORES'],
#  ['ALONSO', 'DE', 'FLORES'],
#  ['ALONSO', 'DE', 'FLORES'],
#  ['ALONSO', 'DE', 'ORTEGA'],
#  ['ALONSO', 'DE', 'SAMORATORO'],
#  ['ALONSO', 'DE', 'SAMORATORO'],
#  ['ALONSO', 'DE', 'ZAMORA'],
#  ['ALONSO', 'DE', 'ZAMORA'],
#  ['ALONSO', 'DE', 'ZAMORA'],
#  ['ALONSO', 'DE', 'ZAMORA'],
#  ['ALONSO', 'DE', 'ZAMORA'],
#  ['ALONSO', 'DE', 'ZAMORA'],
#  ['ALONSO', 'DE', 'ZAMORA'],
#  ['ALONSO', 'DE', 'ZAMORA'],
#  ['ALONSO', 'DE', 'ZAMORA'],
#  ['ALONSO', 'DE', 'ZAMORA'],
#  ['ALONSO', 'DE', 'ZAMORA'],
#  ['ALONSO', 'DE', 'ZAMORA'],
#  ['ALONSO', 'DE', 'ZAMORA'],
#  ['ALONSO', 'DE', 'ZAMORATORO'],
#  ['ALONSO', 'DE', 'ZAMORATORO'],
#  ['ALONSO', 'DE', 'ZAMORATORO'],
#  ['ALONSO', 'DE', 'ZAMORATORO'],
#  ['ALONSO', 'DE', 'ZAMORATORO'],
#  ['ALONSO', 'DE', 'ZAMORATORO'],
#  ['ALONSO', 'DE', 'ZAMORATORO'],
#  ['ALONSO', 'DE', 'ZAMORATORO'],
#  ['ALONSO', 'DE', 'ZAMORATORO'],
#  ['ALONSO', 'DE', 'ZAMORATORO'],
#  ['ALONSO', 'DE', 'ZAMORATORO'],
#  ['ALONSO', 'DE', 'ZAMORATORO'],
#  ['ALONSO', 'DE', 'ZAMORATORO'],
#  ['ALONSO', 'DE', 'ZARATE'],
#  ['ALONSO', 'DE', 'ZARATE'],
#  ['ALONSO', 'DE', 'ZARATE'],
#  ['ALONSO', 'DE', 'ZARATE'],
#  ['ALONSO', 'DE', 'ZARATE'],
#  ['ALONSO', 'DE', 'ZARATE'],
#  ['ALONSO', 'DE', 'ZARATE'],
#  ['ALONSO', 'DE', 'ZARATE'],
#  ['ALONSO', 'DE', 'ZARATE'],
#  ['ALONSO', 'DE', 'ZARATE'],
#  ['ALONSO', 'DE', 'ZARATE'],
#  ['ALONSO', 'DE', 'ZARATE'],
#  ['ALONSO', 'DE', 'ZARATE'],
#  ['ALONSO', 'DE', 'ZARATE'],
#  ['ALONSO', 'DE', 'ZARATE'],
#  ['ALONSO', 'DE', 'ZARATE'],
#  ['ALONSO', 'DE', 'ZARATE'],
#  ['ALONSO', 'FAJARDO'],
#  ['ALONSO', 'FAJARDO'],
#  ['ALONSO', 'FAJARDO'],
#  ['ALONSO', 'FAJARDO'],
#  ['ALONSO', 'FAJARDO'],
#  ['ALONSO', 'FAJARDO'],
#  ['ALONSO', 'FAJARDO'],
#  ['ALONSO', 'FAJARDO'],
#  ['ALONSO', 'FAJARDO'],
#  ['ALONSO', 'FAJARDO'],
#  ['ALONSO', 'FAJARDO'],
#  ['ALONSO', 'FAJARDO'],
#  ['ALONSO', 'FAJARDO'],
#  ['ALONSO', 'FAJARDO'],
#  ['ALONSO', 'FAJARDO'],
#  ['ALONSO', 'FAJARDO'],
#  ['ALONSO', 'FAJARDO'],
#  ['ALONSO', 'FAJARDO'],
#  ['ALONSO', 'FAJARDO'],
#  ['ALONSO', 'FAJARDO'],
#  ['ALONSO', 'FAJARDO'],
#  ['ALONSO', 'FAJARDO'],
#  ['ALONSO', 'FAJARDO'],
#  ['ALONSO', 'FAJARDO'],
#  ['ALONSO', 'FAJARDO'],
#  ['ALONSO', 'FAJARDO'],
#  ['ALONSO', 'FAJARDO'],
#  ['ALONSO', 'FAJARDO'],
#  ['ALONSO', 'FAJARDO'],
#  ['ALONSO', 'FAJARDO'],
#  ['ALONSO', 'FAJARDO'],
#  ['ALONSO', 'FAJARDO'],
#  ['ALONSO', 'FAJARDO'],
#  ['ALONSO', 'FAJARDO'],
#  ['ALONSO', 'FAJARDO'],
#  ['ALONSO', 'FAJARDO'],
#  ['ALONSO', 'FAJARDO'],
#  ['ALONSO', 'FAJARDO'],
#  ['ALONSO', 'FAJARDO'],
#  ['ALONSO', 'FAJARDO'],
#  ['ALONSO', 'FAJARDO'],
#  ['ALONSO', 'FAJARDO'],
#  ['ALONSO', 'FAJARDO'],
#  ['ALONSO', 'FAJARDO'],
#  ['ALONSO', 'FAJARDO'],
#  ['ALONSO', 'FAJARDO'],
#  ['ALONSO', 'FAJARDO'],
#  ['ALONSO', 'FAJARDO'],
#  ['ALONSO', 'FAJARDO'],
#  ['ALONSO', 'FAJARDO'],
#  ['ALONSO', 'FAJARDO'],
#  ['ALONSO', 'FAJARDO'],
#  ['ALONSO', 'FAJARDO'],
#  ['ALONSO', 'FAJARDO'],
#  ['ALONSO', 'FAJARDO'],
#  ['ALONSO', 'FAJARDO'],
#  ['ALONSO', 'FAJARDO'],
#  ['ALONSO', 'FAJARDO'],
#  ['ALONSO', 'FAJARDO'],
#  ['ALONSO', 'FAJARDO'],
#  ['ALONSO', 'FAJARDO'],
#  ['ALONSO', 'FAJARDO'],
#  ['ALONSO', 'FAJARDO'],
#  ['ALONSO', 'FAJARDO'],
#  ['ALONSO', 'FAJARDO'],
#  ['ALONSO', 'FAJARDO'],
#  ['ALONSO', 'FAJARDO'],
#  ['ALONSO', 'FAJARDO'],
#  ['ALONSO', 'FAJARDO'],
#  ['ALONSO', 'FAJARDO'],
#  ['ALONSO', 'FAJARDO'],
#  ['ALONSO', 'FAJARDO'],
#  ['ALONSO', 'FAJARDO'],
#  ['ALONSO', 'FAJARDO'],
#  ['ALONSO', 'FAJARDO'],
#  ['ALONSO', 'FAJARDO'],
#  ['ALONSO', 'FAJARDO'],
#  ['ALONSO', 'FAJARDO'],
#  ['ALONSO', 'FAJARDO'],
#  ['ALONSO', 'FAJARDO'],
#  ['ALONSO', 'FAJARDO'],
#  ['ALONSO', 'FAJARDO', 'DE', 'LA', 'TORRE'],
#  ['ALONSO', 'LOPEZ'],
#  ['ALONSO', 'LOPEZ'],
#  ['ALONSO', 'LOPEZ'],
#  ['ALONSO', 'LOPEZ'],
#  ['ALONSO', 'LOPEZ'],
#  ['ALONSO', 'LOPEZ'],
#  ['ALONSO', 'MARTINEZ'],
#  ['ALONSO', 'MIGUEL', 'DE', 'TOBAR'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ', 'DE', 'HERRERA'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ'],
#  ['ALONSO', 'PEREZ', 'DE', 'ERRERA'],
#  ['ALONSO', 'PEREZ', 'DE', 'GUZMAN'],
#  ['ALONSO', 'PEREZ', 'DE', 'GUZMAN'],
#  ['ALONSO', 'PEREZ', 'DE', 'HERRERA'],
#  ['ALONSO', 'PEREZ', 'DE', 'HERRERA'],
#  ['ALONSO', 'PEREZ', 'DE', 'HERRERA'],
#  ['ALONSO', 'PEREZ', 'DE', 'HERRERA'],
#  ['ALONSO', 'PEREZ', 'DE', 'HERRERA'],
#  ['ALONSO', 'PEREZ', 'DE', 'HERRERA'],
#  ['ALONSO', 'PEREZ', 'DE', 'HERRERA'],
#  ['ALONSO', 'PEREZ', 'DE', 'HERRERA'],
#  ['ALONSO', 'PEREZ', 'DE', 'HERRERA'],
#  ['ALONSO', 'PEREZ', 'DE', 'HERRERA'],
#  ['ALONSO', 'PEREZ', 'DE', 'HERRERA'],
#  ['ALONSO', 'PEREZ', 'DE', 'HERRERA'],
#  ['ALONSO', 'PEREZ', 'DE', 'HERRERA'],
#  ['ALONSO', 'PEREZ', 'DE', 'HERRERA'],
#  ['ALONSO', 'PEREZ', 'DE', 'HERRERA'],
#  ['ALONSO', 'PEREZ', 'DE', 'HERRERA'],
#  ['ALONSO', 'PEREZ', 'DE', 'HERRERA'],
#  ['ALONSO', 'PEREZ', 'DE', 'HERRERA'],
#  ['ALONSO', 'PEREZ', 'MORILLO'],
#  ['ALONSO', 'PEREZ', 'MORILLO'],
#  ['ALONSO', 'Perez'],
#  ['ALONSO', 'RODRIGUEZ', 'CORDERO'],
#  ['ALONSO', 'SANCHEZ'],
#  ['ALONSO', 'SANCHEZ'],
#  ['ALONSO', 'SANCHEZ'],
#  ['ALONSO', 'SANCHEZ'],
#  ['ALONSO', 'SANCHEZ'],
#  ['ALONSO', 'ZAMORA'],
#  ['ALONSO', 'ZAMORA'],
#  ['ALONSO', 'ZAMORA'],
#  ['ALONSO', 'ZAMORA'],
#  ['ALONSO', 'ZAMORA', 'DE', 'TORO'],
#  ['ALONSO', 'ZAMORATORO'],
#  ['ALONSO', 'ZAMORATORO'],
#  ['ALONSO', 'ZAMORATORO'],
#  ['ALONSO', 'ZAMORATORO'],
#  ['ANDRES', 'CANCINO'],
#  ['ANDRES', 'CANCINO'],
#  ['ANDRES', 'CANCINO'],
#  ['ANDRES', 'CANCINO'],
#  ['ANDRES', 'CANCINO'],
#  ['ANDRES', 'CANCINO'],
#  ['ANDRES', 'CANCINO'],
#  ['ANDRES', 'CANSINO'],
#  ['ANDRES', 'CHAMORRO'],
#  ['ANDRES', 'CHAMORRO'],
#  ['ANDRES', 'CHAMORRO'],
#  ['ANDRES', 'CHAMORRO'],
#  ['ANDRES', 'CHAMORRO'],
#  ['ANDRES', 'CHAMORRO'],
#  ['ANDRES', 'CHAMORRO'],
#  ['ANDRES', 'CHAMORRO'],
#  ['ANDRES', 'CHAMORRO'],
#  ['ANDRES', 'CHAMORRO'],
#  ['ANDRES', 'CHAMORRO'],
#  ['ANDRES', 'CHAMORRO'],
#  ['ANDRES', 'CHAMORRO'],
#  ['ANDRES', 'CHAMORRO'],
#  ['ANDRES', 'CHAMORRO', 'DE', 'VALENCIA'],
#  ['ANDRES', 'DE', 'CHAMORRO'],
#  ['ANDRES', 'DE', 'CHAMORRO'],
#  ['ANDRES', 'DE', 'CHAMORRO'],
#  ['ANDRES', 'FRANCO'],
#  ['ANDRES', 'FRANCO'],
#  ['ANDRES', 'FRANCO'],
#  ['ANDRES', 'FRANCO'],
#  ['ANDRES', 'FRANCO'],
#  ['ANDRES', 'FRANCO'],
#  ['ANDRES', 'FRANCO'],
#  ['ANDRES', 'FRANCO'],
#  ['ANDRES', 'GARCIA'],
#  ['ANDRES', 'GARCIA'],
#  ['ANDRES', 'GARCIA'],
#  ['ANDRES', 'GARCIA'],
#  ['ANDRES', 'LEONARDO', 'PEREZ'],
#  ['ANDRES', 'MONTERO'],
#  ['ANDRES', 'MONTERO'],
#  ['ANDRES', 'MONTERO'],
#  ['ANDRES', 'MONTERO'],
#  ['ANDRES', 'MONTERO'],
#  ['ANDRES', 'MONTERO'],
#  ['ANDRES', 'MONTERO'],
#  ['ANDRES', 'MONTERO'],
#  ['ANDRES', 'MONTERO'],
#  ['ANDRES', 'MONTERO'],
#  ['ANDRES', 'MONTERO'],
#  ['ANDRES', 'MONTERO', 'DE', 'ESPINOSA'],
#  ['ANDRES', 'PEREZ'],
#  ['ANDRES', 'PEREZ', 'MORILLO'],
#  ['ANGELO', 'NARDI'],
#  ['ANGELO', 'NARDI'],
#  ['ANTONIO'],
#  ['ANTONIO', 'DE', 'ARIAS'],
#  ['ANTONIO', 'DE', 'LEJALDE'],
#  ['ANTONIO', 'DE', 'LEJALDE'],
#  ['ANTONIO', 'DE', 'LEJALDE'],
#  ['ANTONIO', 'DE', 'LEJALDE'],
#  ['ANTONIO', 'DE', 'LEJALDE'],
#  ['ANTONIO', 'DE', 'LEJALDE'],
#  ['ANTONIO', 'DE', 'PEREA'],
#  ['ANTONIO', 'DE', 'RIBERA'],
#  ['ANTONIO', 'DE', 'SARSOSA'],
#  ['ANTONIO', 'DE', 'VALDIVIESO'],
#  ['ANTONIO', 'DE', 'VALDIVIESO'],
#  ['ANTONIO', 'DE', 'VALDIVIESO'],
#  ['ANTONIO', 'DE', 'VALDIVIESO'],
#  ['ANTONIO', 'DE', 'VALDIVIESO'],
#  ['ANTONIO', 'DE', 'VALDIVIESO'],
#  ['ANTONIO', 'DE', 'VALDIVIESO'],
#  ['ANTONIO', 'DE', 'VALDIVIESO'],
#  ['ANTONIO', 'DE', 'ZARATE'],
#  ['ANTONIO', 'DE', 'ZARZOSA'],
#  ['ANTONIO', 'DE', 'ZARZOSA'],
#  ['ANTONIO', 'DE', 'ZARZOSA'],
#  ['ANTONIO', 'DE', 'ZARZOSA'],
#  ['ANTONIO', 'DE', 'ZARZOSA'],
#  ['ANTONIO', 'DE', 'ZARZOSA'],
#  ['ANTONIO', 'DE', 'ZARZOSA'],
#  ['ANTONIO', 'FAJARDO'],
#  ['ANTONIO', 'FAJARDO'],
#  ['ANTONIO', 'FAJARDO'],
#  ['ANTONIO', 'FAJARDO'],
#  ['ANTONIO', 'FAJARDO'],
#  ['ANTONIO', 'FAJARDO'],
#  ['ANTONIO', 'FAJARDO'],
#  ['ANTONIO', 'FAJARDO'],
#  ['ANTONIO', 'FRANCISCO', 'DE', 'LEJALDE'],
#  ['ANTONIO', 'GALLARDO'],
#  ['ANTONIO', 'GALLARDO'],
#  ['ANTONIO', 'GALLARDO'],
#  ['ANTONIO', 'GALLARDO'],
#  ['ANTONIO', 'GALLARDO'],
#  ['ANTONIO', 'GALLARDO'],
#  ['ANTONIO', 'GALLARDO'],
#  ['ANTONIO', 'GALLARDO'],
#  ['ANTONIO', 'GALLARDO'],
#  ['ANTONIO', 'GALLARDO'],
#  ['ANTONIO', 'GALLARDO'],
#  ['ANTONIO', 'GALLARDO'],
#  ['ANTONIO', 'GALLARDO'],
#  ['ANTONIO', 'GALLARDO'],
#  ['ANTONIO', 'GALLARDO'],
#  ['ANTONIO', 'GALLARDO'],
#  ['ANTONIO', 'GALLARDO'],
#  ['ANTONIO', 'GALLARDO'],
#  ['ANTONIO', 'GALLARDO'],
#  ['ANTONIO', 'GALLARDO'],
#  ['ANTONIO', 'GALLARDO'],
#  ['ANTONIO', 'GALLARDO'],
#  ['ANTONIO', 'GALLARDO'],
#  ['ANTONIO', 'GALLARDO', 'DE', 'LA', 'BARRERA'],
#  ['ANTONIO', 'GONZALEZ'],
#  ['ANTONIO', 'HIDALGO'],
#  ['ANTONIO', 'HIDALGO'],
#  ['ANTONIO', 'HIDALGO'],
#  ['ANTONIO', 'HIDALGO'],
#  ['ANTONIO', 'HIDALGO'],
#  ['ANTONIO', 'HIDALGO'],
#  ['ANTONIO', 'HIDALGO'],
#  ['ANTONIO', 'HIDALGO'],
#  ['ANTONIO', 'HIDALGO'],
#  ['ANTONIO', 'JIMENEZ', 'DE', 'SARACOSA'],
#  ['ANTONIO', 'JIMENEZ', 'DE', 'ZARAZOSA'],
#  ['ANTONIO', 'JIMENEZ', 'DE', 'ZARZOSA'],
#  ['ANTONIO', 'JIMENEZ', 'SARSOSA'],
#  ['ANTONIO', 'JIMENEZ', 'SARSOSA'],
#  ['ANTONIO', 'JIMENEZ', 'SARSOSA'],
#  ['ANTONIO', 'JIMENEZ', 'SARSOSA'],
#  ['ANTONIO', 'JIMENEZ', 'SARSOSA'],
#  ['ANTONIO', 'JIMENEZ', 'SARSOSSA'],
#  ['ANTONIO', 'JIMENEZ', 'ZARCOSA'],
#  ['ANTONIO', 'JIMENEZ', 'ZARZOSA'],
#  ['ANTONIO', 'JIMENEZ', 'ZARZOSA'],
#  ['ANTONIO', 'JIMENEZ', 'ZARZOSA'],
#  ['ANTONIO', 'LOPEZ'],
#  ['ANTONIO', 'MENESES', 'SALOSSO'],
#  ['ANTONIO', 'MARQUEZ'],
#  ['ANTONIO', 'PEREZ'],
#  ['ANTONIO', 'PEREZ'],
#  ['ANTONIO', 'PEREZ'],
#  ['ANTONIO', 'PEREZ'],
#  ['ANTONIO', 'PEREZ'],
#  ['ANTONIO', 'PEREZ'],
#  ['ANTONIO', 'PEREZ'],
#  ['ANTONIO', 'PEREZ'],
#  ['ANTONIO', 'PEREZ'],
#  ['ANTONIO', 'PEREZ'],
#  ['ANTONIO', 'PEREZ'],
#  ['ANTONIO', 'PEREZ'],
#  ['ANTONIO', 'PEREZ'],
#  ['ANTONIO', 'PEREZ'],
#  ['ANTONIO', 'PEREZ'],
#  ['ANTONIO', 'PEREZ'],
#  ['ANTONIO', 'RODRIQUEZ', 'BEJARANO'],
#  ['ANTONIO', 'ROSA'],
#  ['ANTONIO', 'RUIZ'],
#  ['ANTONIO', 'RUIZ'],
#  ['ANTONIO', 'RUIZ'],
#  ['ANTONIO', 'SARZOSA'],
#  ['ANTONIO', 'SUERO'],
#  ['ANTONIO', 'VALDIVIESO'],
#  ['ANTONIO', 'XIMENEZ', 'SARSOSA'],
#  ['ANTONIO', 'XIMENEZ', 'SARSOSA'],
#  ['ANTONIO', 'ZARCOSA'],
#  ['Abraham'],
#  ['Abraham', 'Pedro'],
#  ['Acenfio', 'Maeda'],
#  ['Acenfio', 'Maeda'],
#  ['Acensio', 'Maeda'],
#  ['Acensio', 'Maeda'],
#  ['Acensio', 'Maeda'],
#  ['Acisclos', 'Burgueño'],
#  ['Adan'],
#  ['Ademas'],
#  ['Adriaen', 'Jacome'],
#  ['Adrian', 'Escaraban'],
#  ['Adrian', 'Flamenco'],
#  ['Adrian', 'Francisco', 'Espinola'],
#  ['Adrian', 'Hernandez'],
#  ['Adrian', 'ossu'],
#  ['Adrian', 'ossu'],
#  ['Adrian', 'Jacome'],
#  ['Adrian', 'Lopez'],
#  ['Adrian', 'Clossa'],
#  ['Adrian', 'Escaraban'],
#  ['Adrian', 'Villens'],
#  ['Agnus', 'Dei', 'madera'],
#  ['Agnus', 'cera'],
#  ['Agustin', 'Tamariz'],
#  ['Agustin', 'Colmenares'],
#  ['Agustin', 'Colmenares'],
#  ['Agustin', 'Palma'],
#  ['Agustin', 'Uriarte'],
#  ['Agustin', 'Peña'],
#  ['Agustin', 'Castillo'],
#  ['Agustina', 'Caballero'],
#  ['Agustina', 'Florencia'],
#  ['Agustina', 'Ignacia', 'Zavala'],
#  ['Agustina', 'Martinez', 'Soto'],
#  ['Agustina', 'Maria', 'Josepha'],
#  ['Agustina', 'Maria', 'Schutt'],
#  ['Agustina', 'Maria', 'Schutt'],
#  ['Agustina', 'Maria', 'Schutt'],
#  ['Agustina', 'Maria', 'Olmedo'],
#  ['Agustina', 'Meneses', 'Schutt'],
#  ['Agustina', 'Porto', 'Carrero'],
#  ['Agustina', 'Tello', 'Meneses'],
#  ['Agustina', 'Tello', 'Meneses'],
#  ['Agustina', 'Tello', 'Meneses'],
#  ['Agustina', 'Tello', 'Meneses'],
#  ['Agustina', 'Tello', 'Meneses'],
#  ['Agustina', 'Tello', 'Meneses'],
#  ['Agustina', 'Vidal', 'y', 'Contreras'],
#  ['Agustina', 'Meneses'],
#  ['Agustina', 'Meneses'],
#  ['Agustina', 'Meneses'],
#  ['Agustina', 'Meneses'],
#  ['Agustina', 'Meneses'],
#  ['Agustina', 'Meneses'],
#  ['Agustina', 'Meneses'],
#  ['Agustina', 'Pineda'],
#  ['Agustina', 'Soto'],
#  ['Agustina', 'Soto'],
#  ['Agustina', 'Soto'],
#  ['Agustino', 'Francisco', 'Ribera'],
#  ['Agustino', 'Francisco', 'Ribera'],
#  ['Agustino', 'Francisco', 'Ribera'],
#  ['Agustin'],
#  ['Agustin', 'Berdugo'],
#  ['Agustin', 'Francisco', 'Armejo'],
#  ['Agustin', 'Gallego', 'Vezeria'],
#  ['Agustin', 'Garcia'],
#  ['Agustin', 'Garcia'],
#  ['Agustin', 'Gonzalo'],
#  ['Agustin', 'Gonzalez'],
#  ['Agustin', 'Jurado'],
#  ['Agustin', 'Lorenzo', 'Godoy'],
#  ['Agustin', 'Lorenzo', 'Godoy'],
#  ['Agustin', 'Lopez', 'Morales'],
#  ['Agustin', 'Marias'],
#  ['Agustin', 'Mejias'],
#  ['Agustin', 'Mexia'],
#  ['Agustin', 'Moreno'],
#  ['Agustin', 'Pacheco', 'Calaverde'],
#  ['Agustin', 'Perez', 'Vasconcelos'],
#  ['Agustin', 'Rodriguez'],
#  ['Agustin', 'Sanchez'],
#  ['Agustin', 'Arandia'],
#  ['Agustin', 'Armejo', 'y', 'Ribera'],
#  ['Agustin', 'Armido'],
#  ['Agustin', 'Bilches', 'Carvajal'],
#  ['Agustin', 'Borja'],
#  ['Agustin', 'Borja'],
#  ['Agustin', 'Escobar'],
#  ['Agustin', 'Herrera'],
#  ['Agustin', 'Herrera'],
#  ['Agustin', 'Libera'],
#  ['Agustin', 'Molina'],
#  ['Agustin', 'Toro'],
#  ['Agustin', 'Toro'],
#  ['Agustin', 'Torres'],
#  ['Agustin', 'Torres'],
#  ['Agustin', 'Torres'],
#  ['Agustin', 'Torres'],
#  ['Agustin', 'Torres'],
#  ['Agustin', 'Torres'],
#  ['Agustin', 'Uceda'],
#  ['Agustin', 'Vargas'],
#  ['Agustin', 'Vargas'],
#  ['Agustin', 'Vilches'],
#  ['Agustin', 'Vega'],
#  ['Agustin', 'Vega'],
#  ['Ahasuerus'],
#  ['Alarcon', 'Escribano'],
#  ['Alarcon', 'Escribano', 'Publico'],
#  ['Alarcon', 'Escribano', 'Publico'],
#  ['Alarcon', 'Escribano', 'Publico'],
#  ['Alarcon\x97Simon', 'Ruiz'],
#  ['Albaro', 'Cazeres'],
#  ['Albaro', 'Cazeres'],
#  ['Albaro', 'Cespedes', 'y', 'Vallejo'],
#  ['Alberta', 'Ambar'],
#  ['Alberto', 'Ferino'],
#  ['Alberto', 'Fernandez', 'Lucas'],
#  ['Alberto', 'Gomez'],
#  ['Alberto', 'Gomez'],
#  ['Alberto', 'Gomez'],
#  ['Alberto', 'Gomez'],
#  ['Alberto', 'Cespedes', 'y', 'Vallejo'],
#  ['Alejandro', 'Delgado'],
#  ['Alejandro', 'Lozano', 'Vargas'],
#  ['Alejandro', 'Mateo'],
#  ['Alejandro', 'Ramirez'],
#  ['Alejandro', 'Saavedra'],
#  ['Alejandro', 'Saavedra'],
#  ['Alejandro', 'Saavedra'],
#  ['Alejandro', 'Saavedra'],
#  ['Alejo', 'Fernandez'],
#  ['Alejo', 'Fernandez'],
#  ['Alejo', 'Fernandez'],
#  ['Alejo', 'Fernandez'],
#  ['Alejo', 'Fernandez'],
#  ['Alejo', 'Fernandez'],
#  ['Alejo', 'Fernandez'],
#  ['Alejo', 'Lopez'],
#  ['Alejo', 'Lopez'],
#  ['Alejo', 'Lozano', 'Ana'],
#  ['Alejos', 'Fernandez'],
#  ['Alejos', 'Fernandez'],
#  ['Alexandro', 'Garcia', 'Romero'],
#  ['Alexo', 'Herrera'],
#  ['Alexo', 'fernandes'],
#  ['Alexo', 'fernandes\x97garcia', 'leon'],
#  ['Alexo', 'fernandez\x97Rodrigo'],
#  ['Alexos', 'Fernandez'],
#  ['Alexos', 'Fernandez'],
#  ['Alexos', 'Fernandez'],
#  ['Alexos', 'Fernandez'],
#  ['Alexos', 'fernandes'],
#  ['Alexos', 'fernandez'],
#  ['Alfian'],
#  ['Alfonsa', 'Gutierrez', 'Maso'],
#  ['Alfonsa', 'Gutierrez', 'Mazo'],
#  ['Alfonsa', 'Maria', 'Noregon'],
#  ['Alfonsa', 'Maria', 'Montalban'],
#  ['Alfonso'],
#  ['Alfonso', 'Fernandez'],
#  ['Alfonso', 'Fernandez', 'Herrera'],
#  ['Alfonso', 'Fernandez', 'Herrera'],
#  ['Alfonso', 'Fernandez'],
#  ['Alfonso', 'Fernandez'],
#  ['Alfonso', 'Francisco'],
#  ['Alfonso', 'Francisco', 'Paula'],
#  ['Alfonso', 'Francisco', 'Paula'],
#  ['Alfonso', 'Martin'],
#  ['Alfonso', 'Martin', 'Marchena'],
#  ['Alfonso', 'Martinez'],
#  ['Alfonso', 'Martinez'],
#  ['Alfonso', 'Martinez'],
#  ['Alfonso', 'Martinez'],
#  ['Alfonso', 'Martinez'],
#  ['Alfonso', 'Martinez'],
#  ['Alfonso', 'Martinez'],
#  ['Alfonso', 'Nieto'],
#  ['Alfonso', 'Rodriguez'],
#  ['Alfonso', 'Ruiz', 'Dueñas'],
#  ['Alfonso', 'XII'],
#  ['Alfonso', 'XIII'],
#  ['Alfonso', 'Burgos'],
#  ['Alfonso', 'Escalante'],
#  ['Alfonso', 'Godoy'],
#  ['Alfonso', 'Jaen'],
#  ['Alfonso', 'Vargas'],
#  ['Alfonso', 'vargas'],
#  ['Alfonso', 'martines'],
#  ['Ali'],
#  ['Alo', 'Gordillo'],
#  ['Alo', 'alarcon', 'escriuo'],
#  ['Alo', 'alarcon', 'escriuo'],
#  ['Alo', 'fanchez', 'Gordillo'],
#  ['Alo', 'martin'],
#  ['Alonfo', 'Rivero'],
#  ['Alonfo', 'Mena'],
#  ['Alonfo', 'ximenez'],
#  ['Alonsa', 'Castillo'],
#  ['Alonso'],
#  ['Alonso'],
#  ['Alonso'],
#  ['Alonso'],
#  ['Alonso'],
#  ['Alonso'],
#  ['Alonso'],
#  ['Alonso'],
#  ['Alonso'],
#  ['Alonso', 'Agustin', 'Vanegas'],
#  ['Alonso', 'Agustin', 'Venegas'],
#  ['Alonso', 'Alarcon', 'Escribano', 'Publico'],
#  ['Alonso', 'Albarez'],
#  ['Alonso', 'Alcayde'],
#  ['Alonso', 'Alcayde', 'y', 'Canisares'],
#  ['Alonso', 'Alvarez'],
#  ['Alonso', 'Antonio', 'Tomas', 'Monsalve'],
#  ['Alonso', 'Antonio', 'Torres', 'Monsalve'],
#  ['Alonso', 'Antonio', 'Oros'],
#  ['Alonso', 'Balladare'],
#  ['Alonso', 'Benitez', 'Cardenas'],
#  ['Alonso', 'Calvo', 'Villafranco'],
#  ['Alonso', 'Cano'],
#  ['Alonso', 'Cano'],
#  ['Alonso', 'Cano'],
#  ['Alonso', 'Cano'],
#  ['Alonso', 'Cano'],
#  ['Alonso', 'Cano'],
#  ['Alonso', 'Cano'],
#  ['Alonso', 'Cano'],
#  ['Alonso', 'Cano'],
#  ['Alonso', 'Cano'],
#  ['Alonso', 'Cano'],
#  ['Alonso', 'Cano'],
#  ['Alonso', 'Cano'],
#  ['Alonso', 'Cano'],
#  ['Alonso', 'Cano'],
#  ['Alonso', 'Cano'],
#  ['Alonso', 'Cano'],
#  ['Alonso', 'Cano'],
#  ['Alonso', 'Cano'],
#  ['Alonso', 'Cano'],
#  ['Alonso', 'Carrasco'],
#  ['Alonso', 'Carrasco'],
#  ['Alonso', 'Carvallo'],
#  ['Alonso', 'Castellano'],
#  ['Alonso', 'Castillejo'],
#  ['Alonso', 'Duran'],
#  ['Alonso', 'Duran'],
#  ['Alonso', 'Ecijano'],
#  ['Alonso', 'Esteban', 'Guevara'],
#  ['Alonso', 'Fajardo'],
#  ['Alonso', 'Fajardo'],
#  ['Alonso', 'Farfan'],
#  ['Alonso', 'Fernandez'],
#  ['Alonso', 'Fernandez'],
#  ['Alonso', 'Fernandez'],
#  ['Alonso', 'Fernandez'],
#  ['Alonso', 'Fernandez'],
#  ['Alonso', 'Fernandez', 'Cano'],
#  ['Alonso', 'Fernandez', 'Guerra'],
#  ['Alonso', 'Fernandez', 'Mancheño'],
#  ['Alonso', 'Fernandez', 'Melgarejo'],
#  ['Alonso', 'Fernandez', 'Cordoba'],
#  ['Alonso', 'Fernandez', 'Santillan'],
#  ['Alonso', 'Fernandez'],
#  ['Alonso', 'Fernandez', 'Camacho'],
#  ['Alonso', 'Flores'],
#  ['Alonso', 'Francisco', 'Ortiz'],
#  ['Alonso', 'Franco'],
#  ['Alonso', 'Franco', 'Castro'],
#  ['Alonso', 'Gallardo'],
#  ['Alonso', 'Garcia'],
#  ['Alonso', 'Garcia', 'Ronquillo'],
#  ['Alonso', 'Garcia', 'Ronquillo'],
#  ['Alonso', 'Garcia'],
#  ['Alonso', 'Garcia'],
#  ['Alonso', 'Garcia'],
#  ['Alonso', 'Garcia'],
#  ['Alonso', 'Garcia', 'Guijarro'],
#  ['Alonso', 'Garcia', 'Medida'],
#  ['Alonso', 'Garcia', 'Soto'],
#  ['Alonso', 'Garcia', 'Velladares'],
#  ['Alonso', 'Garcia', 'Villar'],
#  ['Alonso', 'Garido'],
#  ['Alonso', 'Gomez', 'Carvayo'],
#  ['Alonso', 'Gonzalez'],
#  ['Alonso', 'Gonzalez'],
#  ['Alonso', 'Gonzalez'],
#  ['Alonso', 'Gonzalez'],
#  ['Alonso', 'Gonzalez'],
#  ['Alonso', 'Gonzalez', 'Hidalgo'],
#  ['Alonso', 'Guerrero'],
#  ['Alonso', 'Guerrero'],
#  ...]

# %%
flat_a = [item for sublist in a for item in sublist]

# %%
set_a = set(flat_a)

# %%
for token in set_a:
    tokens= tokens.append({'token':token}, ignore_index=True)

# %%
len(tokens)
# Out:
# 7289

# %%
tokens = tokens.replace(to_replace='None', value='')

# %% [markdown]
# Next, we are going to merge the first and last name lists.

# %%
names = fnames

names.extend(lnames)

# %% [markdown]
# Next, we will define a function that gives us the maximum value of the match

# %%
len(names)
# Out:
# 10005

# %%
def fuzzmax(string,names):
        string = str(string).lower()
        result = list(map(lambda a: fuzz.token_sort_ratio(string,a),names))
        return [max(result),names[result.index(max(result))]]

# %%
type(fuzzmax("Antonio de Medina","Jose"))
# Out:
# list

# %%
fuzzmax("Antonio",['Jose','Manuel','Antonia'])
# Out:
# [86, 'Antonia']

# %% [markdown]
# We use this function to find the best matches for each token:

# %%
tokens['score'] = tokens.apply(lambda x: fuzzmax(x['token'], names), axis = 1)

# %%
tokens.head()
# Out:
#         token           score match
# 0    BENJUMEA    [71, enjuta]   NaN
# 1  Prevendado   [71, revenga]   NaN
# 2     Lateral    [77, antera]   NaN
# 3     MORILLO  [100, morillo]   NaN
# 4       Ramon    [100, ramon]   NaN

# %%
tokens['match']=tokens.apply(lambda x: x['score'][1],axis=1)

# %%
tokens['score']=tokens.apply(lambda x: x['score'][0], axis=1)

# %%
tokens.head()
# Out:
#         token  score    match
# 0    BENJUMEA     71   enjuta
# 1  Prevendado     71  revenga
# 2     Lateral     77   antera
# 3     MORILLO    100  morillo
# 4       Ramon    100    ramon

# %%
tokens.to_csv('token_match_scores.csv')

# %%
tokens[tokens['score']>90]
# Out:
#         token  score    match
# 3     MORILLO    100  morillo
# 4       Ramon    100    ramon
# 5       Ruela     91  iruñela
# 6     morante    100  morante
# 8      Coello    100   coello
# ...       ...    ...      ...
# 7282  mendosa     92  mendoça
# 7283  carrion    100  carrion
# 7285    osuna    100    osuna
# 7286   lesmes    100   lesmes
# 7287  Justino    100  justino
#
# [3675 rows x 3 columns]

# %%
tokens = pd.read_csv('token_match_scores.csv')

# %%
tokens.set_index('token', inplace=True)

# %%
tokens.index
# Out:
# Index(['BENJUMEA', 'Prevendado', 'Lateral', 'MORILLO', 'Ramon', 'Ruela',
#        'morante', 'citacion', 'Coello', 'VELAZQUEZ',
#        ...
#        'nuño', 'cota', 'Infantes', 'mendosa', 'carrion', 'Ponze', 'osuna',
#        'lesmes', 'Justino', 'REVES'],
#       dtype='object', name='token', length=7289)

# %% [markdown]
# Function below:
#     will split a string into tokens, and then add up their max scores from the tokens dataframe.
#     We will divide by number of tokens to get the average match score, and accept any average match score above 90

# %%
def avgmatch(string):
    stringspl= string.split()
    scoresum=0
    if len(stringspl)>1:
        for token in stringspl:
            if token in tokens.index:
                a= tokens.loc[token,'score']
                scoresum=scoresum+a
        return(scoresum/len(stringspl))
    else:
        return 0

# %%
avgmatch("Manuel de Santiago")
# Out:
# 93.33333333333333

# %%
people['Remove'] = people.apply(lambda x: 90 if (avgmatch(x['string'])>90 and x['Remove'])=='' else x['Remove'], axis=1)

# %%
grouped = people.groupby('Remove')
grouped.count()
# Out:
#         Unnamed: 0  docid  string  label  start    end
# Remove
# 0            20750  20750   20750  20750  20750  20750
# 90            8937   8937    8937   8937   8937   8937
#               3433   3433    3433   3433   3433   3433

# %%
a= people.loc[people['Remove']==0,'string'].str.lower()
a= a.unique()
a= pd.Series(a)
len(a)
# Out:
# 6752

# %%
b= people.loc[people['Remove']==90,'string'].str.lower()
b= b.unique()
b= pd.Series(b)
len(b)
# Out:
# 4094

# %%
c= people.loc[people['Remove']=='','string'].str.lower()
c= c.unique()
c= pd.Series(c)
len(c)
# Out:
# 2177

# %%
b.to_csv("Files_Cleaning1/acceptedpersnames.csv")
c.to_csv("Files_Cleaning1/remainingpersnames.csv")

# %%
people.to_csv("Files_Cleaning1/people_strat3.csv")

# %% [markdown]
# # Strategy 4: Revision of Remaining unaccepted strings
#
# Next, we went over these manually in excel, marking those that were clearly not names with a 1. We we also marked names that should be recategorized, and those that were correct, leaving blank only those that needed to be double checked against the document.

# %%
import pandas as pd
manual = pd.read_excel("Files_Cleaning1/RemainingPERS_HandTagged.xlsx")

# %%
manual.set_index('string',inplace=True)

# %%
manual.head()
# Out:
#              Unnamed: 0 Remove
# string
# NaN                   0    NaN
# - rodriguez           1      0
# -- manrique           2      0
# -- ramirez            3      0
# -- sarabia            4      0

# %%
manual['Remove'] = manual['Remove'].astype(str)
manual['Remove'] = manual['Remove'].replace('nan','')

# %%
manual.groupby('Remove').count()
# Out:
#         Unnamed: 0
# Remove
#                510
# 0             1371
# 1              269
# D                1
# L               11
# M                4
# O               11

# %% [markdown]
# Records tagged 0 (zero) were accepted through the exact match approach; those tagged 90 were accepted through fuzzy matching.
#
# Records tagged O (letter o), L, D, M should be re-tagged as organizations, locations, dates, money respectively.
#
# Records tagged 1 must be removed
#
# And records without a remove tag must go on to the next phase of cleaning, checking against the documents.

# %% [markdown]
# Next, let's update the people DF with the manually added tags.

# %%
people = pd.read_csv("Files_Cleaning1/people_strat3.csv")

# %%
people['Remove'] = people['Remove'].astype(str)
people['Remove'] = people['Remove'].replace('nan','')
people['Remove'] = people['Remove'].replace('0.0','0')
people['Remove'] = people['Remove'].replace('90.0','90')

# %%
people.groupby('Remove').count()
# Out:
#         Unnamed: 0  Unnamed: 0.1  docid  string  label  start    end
# Remove
#               3433          3433   3433    3430   3433   3433   3433
# 0            20750         20750  20750   20750  20750  20750  20750
# 90            8937          8937   8937    8937   8937   8937   8937

# %%
people['Remove'] = people.apply(lambda x: manual.loc[str(x['string']).lower(),'Remove'] if str(x['string']).lower() in manual.index else x['Remove'], axis=1)

# %%
grouped = people.groupby('Remove')
grouped.count()
# Out:
#         Unnamed: 0  Unnamed: 0.1  docid  string  label  start    end
# Remove
#                830           830    830     827    830    830    830
# 0            22974         22974  22974   22974  22974  22974  22974
# 1              321           321    321     321    321    321    321
# 90            8937          8937   8937    8937   8937   8937   8937
# D                1             1      1       1      1      1      1
# L               12            12     12      12     12     12     12
# M                5             5      5       5      5      5      5
# O               40            40     40      40     40     40     40

# %% [markdown]
# So we have 830 records remaining to mark for acceptance or removal. Of these, there are 510 distinct strings, which corresponds to the labels we could not identify manually.

# %%
rem= people.loc[people['Remove']=='','string'].str.lower()
rem= rem.unique()
rem= pd.Series(rem)
len(rem)
# Out:
# 510

# %% [markdown]
# We also went ahead and checked the accepted names from both the exact and fuzzy matching with the name dictionary. Excitingly, the vast majority were good matches, but we marked a few as wrong or dubious.

# %%
manual2 = pd.read_excel("AcceptedPERS_Checked.xlsx")
manual2.set_index('string',inplace=True)
manual2['Remove'] = manual2['Remove'].astype(str)
manual2['Remove'] = manual2['Remove'].replace('nan','')

# %%
manual2.groupby('Remove').count()
# Out:
#         Unnamed: 0
# Remove
#                 42
# 0             4038
# 1               11
# D                1
# L                2

# %%
people['Remove'] = people.apply(lambda x: manual2.loc[str(x['string']).lower(),'Remove'] if str(x['string']).lower() in manual2.index else x['Remove'], axis=1)

# %%
grouped = people.groupby('Remove')
grouped.count()
# Out:
#         Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  docid  string  label  start  \
# Remove
#                904           904             904    904     901    904    904
# 0            31820         31820           31820  31820   31820  31820  31820
# 1              333           333             333    333     333    333    333
# D                2             2               2      2       2      2      2
# L               16            16              16     16      16     16     16
# M                5             5               5      5       5      5      5
# O               40            40              40     40      40     40     40
#
#           end
# Remove
#           904
# 0       31820
# 1         333
# D           2
# L          16
# M           5
# O          40

# %% [markdown]
# And just to double check, we have 904 records to revise, of which 552 are distinct strings. This corresponds to the 510 + 42 unaccepted strings from our two excel files. We have not lost any records in our dataset.

# %%
rem= people.loc[people['Remove']=='','string'].str.lower()
rem= rem.unique()
rem= pd.Series(rem)
len(rem)
# Out:
# 552

# %%
len(people)
# Out:
# 33120

# %% [markdown]
# And let's save our intermediate CSV for future use too.

# %%
people.to_csv("Files_Cleaning1/people_strat4.csv")

# %% [markdown]
# # Strategy 5: Check Against the Documents
#
# The tags still not marked 0 have not been identified as names. We will look at them within the context of their documents to mark whether they are names or not.

# %%
# For future reference: per tags up to this point have been saved as "people_strat4.csv"

# %%
import pandas as pd
people = pd.read_csv("people_strat4.csv")

# %%
people['string'] = people['string'].astype(str)
people['Remove'] = people['Remove'].astype(str)
people['Remove'] = people['Remove'].replace('nan','')
people['Remove'] = people['Remove'].replace('0.0','0')

# %%
people
# Out:
#        Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  Unnamed: 0.1.1.1  docid  \
# 0               0             0           57935             57935   6792
# 1               1             1           45285             45285   4978
# 2               2             2           45173             45173   4961
# 3               3             3           45108             45108   4952
# 4               4             4           61780             61780   7342
# ...           ...           ...             ...               ...    ...
# 33115       33115         33115           45897             45897   5065
# 33116       33116         33116           65927             65927   7947
# 33117       33117         33117           11101             11101   1304
# 33118       33118         33118           32475             32475   3436
# 33119       33119         33119           13566             13566   1519
#
#                        string label  start  end Remove
# 0                         NaN   PER    135  138
# 1                 - Rodriguez   PER      6    8      0
# 2              -- Gomez Brito   PER     34   38      0
# 3                 -- Manrique   PER     11   13      0
# 4                  -- Ramirez   PER     29   31      0
# ...                       ...   ...    ...  ...    ...
# 33115        Angela Guillenes   PER     19   21      0
# 33116  Angela Rodriguez Borte   PER     28   31      0
# 33117                  çamora   PER    238  239      0
# 33118                  çamora   PER     90   91      0
# 33119        çumarraga maesos   PER    649  651      0
#
# [33120 rows x 10 columns]

# %%
grouped = people.groupby('Remove')
grouped.count()
# Out:
#         Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  Unnamed: 0.1.1.1  docid  \
# Remove
#                904           904             904               904    904
# 0            31820         31820           31820             31820  31820
# 1              333           333             333               333    333
# D                2             2               2                 2      2
# L               16            16              16                16     16
# M                5             5               5                 5      5
# O               40            40              40                40     40
#
#         string  label  start    end
# Remove
#            901    904    904    904
# 0        31820  31820  31820  31820
# 1          333    333    333    333
# D            2      2      2      2
# L           16     16     16     16
# M            5      5      5      5
# O           40     40     40     40

# %% [markdown]
# There are 1478 tags that do not contain at least one first name and one last name token from the lists above.  Next, we will go through them individually, looking at them in context, to determine whether they should be removed or kept.

# %%
from IPython.display import clear_output
import spacy
from spacy import displacy

# %%
import pickle

file = open("../Text Mining (NER)/ Trained_EMS2_NER_data.p", 'rb')
docs = pickle.load(file)

# %%
docs[1]
# Out:
# (...martin de gaynça... soy convenido... con los reverendos padres prior frailes e convento del monasterio de san pablo desta dicha ciudad de Sevilla... en tal manera que yo me obligo de fazer el cruzero de la iglesia junto a la capilla mayor... e de lo fazer de buena obra de canteria del puerto de santa maria del altura de la capilla mayor lo cual tengo de derrocar a mi costa con tanto que todo e material que saliere del dicho cruzero asi de piedra como de ladrillo sea mio e me obligo de ensanchar las ventanas del dicho cruzero del altura que fuere menester e desgarrar lo que fuere menester para ello e de encalar e torar los testeros donde estan las dichas ventanas (muy roto) e mas me obligo de fazer el pilarote sobre que a de venir el canpanario fasta en raz de la capilla e mas me obligo de alinpiar los dos arcos para la parte de la capilla que estan en el dicho cruzero... e de lo dar acabado en fin del mes de marzo de 1543... dandome 400 ducados,
#  {'id': 2})

# %%
type(docs[1][0])
# Out:
# spacy.tokens.doc.Doc

# %% [markdown]
# With the code below, I iterate through the rows of the people dataframe, finding those where remove is still blank. For these, I show a span of the document with all entities highlighted (10 tokens after the string). I can input 0, 1 or a letter representing the new tag. If this isn't enough, typing X allows me to view the whole document, after which I can input the choice.

# %%
for (index, row) in people.iterrows():
    if row['Remove']=='':
        print(row['string'])
        
        docid = row['docid']
        strstart = int(row['start'])
        fetchend = strstart + 10
        
        for doc in docs:
            if doc[1]['id'] == docid:      
                displacy.render(doc[0][strstart:fetchend],style='ent',jupyter=True)
                people.loc[index, 'Remove']=input('Remove?')
                
                if people.loc[index, 'Remove']=='X':
                    for doc in docs:
                        if doc[1]['id'] == docid:
                            displacy.render(doc[0],style='ent',jupyter=True)
                            people.loc[index,'Remove']=input('Remove?')
                clear_output(wait=True)
# Out:
# Alonso
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Alonso
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# , de la parte que le correspondiera en esta </div></span>
# Remove? X
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Miguel Cano
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  por escritura de esta fecha hizo cesion a su hijo
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Alonso
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# , de la parte que le correspondiera en esta obra.</div></span>
# Remove? 0

# %%
grouped = people.groupby('Remove')
grouped.count()
# Out:
#         Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  Unnamed: 0.1.1.1  docid  \
# Remove
# 0            32442         32442           32442             32442  32442
# 1              561           561             561               561    561
# D                6             6               6                 6      6
# L               39            39              39                39     39
# M                6             6               6                 6      6
# O               66            66              66                66     66
#
#         string  label  start    end
# Remove
# 0        32442  32442  32442  32442
# 1          561    561    561    561
# D            6      6      6      6
# L           39     39     39     39
# M            6      6      6      6
# O           66     66     66     66

# %%
people.to_csv("Files_Cleaning1/people_strat5.csv")

# %% [markdown]
# Ultimately, we removed 561 tags and reclassified a total of 127.
#
# The final step is to apply these changes to the relevant places: the people['label'] column and also the document which has the spacy tags.  DATE LOC MON ORG

# %%
people.groupby('label').count()
# Out:
#        Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  Unnamed: 0.1.1.1  docid  \
# label
# PER         33120         33120           33120             33120  33120
#
#        string  start    end  Remove
# label
# PER     33120  33120  33120   33120

# %%
people.loc[people['Remove']=='D','label']= 'DATE'
people.loc[people['Remove']=='L','label']= 'LOC'
people.loc[people['Remove']=='M','label']= 'MON'
people.loc[people['Remove']=='O','label']= 'ORG'
people.loc[people['Remove']=='1','label']= ''

# %%
people.groupby('label').count()
# Out:
#        Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  Unnamed: 0.1.1.1  docid  \
# label
#               561           561             561               561    561
# DATE            6             6               6                 6      6
# LOC            39            39              39                39     39
# MON             6             6               6                 6      6
# ORG            66            66              66                66     66
# PER         32442         32442           32442             32442  32442
#
#        string  start    end  Remove
# label
#           561    561    561     561
# DATE        6      6      6       6
# LOC        39     39     39      39
# MON         6      6      6       6
# ORG        66     66     66      66
# PER     32442  32442  32442   32442

# %%
people.to_csv("Files_Cleaning1/PER_tags_clean1.csv")

# %%
#We will have to remember to combine these with the file that has all tag types (not just 'PER').
